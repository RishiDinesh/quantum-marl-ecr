# %%
# Import necessary packages
from typing import Any, Dict, List, Tuple, Union

import numpy as np
import torch
from torch.optim import Adam, RMSprop

from maro.rl.model import DiscreteACBasedNet, FullyConnected, VNet
from maro.rl.policy import DiscretePolicyGradient
from maro.rl.rl_component.rl_component_bundle import RLComponentBundle
from maro.rl.rollout import AbsEnvSampler, CacheElement, ExpElement
from maro.rl.training import TrainingManager
from maro.rl.training.algorithms import PPOParams, PPOTrainer
from maro.simulator import Env
from maro.simulator.scenarios.cim.common import Action, ActionType, DecisionEvent

# %%
# env and shaping config
reward_shaping_conf = {
    "time_window": 99,
    "fulfillment_factor": 1.0,
    "shortage_factor": 1.0,
    "time_decay": 0.97,
}
state_shaping_conf = {
    "look_back": 7,
    "max_ports_downstream": 2,
}
port_attributes = ["empty", "full", "on_shipper", "on_consignee", "booking", "shortage", "fulfillment"]
vessel_attributes = ["empty", "full", "remaining_space"]
action_shaping_conf = {
    "action_space": [(i - 10) / 10 for i in range(21)],
    "finite_vessel_space": True,
    "has_early_discharge": True,
}

# %%
class CIMEnvSampler(AbsEnvSampler):
    def _get_global_and_agent_state_impl(self, event: DecisionEvent, tick: int = None,) -> Tuple[Union[None, np.ndarray, List[object]], Dict[Any, Union[np.ndarray, List[object]]]]:
        tick = self._env.tick
        vessel_snapshots, port_snapshots = self._env.snapshot_list["vessels"], self._env.snapshot_list["ports"]
        port_idx, vessel_idx = event.port_idx, event.vessel_idx
        ticks = [max(0, tick - rt) for rt in range(state_shaping_conf["look_back"] - 1)]
        future_port_list = vessel_snapshots[tick: vessel_idx: 'future_stop_list'].astype('int')
        state = np.concatenate([
            port_snapshots[ticks: [port_idx] + list(future_port_list): port_attributes],
            vessel_snapshots[tick: vessel_idx: vessel_attributes]
        ])
        return state, {port_idx: state}

    def _translate_to_env_action(
        self, action_dict: Dict[Any, Union[np.ndarray, List[object]]], event: DecisionEvent,
    ) -> Dict[Any, object]:
        action_space = action_shaping_conf["action_space"]
        finite_vsl_space = action_shaping_conf["finite_vessel_space"]
        has_early_discharge = action_shaping_conf["has_early_discharge"]

        port_idx, model_action = list(action_dict.items()).pop()

        vsl_idx, action_scope = event.vessel_idx, event.action_scope
        vsl_snapshots = self._env.snapshot_list["vessels"]
        vsl_space = vsl_snapshots[self._env.tick:vsl_idx:vessel_attributes][2] if finite_vsl_space else float("inf")

        percent = abs(action_space[model_action[0]])
        zero_action_idx = len(action_space) / 2  # index corresponding to value zero.
        if model_action < zero_action_idx:
            action_type = ActionType.LOAD
            actual_action = min(round(percent * action_scope.load), vsl_space)
        elif model_action > zero_action_idx:
            action_type = ActionType.DISCHARGE
            early_discharge = vsl_snapshots[self._env.tick:vsl_idx:"early_discharge"][0] if has_early_discharge else 0
            plan_action = percent * (action_scope.discharge + early_discharge) - early_discharge
            actual_action = round(plan_action) if plan_action > 0 else round(percent * action_scope.discharge)
        else:
            actual_action, action_type = 0, None

        return {port_idx: Action(vsl_idx, int(port_idx), actual_action, action_type)}

    def _get_reward(self, env_action_dict: Dict[Any, object], event: DecisionEvent, tick: int) -> Dict[Any, float]:
        start_tick = tick + 1
        ticks = list(range(start_tick, start_tick + reward_shaping_conf["time_window"]))

        # Get the ports that took actions at the given tick
        ports = [int(port) for port in list(env_action_dict.keys())]
        port_snapshots = self._env.snapshot_list["ports"]
        future_fulfillment = port_snapshots[ticks:ports:"fulfillment"].reshape(len(ticks), -1)
        future_shortage = port_snapshots[ticks:ports:"shortage"].reshape(len(ticks), -1)

        decay_list = [reward_shaping_conf["time_decay"] ** i for i in range(reward_shaping_conf["time_window"])]
        rewards = np.float32(
            reward_shaping_conf["fulfillment_factor"] * np.dot(future_fulfillment.T, decay_list)
            - reward_shaping_conf["shortage_factor"] * np.dot(future_shortage.T, decay_list)
        )
        return {agent_id: reward for agent_id, reward in zip(ports, rewards)}

    def _post_step(self, cache_element: CacheElement) -> None:
        self._info["env_metric"] = self._env.metrics

    def _post_eval_step(self, cache_element: CacheElement) -> None:
        self._post_step(cache_element)

    def post_collect(self, info_list: list, ep: int) -> None:
        # print the env metric from each rollout worker
        for info in info_list:
            print(f"env summary (episode {ep}): {info['env_metric']}")

        # print the average env metric
        if len(info_list) > 1:
            metric_keys, num_envs = info_list[0]["env_metric"].keys(), len(info_list)
            avg_metric = {key: sum(info["env_metric"][key] for info in info_list) / num_envs for key in metric_keys}
            print(f"average env summary (episode {ep}): {avg_metric}")

    def post_evaluate(self, info_list: list, ep: int) -> None:
        self.post_collect(info_list, ep)

# %%
from functools import partial
from typing import List

import torch
from torch.optim import Adam, RMSprop

from maro.rl.model import DiscreteACBasedNet, FullyConnected, MultiQNet
from maro.rl.policy import DiscretePolicyGradient
from maro.rl.training.algorithms import DiscreteMADDPGParams, DiscreteMADDPGTrainer

state_dim = (
    (state_shaping_conf["look_back"] + 1) * (state_shaping_conf["max_ports_downstream"] + 1) * len(port_attributes)
    + len(vessel_attributes)
)
action_num = len(action_shaping_conf["action_space"])

actor_net_conf = {
    "hidden_dims": [256, 128, 64],
    "activation": torch.nn.Tanh,
    "output_activation": torch.nn.Tanh,
    "softmax": True,
    "batch_norm": False,
    "head": True,
}
critic_net_conf = {
    "hidden_dims": [256, 128, 64],
    "output_dim": 1,
    "activation": torch.nn.LeakyReLU,
    "output_activation": torch.nn.LeakyReLU,
    "softmax": False,
    "batch_norm": True,
    "head": True,
}
actor_learning_rate = 0.001
critic_learning_rate = 0.001

class MyActorNet(DiscreteACBasedNet):
    def __init__(self, state_dim: int, action_num: int) -> None:
        super(MyActorNet, self).__init__(state_dim=state_dim, action_num=action_num)
        self._actor = FullyConnected(input_dim=state_dim, output_dim=action_num, **actor_net_conf)
        self._optim = Adam(self._actor.parameters(), lr=actor_learning_rate)

    def _get_action_probs_impl(self, states: torch.Tensor) -> torch.Tensor:
        return self._actor(states)


class MyMultiCriticNet(MultiQNet):
    def __init__(self, state_dim: int, action_dims: List[int]) -> None:
        super(MyMultiCriticNet, self).__init__(state_dim=state_dim, action_dims=action_dims)
        self._critic = FullyConnected(input_dim=state_dim + sum(action_dims), **critic_net_conf)
        self._optim = RMSprop(self._critic.parameters(), critic_learning_rate)

    def _get_q_values(self, states: torch.Tensor, actions: List[torch.Tensor]) -> torch.Tensor:
        return self._critic(torch.cat([states] + actions, dim=1)).squeeze(-1)


def get_multi_critic_net(state_dim: int, action_dims: List[int]) -> MyMultiCriticNet:
    return MyMultiCriticNet(state_dim, action_dims)


def get_maddpg_policy(state_dim: int, action_num: int, name: str) -> DiscretePolicyGradient:
    return DiscretePolicyGradient(name=name, policy_net=MyActorNet(state_dim, action_num))


def get_maddpg(state_dim: int, action_dims: List[int], name: str) -> DiscreteMADDPGTrainer:
    return DiscreteMADDPGTrainer(
        name=name,
        reward_discount=0.0,
        params=DiscreteMADDPGParams(
            num_epoch=10,
            get_q_critic_net_func=partial(get_multi_critic_net, state_dim, action_dims),
            shared_critic=False,
        ),
    )

# %%
learn_env = Env(scenario="cim", topology="toy.4p_ssdd_l0.0", durations=500,options={"enable-dump-snapshot": "./maddpg_learn"})
test_env = Env(scenario="cim", topology="toy.4p_ssdd_l0.1", durations=500,options={"enable-dump-snapshot": "./maddpg_test"})

num_agents = len(learn_env.agent_idx_list)
agent2policy = {agent: f"maddpg_{agent}.policy" for agent in learn_env.agent_idx_list}
policies = [get_maddpg_policy(state_dim, action_num, f"maddpg_{i}.policy") for i in range(num_agents)]
trainers = [get_maddpg(state_dim, [1], f"maddpg_{i}") for i in range(num_agents)]

# %%
# Build RLComponentBundle
rl_component_bundle = RLComponentBundle(
    env_sampler=CIMEnvSampler(
        learn_env=learn_env,
        test_env=test_env,
        policies=policies,
        agent2policy=agent2policy,
        reward_eval_delay=reward_shaping_conf["time_window"],
    ),
    agent2policy=agent2policy,
    policies=policies,
    trainers=trainers,
)

# %%
env_sampler = rl_component_bundle.env_sampler

num_episodes = 800
eval_schedule = [5*i for i in range(1,161)]
eval_point_index = 0

training_manager = TrainingManager(rl_component_bundle=rl_component_bundle)

# main loop
for ep in range(1, num_episodes + 1):
    result = env_sampler.sample()
    experiences: List[List[ExpElement]] = result["experiences"]
    info_list: List[dict] = result["info"]
        
    print("Collecting result:")
    env_sampler.post_collect(info_list, ep)
    print()

    training_manager.record_experiences(experiences)
    training_manager.train_step()

    if ep == eval_schedule[eval_point_index]:
        eval_point_index += 1
        result = env_sampler.eval()
        
        print("Evaluation result:")
        env_sampler.post_evaluate(result["info"], ep)
        print()

training_manager.exit()
# Out:
# Collecting result:
# env summary (episode 1): {'order_requirements': 1000000, 'container_shortage': 634299, 'operation_number': 1870821}
#
# Collecting result:
# env summary (episode 2): {'order_requirements': 1000000, 'container_shortage': 459398, 'operation_number': 1998575}
#
# Collecting result:
# env summary (episode 3): {'order_requirements': 1000000, 'container_shortage': 221582, 'operation_number': 1903085}
#
# Collecting result:
# env summary (episode 4): {'order_requirements': 1000000, 'container_shortage': 178950, 'operation_number': 1974516}
#
# Collecting result:
# env summary (episode 5): {'order_requirements': 1000000, 'container_shortage': 77691, 'operation_number': 1893779}
#
# Evaluation result:
# env summary (episode 5): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 6): {'order_requirements': 1000000, 'container_shortage': 60962, 'operation_number': 1914905}
#
# Collecting result:
# env summary (episode 7): {'order_requirements': 1000000, 'container_shortage': 94694, 'operation_number': 1868403}
#
# Collecting result:
# env summary (episode 8): {'order_requirements': 1000000, 'container_shortage': 87936, 'operation_number': 1822747}
#
# Collecting result:
# env summary (episode 9): {'order_requirements': 1000000, 'container_shortage': 149007, 'operation_number': 1714392}
#
# Collecting result:
# env summary (episode 10): {'order_requirements': 1000000, 'container_shortage': 146758, 'operation_number': 1741448}
#
# Evaluation result:
# env summary (episode 10): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 11): {'order_requirements': 1000000, 'container_shortage': 133415, 'operation_number': 1782618}
#
# Collecting result:
# env summary (episode 12): {'order_requirements': 1000000, 'container_shortage': 192158, 'operation_number': 1692916}
#
# Collecting result:
# env summary (episode 13): {'order_requirements': 1000000, 'container_shortage': 205615, 'operation_number': 1654837}
#
# Collecting result:
# env summary (episode 14): {'order_requirements': 1000000, 'container_shortage': 266890, 'operation_number': 1520732}
#
# Collecting result:
# env summary (episode 15): {'order_requirements': 1000000, 'container_shortage': 309063, 'operation_number': 1485949}
#
# Evaluation result:
# env summary (episode 15): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 16): {'order_requirements': 1000000, 'container_shortage': 264215, 'operation_number': 1566475}
#
# Collecting result:
# env summary (episode 17): {'order_requirements': 1000000, 'container_shortage': 237043, 'operation_number': 1617759}
#
# Collecting result:
# env summary (episode 18): {'order_requirements': 1000000, 'container_shortage': 329966, 'operation_number': 1394788}
#
# Collecting result:
# env summary (episode 19): {'order_requirements': 1000000, 'container_shortage': 269793, 'operation_number': 1548689}
#
# Collecting result:
# env summary (episode 20): {'order_requirements': 1000000, 'container_shortage': 173691, 'operation_number': 1772102}
#
# Evaluation result:
# env summary (episode 20): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 21): {'order_requirements': 1000000, 'container_shortage': 152800, 'operation_number': 1802818}
#
# Collecting result:
# env summary (episode 22): {'order_requirements': 1000000, 'container_shortage': 186320, 'operation_number': 1701057}
#
# Collecting result:
# env summary (episode 23): {'order_requirements': 1000000, 'container_shortage': 183218, 'operation_number': 1708590}
#
# Collecting result:
# env summary (episode 24): {'order_requirements': 1000000, 'container_shortage': 221362, 'operation_number': 1606509}
#
# Collecting result:
# env summary (episode 25): {'order_requirements': 1000000, 'container_shortage': 238850, 'operation_number': 1628306}
#
# Evaluation result:
# env summary (episode 25): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 26): {'order_requirements': 1000000, 'container_shortage': 227521, 'operation_number': 1602884}
#
# Collecting result:
# env summary (episode 27): {'order_requirements': 1000000, 'container_shortage': 245720, 'operation_number': 1613318}
#
# Collecting result:
# env summary (episode 28): {'order_requirements': 1000000, 'container_shortage': 226918, 'operation_number': 1626694}
#
# Collecting result:
# env summary (episode 29): {'order_requirements': 1000000, 'container_shortage': 156669, 'operation_number': 1777273}
#
# Collecting result:
# env summary (episode 30): {'order_requirements': 1000000, 'container_shortage': 239656, 'operation_number': 1623152}
#
# Evaluation result:
# env summary (episode 30): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 31): {'order_requirements': 1000000, 'container_shortage': 239557, 'operation_number': 1647533}
#
# Collecting result:
# env summary (episode 32): {'order_requirements': 1000000, 'container_shortage': 279763, 'operation_number': 1587659}
#
# Collecting result:
# env summary (episode 33): {'order_requirements': 1000000, 'container_shortage': 308432, 'operation_number': 1453803}
#
# Collecting result:
# env summary (episode 34): {'order_requirements': 1000000, 'container_shortage': 274624, 'operation_number': 1500195}
#
# Collecting result:
# env summary (episode 35): {'order_requirements': 1000000, 'container_shortage': 318733, 'operation_number': 1434588}
#
# Evaluation result:
# env summary (episode 35): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 36): {'order_requirements': 1000000, 'container_shortage': 326810, 'operation_number': 1453927}
#
# Collecting result:
# env summary (episode 37): {'order_requirements': 1000000, 'container_shortage': 270916, 'operation_number': 1538732}
#
# Collecting result:
# env summary (episode 38): {'order_requirements': 1000000, 'container_shortage': 287747, 'operation_number': 1500042}
#
# Collecting result:
# env summary (episode 39): {'order_requirements': 1000000, 'container_shortage': 313047, 'operation_number': 1499827}
#
# Collecting result:
# env summary (episode 40): {'order_requirements': 1000000, 'container_shortage': 353972, 'operation_number': 1417964}
#
# Evaluation result:
# env summary (episode 40): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 41): {'order_requirements': 1000000, 'container_shortage': 299028, 'operation_number': 1486264}
#
# Collecting result:
# env summary (episode 42): {'order_requirements': 1000000, 'container_shortage': 401048, 'operation_number': 1349707}
#
# Collecting result:
# env summary (episode 43): {'order_requirements': 1000000, 'container_shortage': 374569, 'operation_number': 1343697}
#
# Collecting result:
# env summary (episode 44): {'order_requirements': 1000000, 'container_shortage': 354171, 'operation_number': 1363045}
#
# Collecting result:
# env summary (episode 45): {'order_requirements': 1000000, 'container_shortage': 269534, 'operation_number': 1565230}
#
# Evaluation result:
# env summary (episode 45): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 46): {'order_requirements': 1000000, 'container_shortage': 330570, 'operation_number': 1408897}
#
# Collecting result:
# env summary (episode 47): {'order_requirements': 1000000, 'container_shortage': 374410, 'operation_number': 1311711}
#
# Collecting result:
# env summary (episode 48): {'order_requirements': 1000000, 'container_shortage': 422683, 'operation_number': 1207654}
#
# Collecting result:
# env summary (episode 49): {'order_requirements': 1000000, 'container_shortage': 540445, 'operation_number': 934535}
#
# Collecting result:
# env summary (episode 50): {'order_requirements': 1000000, 'container_shortage': 415475, 'operation_number': 1227309}
#
# Evaluation result:
# env summary (episode 50): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 51): {'order_requirements': 1000000, 'container_shortage': 454948, 'operation_number': 1133425}
#
# Collecting result:
# env summary (episode 52): {'order_requirements': 1000000, 'container_shortage': 448437, 'operation_number': 1145915}
#
# Collecting result:
# env summary (episode 53): {'order_requirements': 1000000, 'container_shortage': 292078, 'operation_number': 1510901}
#
# Collecting result:
# env summary (episode 54): {'order_requirements': 1000000, 'container_shortage': 578411, 'operation_number': 857974}
#
# Collecting result:
# env summary (episode 55): {'order_requirements': 1000000, 'container_shortage': 386641, 'operation_number': 1338917}
#
# Evaluation result:
# env summary (episode 55): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 56): {'order_requirements': 1000000, 'container_shortage': 372221, 'operation_number': 1352305}
#
# Collecting result:
# env summary (episode 57): {'order_requirements': 1000000, 'container_shortage': 413360, 'operation_number': 1321703}
#
# Collecting result:
# env summary (episode 58): {'order_requirements': 1000000, 'container_shortage': 386346, 'operation_number': 1285182}
#
# Collecting result:
# env summary (episode 59): {'order_requirements': 1000000, 'container_shortage': 424564, 'operation_number': 1197211}
#
# Collecting result:
# env summary (episode 60): {'order_requirements': 1000000, 'container_shortage': 334492, 'operation_number': 1411394}
#
# Evaluation result:
# env summary (episode 60): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 61): {'order_requirements': 1000000, 'container_shortage': 474826, 'operation_number': 1080964}
#
# Collecting result:
# env summary (episode 62): {'order_requirements': 1000000, 'container_shortage': 319305, 'operation_number': 1463369}
#
# Collecting result:
# env summary (episode 63): {'order_requirements': 1000000, 'container_shortage': 392040, 'operation_number': 1316428}
#
# Collecting result:
# env summary (episode 64): {'order_requirements': 1000000, 'container_shortage': 302093, 'operation_number': 1469038}
#
# Collecting result:
# env summary (episode 65): {'order_requirements': 1000000, 'container_shortage': 355173, 'operation_number': 1359671}
#
# Evaluation result:
# env summary (episode 65): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 66): {'order_requirements': 1000000, 'container_shortage': 370079, 'operation_number': 1319444}
#
# Collecting result:
# env summary (episode 67): {'order_requirements': 1000000, 'container_shortage': 446797, 'operation_number': 1149840}
#
# Collecting result:
# env summary (episode 68): {'order_requirements': 1000000, 'container_shortage': 468417, 'operation_number': 1225659}
#
# Collecting result:
# env summary (episode 69): {'order_requirements': 1000000, 'container_shortage': 489053, 'operation_number': 1130484}
#
# Collecting result:
# env summary (episode 70): {'order_requirements': 1000000, 'container_shortage': 323941, 'operation_number': 1431837}
#
# Evaluation result:
# env summary (episode 70): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 71): {'order_requirements': 1000000, 'container_shortage': 541089, 'operation_number': 1025901}
#
# Collecting result:
# env summary (episode 72): {'order_requirements': 1000000, 'container_shortage': 430189, 'operation_number': 1243250}
#
# Collecting result:
# env summary (episode 73): {'order_requirements': 1000000, 'container_shortage': 348376, 'operation_number': 1376757}
#
# Collecting result:
# env summary (episode 74): {'order_requirements': 1000000, 'container_shortage': 447404, 'operation_number': 1253903}
#
# Collecting result:
# env summary (episode 75): {'order_requirements': 1000000, 'container_shortage': 531479, 'operation_number': 958094}
#
# Evaluation result:
# env summary (episode 75): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 76): {'order_requirements': 1000000, 'container_shortage': 496675, 'operation_number': 1061644}
#
# Collecting result:
# env summary (episode 77): {'order_requirements': 1000000, 'container_shortage': 561568, 'operation_number': 974088}
#
# Collecting result:
# env summary (episode 78): {'order_requirements': 1000000, 'container_shortage': 525896, 'operation_number': 971270}
#
# Collecting result:
# env summary (episode 79): {'order_requirements': 1000000, 'container_shortage': 568113, 'operation_number': 881228}
#
# Collecting result:
# env summary (episode 80): {'order_requirements': 1000000, 'container_shortage': 481713, 'operation_number': 1155200}
#
# Evaluation result:
# env summary (episode 80): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 81): {'order_requirements': 1000000, 'container_shortage': 502381, 'operation_number': 1019375}
#
# Collecting result:
# env summary (episode 82): {'order_requirements': 1000000, 'container_shortage': 435518, 'operation_number': 1181992}
#
# Collecting result:
# env summary (episode 83): {'order_requirements': 1000000, 'container_shortage': 433594, 'operation_number': 1187015}
#
# Collecting result:
# env summary (episode 84): {'order_requirements': 1000000, 'container_shortage': 515619, 'operation_number': 1000844}
#
# Collecting result:
# env summary (episode 85): {'order_requirements': 1000000, 'container_shortage': 483267, 'operation_number': 1071987}
#
# Evaluation result:
# env summary (episode 85): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 86): {'order_requirements': 1000000, 'container_shortage': 572517, 'operation_number': 1006658}
#
# Collecting result:
# env summary (episode 87): {'order_requirements': 1000000, 'container_shortage': 503461, 'operation_number': 1022626}
#
# Collecting result:
# env summary (episode 88): {'order_requirements': 1000000, 'container_shortage': 625404, 'operation_number': 753139}
#
# Collecting result:
# env summary (episode 89): {'order_requirements': 1000000, 'container_shortage': 497189, 'operation_number': 1034257}
#
# Collecting result:
# env summary (episode 90): {'order_requirements': 1000000, 'container_shortage': 572313, 'operation_number': 865153}
#
# Evaluation result:
# env summary (episode 90): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 91): {'order_requirements': 1000000, 'container_shortage': 680214, 'operation_number': 637223}
#
# Collecting result:
# env summary (episode 92): {'order_requirements': 1000000, 'container_shortage': 489540, 'operation_number': 1054727}
#
# Collecting result:
# env summary (episode 93): {'order_requirements': 1000000, 'container_shortage': 543511, 'operation_number': 937234}
#
# Collecting result:
# env summary (episode 94): {'order_requirements': 1000000, 'container_shortage': 585457, 'operation_number': 922276}
#
# Collecting result:
# env summary (episode 95): {'order_requirements': 1000000, 'container_shortage': 432714, 'operation_number': 1188181}
#
# Evaluation result:
# env summary (episode 95): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 96): {'order_requirements': 1000000, 'container_shortage': 657291, 'operation_number': 685260}
#
# Collecting result:
# env summary (episode 97): {'order_requirements': 1000000, 'container_shortage': 602233, 'operation_number': 809029}
#
# Collecting result:
# env summary (episode 98): {'order_requirements': 1000000, 'container_shortage': 437584, 'operation_number': 1228295}
#
# Collecting result:
# env summary (episode 99): {'order_requirements': 1000000, 'container_shortage': 578995, 'operation_number': 854768}
#
# Collecting result:
# env summary (episode 100): {'order_requirements': 1000000, 'container_shortage': 411723, 'operation_number': 1226210}
#
# Evaluation result:
# env summary (episode 100): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 101): {'order_requirements': 1000000, 'container_shortage': 491527, 'operation_number': 1095565}
#
# Collecting result:
# env summary (episode 102): {'order_requirements': 1000000, 'container_shortage': 432691, 'operation_number': 1181904}
#
# Collecting result:
# env summary (episode 103): {'order_requirements': 1000000, 'container_shortage': 491484, 'operation_number': 1130186}
#
# Collecting result:
# env summary (episode 104): {'order_requirements': 1000000, 'container_shortage': 467456, 'operation_number': 1096115}
#
# Collecting result:
# env summary (episode 105): {'order_requirements': 1000000, 'container_shortage': 504896, 'operation_number': 1077935}
#
# Evaluation result:
# env summary (episode 105): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 106): {'order_requirements': 1000000, 'container_shortage': 430130, 'operation_number': 1252161}
#
# Collecting result:
# env summary (episode 107): {'order_requirements': 1000000, 'container_shortage': 701112, 'operation_number': 726378}
#
# Collecting result:
# env summary (episode 108): {'order_requirements': 1000000, 'container_shortage': 509312, 'operation_number': 1007170}
#
# Collecting result:
# env summary (episode 109): {'order_requirements': 1000000, 'container_shortage': 434218, 'operation_number': 1180252}
#
# Collecting result:
# env summary (episode 110): {'order_requirements': 1000000, 'container_shortage': 682017, 'operation_number': 633223}
#
# Evaluation result:
# env summary (episode 110): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 111): {'order_requirements': 1000000, 'container_shortage': 585425, 'operation_number': 838208}
#
# Collecting result:
# env summary (episode 112): {'order_requirements': 1000000, 'container_shortage': 566264, 'operation_number': 879944}
#
# Collecting result:
# env summary (episode 113): {'order_requirements': 1000000, 'container_shortage': 515275, 'operation_number': 1015660}
#
# Collecting result:
# env summary (episode 114): {'order_requirements': 1000000, 'container_shortage': 365119, 'operation_number': 1367919}
#
# Collecting result:
# env summary (episode 115): {'order_requirements': 1000000, 'container_shortage': 420496, 'operation_number': 1267371}
#
# Evaluation result:
# env summary (episode 115): {'order_requirements': 1000000, 'container_shortage': 724072, 'operation_number': 486379}
#
# Collecting result:
# env summary (episode 116): {'order_requirements': 1000000, 'container_shortage': 352572, 'operation_number': 1369241}
#
# Collecting result:
# env summary (episode 117): {'order_requirements': 1000000, 'container_shortage': 492218, 'operation_number': 1046280}
#
# Collecting result:
# env summary (episode 118): {'order_requirements': 1000000, 'container_shortage': 394282, 'operation_number': 1311687}
#
# Collecting result:
# env summary (episode 119): {'order_requirements': 1000000, 'container_shortage': 443329, 'operation_number': 1208800}
#
# Collecting result:
# env summary (episode 120): {'order_requirements': 1000000, 'container_shortage': 338284, 'operation_number': 1407969}
#
# Evaluation result:
# env summary (episode 120): {'order_requirements': 1000000, 'container_shortage': 675681, 'operation_number': 554065}
#
# Collecting result:
# env summary (episode 121): {'order_requirements': 1000000, 'container_shortage': 343143, 'operation_number': 1447632}
#
# Collecting result:
# env summary (episode 122): {'order_requirements': 1000000, 'container_shortage': 268398, 'operation_number': 1560099}
#
# Collecting result:
# env summary (episode 123): {'order_requirements': 1000000, 'container_shortage': 313742, 'operation_number': 1439725}
#
# Collecting result:
# env summary (episode 124): {'order_requirements': 1000000, 'container_shortage': 272773, 'operation_number': 1552850}
#
# Collecting result:
# env summary (episode 125): {'order_requirements': 1000000, 'container_shortage': 290041, 'operation_number': 1470861}
#
# Evaluation result:
# env summary (episode 125): {'order_requirements': 1000000, 'container_shortage': 675681, 'operation_number': 554065}
#
# Collecting result:
# env summary (episode 126): {'order_requirements': 1000000, 'container_shortage': 246881, 'operation_number': 1599760}
#
# Collecting result:
# env summary (episode 127): {'order_requirements': 1000000, 'container_shortage': 337037, 'operation_number': 1389037}
#
# Collecting result:
# env summary (episode 128): {'order_requirements': 1000000, 'container_shortage': 244631, 'operation_number': 1576106}
#
# Collecting result:
# env summary (episode 129): {'order_requirements': 1000000, 'container_shortage': 224744, 'operation_number': 1623143}
#
# Collecting result:
# env summary (episode 130): {'order_requirements': 1000000, 'container_shortage': 235942, 'operation_number': 1599366}
#
# Evaluation result:
# env summary (episode 130): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 131): {'order_requirements': 1000000, 'container_shortage': 267051, 'operation_number': 1586899}
#
# Collecting result:
# env summary (episode 132): {'order_requirements': 1000000, 'container_shortage': 262903, 'operation_number': 1540404}
#
# Collecting result:
# env summary (episode 133): {'order_requirements': 1000000, 'container_shortage': 256064, 'operation_number': 1584624}
#
# Collecting result:
# env summary (episode 134): {'order_requirements': 1000000, 'container_shortage': 217927, 'operation_number': 1635952}
#
# Collecting result:
# env summary (episode 135): {'order_requirements': 1000000, 'container_shortage': 153737, 'operation_number': 1786293}
#
# Evaluation result:
# env summary (episode 135): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 136): {'order_requirements': 1000000, 'container_shortage': 243057, 'operation_number': 1595071}
#
# Collecting result:
# env summary (episode 137): {'order_requirements': 1000000, 'container_shortage': 217446, 'operation_number': 1637211}
#
# Collecting result:
# env summary (episode 138): {'order_requirements': 1000000, 'container_shortage': 260629, 'operation_number': 1541758}
#
# Collecting result:
# env summary (episode 139): {'order_requirements': 1000000, 'container_shortage': 242256, 'operation_number': 1588699}
#
# Collecting result:
# env summary (episode 140): {'order_requirements': 1000000, 'container_shortage': 255453, 'operation_number': 1580491}
#
# Evaluation result:
# env summary (episode 140): {'order_requirements': 1000000, 'container_shortage': 675681, 'operation_number': 554065}
#
# Collecting result:
# env summary (episode 141): {'order_requirements': 1000000, 'container_shortage': 226836, 'operation_number': 1619430}
#
# Collecting result:
# env summary (episode 142): {'order_requirements': 1000000, 'container_shortage': 266842, 'operation_number': 1531901}
#
# Collecting result:
# env summary (episode 143): {'order_requirements': 1000000, 'container_shortage': 237694, 'operation_number': 1585046}
#
# Collecting result:
# env summary (episode 144): {'order_requirements': 1000000, 'container_shortage': 277311, 'operation_number': 1506062}
#
# Collecting result:
# env summary (episode 145): {'order_requirements': 1000000, 'container_shortage': 250092, 'operation_number': 1578822}
#
# Evaluation result:
# env summary (episode 145): {'order_requirements': 1000000, 'container_shortage': 675681, 'operation_number': 554065}
#
# Collecting result:
# env summary (episode 146): {'order_requirements': 1000000, 'container_shortage': 241409, 'operation_number': 1583282}
#
# Collecting result:
# env summary (episode 147): {'order_requirements': 1000000, 'container_shortage': 233587, 'operation_number': 1594124}
#
# Collecting result:
# env summary (episode 148): {'order_requirements': 1000000, 'container_shortage': 202391, 'operation_number': 1680318}
#
# Collecting result:
# env summary (episode 149): {'order_requirements': 1000000, 'container_shortage': 222586, 'operation_number': 1638620}
#
# Collecting result:
# env summary (episode 150): {'order_requirements': 1000000, 'container_shortage': 214198, 'operation_number': 1622264}
#
# Evaluation result:
# env summary (episode 150): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 151): {'order_requirements': 1000000, 'container_shortage': 163271, 'operation_number': 1716553}
#
# Collecting result:
# env summary (episode 152): {'order_requirements': 1000000, 'container_shortage': 210948, 'operation_number': 1639721}
#
# Collecting result:
# env summary (episode 153): {'order_requirements': 1000000, 'container_shortage': 178671, 'operation_number': 1686615}
#
# Collecting result:
# env summary (episode 154): {'order_requirements': 1000000, 'container_shortage': 209090, 'operation_number': 1624986}
#
# Collecting result:
# env summary (episode 155): {'order_requirements': 1000000, 'container_shortage': 228860, 'operation_number': 1614557}
#
# Evaluation result:
# env summary (episode 155): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 156): {'order_requirements': 1000000, 'container_shortage': 216448, 'operation_number': 1620443}
#
# Collecting result:
# env summary (episode 157): {'order_requirements': 1000000, 'container_shortage': 201609, 'operation_number': 1646996}
#
# Collecting result:
# env summary (episode 158): {'order_requirements': 1000000, 'container_shortage': 198625, 'operation_number': 1656603}
#
# Collecting result:
# env summary (episode 159): {'order_requirements': 1000000, 'container_shortage': 209239, 'operation_number': 1637032}
#
# Collecting result:
# env summary (episode 160): {'order_requirements': 1000000, 'container_shortage': 202314, 'operation_number': 1645758}
#
# Evaluation result:
# env summary (episode 160): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 161): {'order_requirements': 1000000, 'container_shortage': 187990, 'operation_number': 1678110}
#
# Collecting result:
# env summary (episode 162): {'order_requirements': 1000000, 'container_shortage': 204872, 'operation_number': 1636696}
#
# Collecting result:
# env summary (episode 163): {'order_requirements': 1000000, 'container_shortage': 188812, 'operation_number': 1663004}
#
# Collecting result:
# env summary (episode 164): {'order_requirements': 1000000, 'container_shortage': 199246, 'operation_number': 1641983}
#
# Collecting result:
# env summary (episode 165): {'order_requirements': 1000000, 'container_shortage': 202440, 'operation_number': 1643723}
#
# Evaluation result:
# env summary (episode 165): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 166): {'order_requirements': 1000000, 'container_shortage': 195038, 'operation_number': 1647934}
#
# Collecting result:
# env summary (episode 167): {'order_requirements': 1000000, 'container_shortage': 193244, 'operation_number': 1645483}
#
# Collecting result:
# env summary (episode 168): {'order_requirements': 1000000, 'container_shortage': 120184, 'operation_number': 1805850}
#
# Collecting result:
# env summary (episode 169): {'order_requirements': 1000000, 'container_shortage': 184042, 'operation_number': 1664771}
#
# Collecting result:
# env summary (episode 170): {'order_requirements': 1000000, 'container_shortage': 185409, 'operation_number': 1658124}
#
# Evaluation result:
# env summary (episode 170): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 171): {'order_requirements': 1000000, 'container_shortage': 177127, 'operation_number': 1684088}
#
# Collecting result:
# env summary (episode 172): {'order_requirements': 1000000, 'container_shortage': 186648, 'operation_number': 1665114}
#
# Collecting result:
# env summary (episode 173): {'order_requirements': 1000000, 'container_shortage': 164719, 'operation_number': 1713644}
#
# Collecting result:
# env summary (episode 174): {'order_requirements': 1000000, 'container_shortage': 185538, 'operation_number': 1656525}
#
# Collecting result:
# env summary (episode 175): {'order_requirements': 1000000, 'container_shortage': 207897, 'operation_number': 1636290}
#
# Evaluation result:
# env summary (episode 175): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 176): {'order_requirements': 1000000, 'container_shortage': 162391, 'operation_number': 1704645}
#
# Collecting result:
# env summary (episode 177): {'order_requirements': 1000000, 'container_shortage': 195008, 'operation_number': 1644983}
#
# Collecting result:
# env summary (episode 178): {'order_requirements': 1000000, 'container_shortage': 159828, 'operation_number': 1710625}
#
# Collecting result:
# env summary (episode 179): {'order_requirements': 1000000, 'container_shortage': 187334, 'operation_number': 1661685}
#
# Collecting result:
# env summary (episode 180): {'order_requirements': 1000000, 'container_shortage': 182979, 'operation_number': 1668137}
#
# Evaluation result:
# env summary (episode 180): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 181): {'order_requirements': 1000000, 'container_shortage': 207662, 'operation_number': 1621266}
#
# Collecting result:
# env summary (episode 182): {'order_requirements': 1000000, 'container_shortage': 183591, 'operation_number': 1673065}
#
# Collecting result:
# env summary (episode 183): {'order_requirements': 1000000, 'container_shortage': 166531, 'operation_number': 1696257}
#
# Collecting result:
# env summary (episode 184): {'order_requirements': 1000000, 'container_shortage': 188480, 'operation_number': 1655104}
#
# Collecting result:
# env summary (episode 185): {'order_requirements': 1000000, 'container_shortage': 205675, 'operation_number': 1624366}
#
# Evaluation result:
# env summary (episode 185): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 186): {'order_requirements': 1000000, 'container_shortage': 167933, 'operation_number': 1708432}
#
# Collecting result:
# env summary (episode 187): {'order_requirements': 1000000, 'container_shortage': 196940, 'operation_number': 1640540}
#
# Collecting result:
# env summary (episode 188): {'order_requirements': 1000000, 'container_shortage': 200537, 'operation_number': 1636510}
#
# Collecting result:
# env summary (episode 189): {'order_requirements': 1000000, 'container_shortage': 197036, 'operation_number': 1647980}
#
# Collecting result:
# env summary (episode 190): {'order_requirements': 1000000, 'container_shortage': 177140, 'operation_number': 1675163}
#
# Evaluation result:
# env summary (episode 190): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 191): {'order_requirements': 1000000, 'container_shortage': 170823, 'operation_number': 1691299}
#
# Collecting result:
# env summary (episode 192): {'order_requirements': 1000000, 'container_shortage': 155997, 'operation_number': 1720820}
#
# Collecting result:
# env summary (episode 193): {'order_requirements': 1000000, 'container_shortage': 178918, 'operation_number': 1674504}
#
# Collecting result:
# env summary (episode 194): {'order_requirements': 1000000, 'container_shortage': 166062, 'operation_number': 1696574}
#
# Collecting result:
# env summary (episode 195): {'order_requirements': 1000000, 'container_shortage': 193830, 'operation_number': 1645311}
#
# Evaluation result:
# env summary (episode 195): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 196): {'order_requirements': 1000000, 'container_shortage': 171154, 'operation_number': 1691556}
#
# Collecting result:
# env summary (episode 197): {'order_requirements': 1000000, 'container_shortage': 123893, 'operation_number': 1766857}
#
# Collecting result:
# env summary (episode 198): {'order_requirements': 1000000, 'container_shortage': 154923, 'operation_number': 1716807}
#
# Collecting result:
# env summary (episode 199): {'order_requirements': 1000000, 'container_shortage': 194474, 'operation_number': 1644177}
#
# Collecting result:
# env summary (episode 200): {'order_requirements': 1000000, 'container_shortage': 176436, 'operation_number': 1688844}
#
# Evaluation result:
# env summary (episode 200): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 201): {'order_requirements': 1000000, 'container_shortage': 79876, 'operation_number': 1855030}
#
# Collecting result:
# env summary (episode 202): {'order_requirements': 1000000, 'container_shortage': 209587, 'operation_number': 1617468}
#
# Collecting result:
# env summary (episode 203): {'order_requirements': 1000000, 'container_shortage': 128751, 'operation_number': 1773510}
#
# Collecting result:
# env summary (episode 204): {'order_requirements': 1000000, 'container_shortage': 175019, 'operation_number': 1693963}
#
# Collecting result:
# env summary (episode 205): {'order_requirements': 1000000, 'container_shortage': 129640, 'operation_number': 1770691}
#
# Evaluation result:
# env summary (episode 205): {'order_requirements': 1000000, 'container_shortage': 134839, 'operation_number': 1433132}
#
# Collecting result:
# env summary (episode 206): {'order_requirements': 1000000, 'container_shortage': 189846, 'operation_number': 1659612}
#
# Collecting result:
# env summary (episode 207): {'order_requirements': 1000000, 'container_shortage': 213703, 'operation_number': 1621107}
#
# Collecting result:
# env summary (episode 208): {'order_requirements': 1000000, 'container_shortage': 153166, 'operation_number': 1728014}
#
# Collecting result:
# env summary (episode 209): {'order_requirements': 1000000, 'container_shortage': 183029, 'operation_number': 1676062}
#
# Collecting result:
# env summary (episode 210): {'order_requirements': 1000000, 'container_shortage': 161597, 'operation_number': 1696739}
#
# Evaluation result:
# env summary (episode 210): {'order_requirements': 1000000, 'container_shortage': 139107, 'operation_number': 1429733}
#
# Collecting result:
# env summary (episode 211): {'order_requirements': 1000000, 'container_shortage': 88801, 'operation_number': 1835486}
#
# Collecting result:
# env summary (episode 212): {'order_requirements': 1000000, 'container_shortage': 208843, 'operation_number': 1618377}
#
# Collecting result:
# env summary (episode 213): {'order_requirements': 1000000, 'container_shortage': 199387, 'operation_number': 1633577}
#
# Collecting result:
# env summary (episode 214): {'order_requirements': 1000000, 'container_shortage': 223320, 'operation_number': 1598575}
#
# Collecting result:
# env summary (episode 215): {'order_requirements': 1000000, 'container_shortage': 188913, 'operation_number': 1655759}
#
# Evaluation result:
# env summary (episode 215): {'order_requirements': 1000000, 'container_shortage': 139107, 'operation_number': 1429733}
#
# Collecting result:
# env summary (episode 216): {'order_requirements': 1000000, 'container_shortage': 161981, 'operation_number': 1713674}
#
# Collecting result:
# env summary (episode 217): {'order_requirements': 1000000, 'container_shortage': 177635, 'operation_number': 1679943}
#
# Collecting result:
# env summary (episode 218): {'order_requirements': 1000000, 'container_shortage': 197784, 'operation_number': 1628359}
#
# Collecting result:
# env summary (episode 219): {'order_requirements': 1000000, 'container_shortage': 251682, 'operation_number': 1543157}
#
# Collecting result:
# env summary (episode 220): {'order_requirements': 1000000, 'container_shortage': 332133, 'operation_number': 1329880}
#
# Evaluation result:
# env summary (episode 220): {'order_requirements': 1000000, 'container_shortage': 481708, 'operation_number': 798773}
#
# Collecting result:
# env summary (episode 221): {'order_requirements': 1000000, 'container_shortage': 319609, 'operation_number': 1333249}
#
# Collecting result:
# env summary (episode 222): {'order_requirements': 1000000, 'container_shortage': 299639, 'operation_number': 1381583}
#
# Collecting result:
# env summary (episode 223): {'order_requirements': 1000000, 'container_shortage': 324992, 'operation_number': 1330337}
#
# Collecting result:
# env summary (episode 224): {'order_requirements': 1000000, 'container_shortage': 372960, 'operation_number': 1237293}
#
# Collecting result:
# env summary (episode 225): {'order_requirements': 1000000, 'container_shortage': 286369, 'operation_number': 1404476}
#
# Evaluation result:
# env summary (episode 225): {'order_requirements': 1000000, 'container_shortage': 481708, 'operation_number': 798773}
#
# Collecting result:
# env summary (episode 226): {'order_requirements': 1000000, 'container_shortage': 305526, 'operation_number': 1365958}
#
# Collecting result:
# env summary (episode 227): {'order_requirements': 1000000, 'container_shortage': 352936, 'operation_number': 1291939}
#
# Collecting result:
# env summary (episode 228): {'order_requirements': 1000000, 'container_shortage': 342629, 'operation_number': 1297116}
#
# Collecting result:
# env summary (episode 229): {'order_requirements': 1000000, 'container_shortage': 317615, 'operation_number': 1335052}
#
# Collecting result:
# env summary (episode 230): {'order_requirements': 1000000, 'container_shortage': 227619, 'operation_number': 1478815}
#
# Evaluation result:
# env summary (episode 230): {'order_requirements': 1000000, 'container_shortage': 481708, 'operation_number': 798773}
#
# Collecting result:
# env summary (episode 231): {'order_requirements': 1000000, 'container_shortage': 232407, 'operation_number': 1498881}
#
# Collecting result:
# env summary (episode 232): {'order_requirements': 1000000, 'container_shortage': 269469, 'operation_number': 1410857}
#
# Collecting result:
# env summary (episode 233): {'order_requirements': 1000000, 'container_shortage': 273553, 'operation_number': 1413833}
#
# Collecting result:
# env summary (episode 234): {'order_requirements': 1000000, 'container_shortage': 275301, 'operation_number': 1382539}
#
# Collecting result:
# env summary (episode 235): {'order_requirements': 1000000, 'container_shortage': 276650, 'operation_number': 1385344}
#
# Evaluation result:
# env summary (episode 235): {'order_requirements': 1000000, 'container_shortage': 481708, 'operation_number': 798773}
#
# Collecting result:
# env summary (episode 236): {'order_requirements': 1000000, 'container_shortage': 236282, 'operation_number': 1456009}
#
# Collecting result:
# env summary (episode 237): {'order_requirements': 1000000, 'container_shortage': 244856, 'operation_number': 1444920}
#
# Collecting result:
# env summary (episode 238): {'order_requirements': 1000000, 'container_shortage': 308319, 'operation_number': 1355627}
#
# Collecting result:
# env summary (episode 239): {'order_requirements': 1000000, 'container_shortage': 269533, 'operation_number': 1385038}
#
# Collecting result:
# env summary (episode 240): {'order_requirements': 1000000, 'container_shortage': 279119, 'operation_number': 1379117}
#
# Evaluation result:
# env summary (episode 240): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 241): {'order_requirements': 1000000, 'container_shortage': 288342, 'operation_number': 1348511}
#
# Collecting result:
# env summary (episode 242): {'order_requirements': 1000000, 'container_shortage': 285449, 'operation_number': 1350412}
#
# Collecting result:
# env summary (episode 243): {'order_requirements': 1000000, 'container_shortage': 327346, 'operation_number': 1267528}
#
# Collecting result:
# env summary (episode 244): {'order_requirements': 1000000, 'container_shortage': 400119, 'operation_number': 1145616}
#
# Collecting result:
# env summary (episode 245): {'order_requirements': 1000000, 'container_shortage': 306796, 'operation_number': 1338778}
#
# Evaluation result:
# env summary (episode 245): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 246): {'order_requirements': 1000000, 'container_shortage': 353339, 'operation_number': 1215874}
#
# Collecting result:
# env summary (episode 247): {'order_requirements': 1000000, 'container_shortage': 374408, 'operation_number': 1195395}
#
# Collecting result:
# env summary (episode 248): {'order_requirements': 1000000, 'container_shortage': 328631, 'operation_number': 1308694}
#
# Collecting result:
# env summary (episode 249): {'order_requirements': 1000000, 'container_shortage': 346194, 'operation_number': 1253215}
#
# Collecting result:
# env summary (episode 250): {'order_requirements': 1000000, 'container_shortage': 360940, 'operation_number': 1196223}
#
# Evaluation result:
# env summary (episode 250): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 251): {'order_requirements': 1000000, 'container_shortage': 365552, 'operation_number': 1181345}
#
# Collecting result:
# env summary (episode 252): {'order_requirements': 1000000, 'container_shortage': 395399, 'operation_number': 1119980}
#
# Collecting result:
# env summary (episode 253): {'order_requirements': 1000000, 'container_shortage': 446684, 'operation_number': 1053175}
#
# Collecting result:
# env summary (episode 254): {'order_requirements': 1000000, 'container_shortage': 454996, 'operation_number': 1003960}
#
# Collecting result:
# env summary (episode 255): {'order_requirements': 1000000, 'container_shortage': 500791, 'operation_number': 945369}
#
# Evaluation result:
# env summary (episode 255): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 256): {'order_requirements': 1000000, 'container_shortage': 491439, 'operation_number': 929499}
#
# Collecting result:
# env summary (episode 257): {'order_requirements': 1000000, 'container_shortage': 538502, 'operation_number': 828989}
#
# Collecting result:
# env summary (episode 258): {'order_requirements': 1000000, 'container_shortage': 584337, 'operation_number': 734544}
#
# Collecting result:
# env summary (episode 259): {'order_requirements': 1000000, 'container_shortage': 534988, 'operation_number': 885594}
#
# Collecting result:
# env summary (episode 260): {'order_requirements': 1000000, 'container_shortage': 538042, 'operation_number': 834847}
#
# Evaluation result:
# env summary (episode 260): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 261): {'order_requirements': 1000000, 'container_shortage': 536056, 'operation_number': 834775}
#
# Collecting result:
# env summary (episode 262): {'order_requirements': 1000000, 'container_shortage': 636029, 'operation_number': 713466}
#
# Collecting result:
# env summary (episode 263): {'order_requirements': 1000000, 'container_shortage': 526183, 'operation_number': 882907}
#
# Collecting result:
# env summary (episode 264): {'order_requirements': 1000000, 'container_shortage': 608546, 'operation_number': 694929}
#
# Collecting result:
# env summary (episode 265): {'order_requirements': 1000000, 'container_shortage': 625467, 'operation_number': 653151}
#
# Evaluation result:
# env summary (episode 265): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 266): {'order_requirements': 1000000, 'container_shortage': 617891, 'operation_number': 666614}
#
# Collecting result:
# env summary (episode 267): {'order_requirements': 1000000, 'container_shortage': 675904, 'operation_number': 599293}
#
# Collecting result:
# env summary (episode 268): {'order_requirements': 1000000, 'container_shortage': 790179, 'operation_number': 421242}
#
# Collecting result:
# env summary (episode 269): {'order_requirements': 1000000, 'container_shortage': 693242, 'operation_number': 514385}
#
# Collecting result:
# env summary (episode 270): {'order_requirements': 1000000, 'container_shortage': 817070, 'operation_number': 266775}
#
# Evaluation result:
# env summary (episode 270): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 271): {'order_requirements': 1000000, 'container_shortage': 724928, 'operation_number': 515990}
#
# Collecting result:
# env summary (episode 272): {'order_requirements': 1000000, 'container_shortage': 514640, 'operation_number': 923082}
#
# Collecting result:
# env summary (episode 273): {'order_requirements': 1000000, 'container_shortage': 504587, 'operation_number': 897989}
#
# Collecting result:
# env summary (episode 274): {'order_requirements': 1000000, 'container_shortage': 613400, 'operation_number': 675313}
#
# Collecting result:
# env summary (episode 275): {'order_requirements': 1000000, 'container_shortage': 638289, 'operation_number': 629795}
#
# Evaluation result:
# env summary (episode 275): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 276): {'order_requirements': 1000000, 'container_shortage': 746192, 'operation_number': 579644}
#
# Collecting result:
# env summary (episode 277): {'order_requirements': 1000000, 'container_shortage': 655910, 'operation_number': 734833}
#
# Collecting result:
# env summary (episode 278): {'order_requirements': 1000000, 'container_shortage': 655146, 'operation_number': 645509}
#
# Collecting result:
# env summary (episode 279): {'order_requirements': 1000000, 'container_shortage': 570282, 'operation_number': 841004}
#
# Collecting result:
# env summary (episode 280): {'order_requirements': 1000000, 'container_shortage': 543176, 'operation_number': 819995}
#
# Evaluation result:
# env summary (episode 280): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 281): {'order_requirements': 1000000, 'container_shortage': 426157, 'operation_number': 1060708}
#
# Collecting result:
# env summary (episode 282): {'order_requirements': 1000000, 'container_shortage': 457994, 'operation_number': 1038311}
#
# Collecting result:
# env summary (episode 283): {'order_requirements': 1000000, 'container_shortage': 523802, 'operation_number': 878929}
#
# Collecting result:
# env summary (episode 284): {'order_requirements': 1000000, 'container_shortage': 518938, 'operation_number': 869737}
#
# Collecting result:
# env summary (episode 285): {'order_requirements': 1000000, 'container_shortage': 597287, 'operation_number': 765185}
#
# Evaluation result:
# env summary (episode 285): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 286): {'order_requirements': 1000000, 'container_shortage': 638297, 'operation_number': 625070}
#
# Collecting result:
# env summary (episode 287): {'order_requirements': 1000000, 'container_shortage': 602518, 'operation_number': 713379}
#
# Collecting result:
# env summary (episode 288): {'order_requirements': 1000000, 'container_shortage': 599909, 'operation_number': 702120}
#
# Collecting result:
# env summary (episode 289): {'order_requirements': 1000000, 'container_shortage': 695923, 'operation_number': 625661}
#
# Collecting result:
# env summary (episode 290): {'order_requirements': 1000000, 'container_shortage': 575948, 'operation_number': 759018}
#
# Evaluation result:
# env summary (episode 290): {'order_requirements': 1000000, 'container_shortage': 851510, 'operation_number': 198387}
#
# Collecting result:
# env summary (episode 291): {'order_requirements': 1000000, 'container_shortage': 568783, 'operation_number': 796143}
#
# Collecting result:
# ...
#
# Collecting result:
# env summary (episode 705): {'order_requirements': 1000000, 'container_shortage': 764495, 'operation_number': 371028}
#
# Evaluation result:
# env summary (episode 705): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 706): {'order_requirements': 1000000, 'container_shortage': 764400, 'operation_number': 371330}
#
# Collecting result:
# env summary (episode 707): {'order_requirements': 1000000, 'container_shortage': 766766, 'operation_number': 367882}
#
# Collecting result:
# env summary (episode 708): {'order_requirements': 1000000, 'container_shortage': 600472, 'operation_number': 700442}
#
# Collecting result:
# env summary (episode 709): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 710): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 710): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 711): {'order_requirements': 1000000, 'container_shortage': 761006, 'operation_number': 378026}
#
# Collecting result:
# env summary (episode 712): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 713): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 714): {'order_requirements': 1000000, 'container_shortage': 763472, 'operation_number': 373086}
#
# Collecting result:
# env summary (episode 715): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 715): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 716): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 717): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 718): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 719): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 720): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 720): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 721): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 722): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 723): {'order_requirements': 1000000, 'container_shortage': 663208, 'operation_number': 574968}
#
# Collecting result:
# env summary (episode 724): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 725): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 725): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 726): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 727): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 728): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 729): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 730): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 730): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 731): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 732): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 733): {'order_requirements': 1000000, 'container_shortage': 581760, 'operation_number': 753632}
#
# Collecting result:
# env summary (episode 734): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 735): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 735): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 736): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 737): {'order_requirements': 1000000, 'container_shortage': 605833, 'operation_number': 689440}
#
# Collecting result:
# env summary (episode 738): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 739): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 420538}
#
# Collecting result:
# env summary (episode 740): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 740): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 741): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 742): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 743): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 744): {'order_requirements': 1000000, 'container_shortage': 764096, 'operation_number': 371844}
#
# Collecting result:
# env summary (episode 745): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 745): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 746): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 747): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 748): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 749): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 750): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 750): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 751): {'order_requirements': 1000000, 'container_shortage': 721688, 'operation_number': 456652}
#
# Collecting result:
# env summary (episode 752): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 753): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 754): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 755): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 755): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 756): {'order_requirements': 1000000, 'container_shortage': 715237, 'operation_number': 469828}
#
# Collecting result:
# env summary (episode 757): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 758): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 759): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 760): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 760): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 761): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 762): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 763): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 764): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 765): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 765): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 766): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 767): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 768): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 769): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 770): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 770): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 771): {'order_requirements': 1000000, 'container_shortage': 766025, 'operation_number': 369112}
#
# Collecting result:
# env summary (episode 772): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 773): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 774): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 775): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 775): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 776): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 777): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 778): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 779): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 780): {'order_requirements': 1000000, 'container_shortage': 764024, 'operation_number': 371992}
#
# Evaluation result:
# env summary (episode 780): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 781): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 782): {'order_requirements': 1000000, 'container_shortage': 638385, 'operation_number': 624152}
#
# Collecting result:
# env summary (episode 783): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 784): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 785): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 785): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 786): {'order_requirements': 1000000, 'container_shortage': 769655, 'operation_number': 362910}
#
# Collecting result:
# env summary (episode 787): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 788): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 789): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 790): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 790): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 791): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 792): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 793): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 794): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 795): {'order_requirements': 1000000, 'container_shortage': 616130, 'operation_number': 671314}
#
# Evaluation result:
# env summary (episode 795): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
#
# Collecting result:
# env summary (episode 796): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 797): {'order_requirements': 1000000, 'container_shortage': 766174, 'operation_number': 367666}
#
# Collecting result:
# env summary (episode 798): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 799): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Collecting result:
# env summary (episode 800): {'order_requirements': 1000000, 'container_shortage': 764658, 'operation_number': 370712}
#
# Evaluation result:
# env summary (episode 800): {'order_requirements': 1000000, 'container_shortage': 766287, 'operation_number': 361987}
