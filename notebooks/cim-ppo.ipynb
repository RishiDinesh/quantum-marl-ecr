# %%
# Import necessary packages
from typing import Any, Dict, List, Tuple, Union

import numpy as np
import torch
from torch.optim import Adam, RMSprop

from maro.rl.model import DiscreteACBasedNet, FullyConnected, VNet
from maro.rl.policy import DiscretePolicyGradient
from maro.rl.rl_component.rl_component_bundle import RLComponentBundle
from maro.rl.rollout import AbsEnvSampler, CacheElement, ExpElement
from maro.rl.training import TrainingManager
from maro.rl.training.algorithms import PPOParams, PPOTrainer
from maro.simulator import Env
from maro.simulator.scenarios.cim.common import Action, ActionType, DecisionEvent

# %%
# env and shaping config
reward_shaping_conf = {
    "time_window": 99,
    "fulfillment_factor": 1.0,
    "shortage_factor": 1.0,
    "time_decay": 0.97,
}
state_shaping_conf = {
    "look_back": 7,
    "max_ports_downstream": 2,
}
port_attributes = ["empty", "full", "on_shipper", "on_consignee", "booking", "shortage", "fulfillment"]
vessel_attributes = ["empty", "full", "remaining_space"]
action_shaping_conf = {
    "action_space": [(i - 10) / 10 for i in range(21)],
    "finite_vessel_space": True,
    "has_early_discharge": True,
}
state_dim = (
    (state_shaping_conf["look_back"] + 1) * (state_shaping_conf["max_ports_downstream"] + 1) * len(port_attributes)
    + len(vessel_attributes)
)
action_num = len(action_shaping_conf["action_space"])

# %%
class CIMEnvSampler(AbsEnvSampler):
    def _get_global_and_agent_state_impl(self, event: DecisionEvent, tick: int = None,) -> Tuple[Union[None, np.ndarray, List[object]], Dict[Any, Union[np.ndarray, List[object]]]]:
        tick = self._env.tick
        vessel_snapshots, port_snapshots = self._env.snapshot_list["vessels"], self._env.snapshot_list["ports"]
        port_idx, vessel_idx = event.port_idx, event.vessel_idx
        ticks = [max(0, tick - rt) for rt in range(state_shaping_conf["look_back"] - 1)]
        future_port_list = vessel_snapshots[tick: vessel_idx: 'future_stop_list'].astype('int')
        state = np.concatenate([
            port_snapshots[ticks: [port_idx] + list(future_port_list): port_attributes],
            vessel_snapshots[tick: vessel_idx: vessel_attributes]
        ])
        return state, {port_idx: state}

    def _translate_to_env_action(
        self, action_dict: Dict[Any, Union[np.ndarray, List[object]]], event: DecisionEvent,
    ) -> Dict[Any, object]:
        action_space = action_shaping_conf["action_space"]
        finite_vsl_space = action_shaping_conf["finite_vessel_space"]
        has_early_discharge = action_shaping_conf["has_early_discharge"]

        port_idx, model_action = list(action_dict.items()).pop()

        vsl_idx, action_scope = event.vessel_idx, event.action_scope
        vsl_snapshots = self._env.snapshot_list["vessels"]
        vsl_space = vsl_snapshots[self._env.tick:vsl_idx:vessel_attributes][2] if finite_vsl_space else float("inf")

        percent = abs(action_space[model_action[0]])
        zero_action_idx = len(action_space) / 2  # index corresponding to value zero.
        if model_action < zero_action_idx:
            action_type = ActionType.LOAD
            actual_action = min(round(percent * action_scope.load), vsl_space)
        elif model_action > zero_action_idx:
            action_type = ActionType.DISCHARGE
            early_discharge = vsl_snapshots[self._env.tick:vsl_idx:"early_discharge"][0] if has_early_discharge else 0
            plan_action = percent * (action_scope.discharge + early_discharge) - early_discharge
            actual_action = round(plan_action) if plan_action > 0 else round(percent * action_scope.discharge)
        else:
            actual_action, action_type = 0, None

        return {port_idx: Action(vsl_idx, int(port_idx), actual_action, action_type)}

    def _get_reward(self, env_action_dict: Dict[Any, object], event: DecisionEvent, tick: int) -> Dict[Any, float]:
        start_tick = tick + 1
        ticks = list(range(start_tick, start_tick + reward_shaping_conf["time_window"]))

        # Get the ports that took actions at the given tick
        ports = [int(port) for port in list(env_action_dict.keys())]
        port_snapshots = self._env.snapshot_list["ports"]
        future_fulfillment = port_snapshots[ticks:ports:"fulfillment"].reshape(len(ticks), -1)
        future_shortage = port_snapshots[ticks:ports:"shortage"].reshape(len(ticks), -1)

        decay_list = [reward_shaping_conf["time_decay"] ** i for i in range(reward_shaping_conf["time_window"])]
        rewards = np.float32(
            reward_shaping_conf["fulfillment_factor"] * np.dot(future_fulfillment.T, decay_list)
            - reward_shaping_conf["shortage_factor"] * np.dot(future_shortage.T, decay_list)
        )
        return {agent_id: reward for agent_id, reward in zip(ports, rewards)}

    def _post_step(self, cache_element: CacheElement) -> None:
        self._info["env_metric"] = self._env.metrics

    def _post_eval_step(self, cache_element: CacheElement) -> None:
        self._post_step(cache_element)

    def post_collect(self, info_list: list, ep: int) -> None:
        # print the env metric from each rollout worker
        for info in info_list:
            print(f"env summary (episode {ep}): {info['env_metric']}")

        # print the average env metric
        if len(info_list) > 1:
            metric_keys, num_envs = info_list[0]["env_metric"].keys(), len(info_list)
            avg_metric = {key: sum(info["env_metric"][key] for info in info_list) / num_envs for key in metric_keys}
            print(f"average env summary (episode {ep}): {avg_metric}")

    def post_evaluate(self, info_list: list, ep: int) -> None:
        self.post_collect(info_list, ep)

# %%
import torch

from maro.rl.policy import DiscretePolicyGradient
from maro.rl.training.algorithms import PPOParams, PPOTrainer

actor_net_conf = {
    "hidden_dims": [256, 128, 64],
    "activation": torch.nn.Tanh,
    "softmax": True,
    "batch_norm": False,
    "head": True,
}
critic_net_conf = {
    "hidden_dims": [256, 128, 64],
    "output_dim": 1,
    "activation": torch.nn.LeakyReLU,
    "softmax": False,
    "batch_norm": True,
    "head": True,
}

actor_learning_rate = 0.001
critic_learning_rate = 0.001

class MyActorNet(DiscreteACBasedNet):
    def __init__(self, state_dim: int, action_num: int) -> None:
        super(MyActorNet, self).__init__(state_dim=state_dim, action_num=action_num)
        self._actor = FullyConnected(input_dim=state_dim, output_dim=action_num, **actor_net_conf)
        self._optim = Adam(self._actor.parameters(), lr=actor_learning_rate)

    def _get_action_probs_impl(self, states: torch.Tensor) -> torch.Tensor:
        return self._actor(states)


class MyCriticNet(VNet):
    def __init__(self, state_dim: int) -> None:
        super(MyCriticNet, self).__init__(state_dim=state_dim)
        self._critic = FullyConnected(input_dim=state_dim, **critic_net_conf)
        self._optim = RMSprop(self._critic.parameters(), lr=critic_learning_rate)

    def _get_v_values(self, states: torch.Tensor) -> torch.Tensor:
        return self._critic(states).squeeze(-1)
    
def get_ppo_policy(state_dim: int, action_num: int, name: str) -> DiscretePolicyGradient:
    return DiscretePolicyGradient(name=name, policy_net=MyActorNet(state_dim, action_num))


def get_ppo(state_dim: int, name: str) -> PPOTrainer:
    return PPOTrainer(
        name=name,
        reward_discount=0.0,
        params=PPOParams(
            get_v_critic_net_func=lambda: MyCriticNet(state_dim),
            grad_iters=10,
            critic_loss_cls=torch.nn.SmoothL1Loss,
            lam=0.0,
            clip_ratio=0.1,
        ),
    )

# %%
learn_env = Env(scenario="cim", topology="toy.4p_ssdd_l0.0", durations=500,options={"enable-dump-snapshot": "./ppo_learn"})
test_env = Env(scenario="cim", topology="toy.4p_ssdd_l0.1", durations=500,options={"enable-dump-snapshot": "./ppo_test"})

num_agents = len(learn_env.agent_idx_list)
agent2policy = {agent: f"ppo_{agent}.policy" for agent in learn_env.agent_idx_list}
policies = [get_ppo_policy(state_dim, action_num, f"ppo_{i}.policy") for i in range(num_agents)]
trainers = [get_ppo(state_dim, f"ppo_{i}") for i in range(num_agents)]

# %%
rl_component_bundle = RLComponentBundle(
    env_sampler=CIMEnvSampler(
        learn_env=learn_env,
        test_env=test_env,
        policies=policies,
        agent2policy=agent2policy,
        reward_eval_delay=reward_shaping_conf["time_window"],
    ),
    agent2policy=agent2policy,
    policies=policies,
    trainers=trainers,
)

# %%
env_sampler = rl_component_bundle.env_sampler

num_episodes = 800
eval_schedule = [5*i for i in range(1,161)]
eval_point_index = 0

training_manager = TrainingManager(rl_component_bundle=rl_component_bundle)

# main loop
for ep in range(1, num_episodes + 1):
    result = env_sampler.sample()
    experiences: List[List[ExpElement]] = result["experiences"]
    info_list: List[dict] = result["info"]
        
    print("Collecting result:")
    env_sampler.post_collect(info_list, ep)
    print()

    training_manager.record_experiences(experiences)
    training_manager.train_step()

    if ep == eval_schedule[eval_point_index]:
        eval_point_index += 1
        result = env_sampler.eval()
        
        print("Evaluation result:")
        env_sampler.post_evaluate(result["info"], ep)
        print()

training_manager.exit()
# Out:
# Collecting result:
# env summary (episode 1): {'order_requirements': 1000000, 'container_shortage': 740667, 'operation_number': 1749480}
#
# Collecting result:
# env summary (episode 2): {'order_requirements': 1000000, 'container_shortage': 653828, 'operation_number': 1980837}
#
# Collecting result:
# env summary (episode 3): {'order_requirements': 1000000, 'container_shortage': 616729, 'operation_number': 1815131}
#
# Collecting result:
# env summary (episode 4): {'order_requirements': 1000000, 'container_shortage': 533155, 'operation_number': 1672061}
#
# Collecting result:
# env summary (episode 5): {'order_requirements': 1000000, 'container_shortage': 524979, 'operation_number': 1829173}
#
# Evaluation result:
# env summary (episode 5): {'order_requirements': 1000000, 'container_shortage': 940801, 'operation_number': 33464}
#
# Collecting result:
# env summary (episode 6): {'order_requirements': 1000000, 'container_shortage': 576621, 'operation_number': 1765521}
#
# Collecting result:
# env summary (episode 7): {'order_requirements': 1000000, 'container_shortage': 434479, 'operation_number': 1870420}
#
# Collecting result:
# env summary (episode 8): {'order_requirements': 1000000, 'container_shortage': 466075, 'operation_number': 1720443}
#
# Collecting result:
# env summary (episode 9): {'order_requirements': 1000000, 'container_shortage': 480499, 'operation_number': 1999415}
#
# Collecting result:
# env summary (episode 10): {'order_requirements': 1000000, 'container_shortage': 521155, 'operation_number': 1767009}
#
# Evaluation result:
# env summary (episode 10): {'order_requirements': 1000000, 'container_shortage': 896659, 'operation_number': 113251}
#
# Collecting result:
# env summary (episode 11): {'order_requirements': 1000000, 'container_shortage': 546479, 'operation_number': 1476402}
#
# Collecting result:
# env summary (episode 12): {'order_requirements': 1000000, 'container_shortage': 473597, 'operation_number': 1918498}
#
# Collecting result:
# env summary (episode 13): {'order_requirements': 1000000, 'container_shortage': 331871, 'operation_number': 1844452}
#
# Collecting result:
# env summary (episode 14): {'order_requirements': 1000000, 'container_shortage': 420961, 'operation_number': 1844069}
#
# Collecting result:
# env summary (episode 15): {'order_requirements': 1000000, 'container_shortage': 373085, 'operation_number': 1870117}
#
# Evaluation result:
# env summary (episode 15): {'order_requirements': 1000000, 'container_shortage': 892493, 'operation_number': 126911}
#
# Collecting result:
# env summary (episode 16): {'order_requirements': 1000000, 'container_shortage': 409139, 'operation_number': 1773467}
#
# Collecting result:
# env summary (episode 17): {'order_requirements': 1000000, 'container_shortage': 337937, 'operation_number': 1824327}
#
# Collecting result:
# env summary (episode 18): {'order_requirements': 1000000, 'container_shortage': 280718, 'operation_number': 1893713}
#
# Collecting result:
# env summary (episode 19): {'order_requirements': 1000000, 'container_shortage': 349678, 'operation_number': 1859659}
#
# Collecting result:
# env summary (episode 20): {'order_requirements': 1000000, 'container_shortage': 299947, 'operation_number': 1893108}
#
# Evaluation result:
# env summary (episode 20): {'order_requirements': 1000000, 'container_shortage': 829640, 'operation_number': 287376}
#
# Collecting result:
# env summary (episode 21): {'order_requirements': 1000000, 'container_shortage': 354314, 'operation_number': 1771577}
#
# Collecting result:
# env summary (episode 22): {'order_requirements': 1000000, 'container_shortage': 258623, 'operation_number': 1848427}
#
# Collecting result:
# env summary (episode 23): {'order_requirements': 1000000, 'container_shortage': 343132, 'operation_number': 1718316}
#
# Collecting result:
# env summary (episode 24): {'order_requirements': 1000000, 'container_shortage': 330116, 'operation_number': 1724484}
#
# Collecting result:
# env summary (episode 25): {'order_requirements': 1000000, 'container_shortage': 292615, 'operation_number': 1802204}
#
# Evaluation result:
# env summary (episode 25): {'order_requirements': 1000000, 'container_shortage': 811112, 'operation_number': 322921}
#
# Collecting result:
# env summary (episode 26): {'order_requirements': 1000000, 'container_shortage': 328768, 'operation_number': 1882289}
#
# Collecting result:
# env summary (episode 27): {'order_requirements': 1000000, 'container_shortage': 220152, 'operation_number': 1866182}
#
# Collecting result:
# env summary (episode 28): {'order_requirements': 1000000, 'container_shortage': 286048, 'operation_number': 1857553}
#
# Collecting result:
# env summary (episode 29): {'order_requirements': 1000000, 'container_shortage': 277480, 'operation_number': 1800716}
#
# Collecting result:
# env summary (episode 30): {'order_requirements': 1000000, 'container_shortage': 222479, 'operation_number': 1837664}
#
# Evaluation result:
# env summary (episode 30): {'order_requirements': 1000000, 'container_shortage': 840501, 'operation_number': 271646}
#
# Collecting result:
# env summary (episode 31): {'order_requirements': 1000000, 'container_shortage': 217677, 'operation_number': 1784130}
#
# Collecting result:
# env summary (episode 32): {'order_requirements': 1000000, 'container_shortage': 283247, 'operation_number': 1676673}
#
# Collecting result:
# env summary (episode 33): {'order_requirements': 1000000, 'container_shortage': 245740, 'operation_number': 1766703}
#
# Collecting result:
# env summary (episode 34): {'order_requirements': 1000000, 'container_shortage': 229595, 'operation_number': 1758620}
#
# Collecting result:
# env summary (episode 35): {'order_requirements': 1000000, 'container_shortage': 273100, 'operation_number': 1648019}
#
# Evaluation result:
# env summary (episode 35): {'order_requirements': 1000000, 'container_shortage': 567771, 'operation_number': 778183}
#
# Collecting result:
# env summary (episode 36): {'order_requirements': 1000000, 'container_shortage': 216096, 'operation_number': 1906869}
#
# Collecting result:
# env summary (episode 37): {'order_requirements': 1000000, 'container_shortage': 254893, 'operation_number': 1803299}
#
# Collecting result:
# env summary (episode 38): {'order_requirements': 1000000, 'container_shortage': 273560, 'operation_number': 1664645}
#
# Collecting result:
# env summary (episode 39): {'order_requirements': 1000000, 'container_shortage': 252681, 'operation_number': 1801562}
#
# Collecting result:
# env summary (episode 40): {'order_requirements': 1000000, 'container_shortage': 211320, 'operation_number': 1799279}
#
# Evaluation result:
# env summary (episode 40): {'order_requirements': 1000000, 'container_shortage': 407368, 'operation_number': 960975}
#
# Collecting result:
# env summary (episode 41): {'order_requirements': 1000000, 'container_shortage': 221803, 'operation_number': 1842837}
#
# Collecting result:
# env summary (episode 42): {'order_requirements': 1000000, 'container_shortage': 244073, 'operation_number': 1754265}
#
# Collecting result:
# env summary (episode 43): {'order_requirements': 1000000, 'container_shortage': 317614, 'operation_number': 1695793}
#
# Collecting result:
# env summary (episode 44): {'order_requirements': 1000000, 'container_shortage': 213917, 'operation_number': 1705581}
#
# Collecting result:
# env summary (episode 45): {'order_requirements': 1000000, 'container_shortage': 270226, 'operation_number': 1641938}
#
# Evaluation result:
# env summary (episode 45): {'order_requirements': 1000000, 'container_shortage': 509631, 'operation_number': 900779}
#
# Collecting result:
# env summary (episode 46): {'order_requirements': 1000000, 'container_shortage': 250774, 'operation_number': 1709806}
#
# Collecting result:
# env summary (episode 47): {'order_requirements': 1000000, 'container_shortage': 243793, 'operation_number': 1739386}
#
# Collecting result:
# env summary (episode 48): {'order_requirements': 1000000, 'container_shortage': 415782, 'operation_number': 1369742}
#
# Collecting result:
# env summary (episode 49): {'order_requirements': 1000000, 'container_shortage': 327792, 'operation_number': 1685968}
#
# Collecting result:
# env summary (episode 50): {'order_requirements': 1000000, 'container_shortage': 260793, 'operation_number': 1766191}
#
# Evaluation result:
# env summary (episode 50): {'order_requirements': 1000000, 'container_shortage': 458357, 'operation_number': 984227}
#
# Collecting result:
# env summary (episode 51): {'order_requirements': 1000000, 'container_shortage': 210487, 'operation_number': 1796663}
#
# Collecting result:
# env summary (episode 52): {'order_requirements': 1000000, 'container_shortage': 235542, 'operation_number': 1647204}
#
# Collecting result:
# env summary (episode 53): {'order_requirements': 1000000, 'container_shortage': 289280, 'operation_number': 1686264}
#
# Collecting result:
# env summary (episode 54): {'order_requirements': 1000000, 'container_shortage': 234774, 'operation_number': 1658849}
#
# Collecting result:
# env summary (episode 55): {'order_requirements': 1000000, 'container_shortage': 207096, 'operation_number': 1757673}
#
# Evaluation result:
# env summary (episode 55): {'order_requirements': 1000000, 'container_shortage': 404031, 'operation_number': 1085363}
#
# Collecting result:
# env summary (episode 56): {'order_requirements': 1000000, 'container_shortage': 226802, 'operation_number': 1786024}
#
# Collecting result:
# env summary (episode 57): {'order_requirements': 1000000, 'container_shortage': 246725, 'operation_number': 1744886}
#
# Collecting result:
# env summary (episode 58): {'order_requirements': 1000000, 'container_shortage': 193619, 'operation_number': 1788372}
#
# Collecting result:
# env summary (episode 59): {'order_requirements': 1000000, 'container_shortage': 222792, 'operation_number': 1765759}
#
# Collecting result:
# env summary (episode 60): {'order_requirements': 1000000, 'container_shortage': 214472, 'operation_number': 1876520}
#
# Evaluation result:
# env summary (episode 60): {'order_requirements': 1000000, 'container_shortage': 393517, 'operation_number': 1105484}
#
# Collecting result:
# env summary (episode 61): {'order_requirements': 1000000, 'container_shortage': 215006, 'operation_number': 1688710}
#
# Collecting result:
# env summary (episode 62): {'order_requirements': 1000000, 'container_shortage': 225208, 'operation_number': 1807236}
#
# Collecting result:
# env summary (episode 63): {'order_requirements': 1000000, 'container_shortage': 219019, 'operation_number': 1843284}
#
# Collecting result:
# env summary (episode 64): {'order_requirements': 1000000, 'container_shortage': 237216, 'operation_number': 1723887}
#
# Collecting result:
# env summary (episode 65): {'order_requirements': 1000000, 'container_shortage': 223218, 'operation_number': 1701699}
#
# Evaluation result:
# env summary (episode 65): {'order_requirements': 1000000, 'container_shortage': 390936, 'operation_number': 1112001}
#
# Collecting result:
# env summary (episode 66): {'order_requirements': 1000000, 'container_shortage': 230508, 'operation_number': 1694039}
#
# Collecting result:
# env summary (episode 67): {'order_requirements': 1000000, 'container_shortage': 208083, 'operation_number': 1768000}
#
# Collecting result:
# env summary (episode 68): {'order_requirements': 1000000, 'container_shortage': 241553, 'operation_number': 1634262}
#
# Collecting result:
# env summary (episode 69): {'order_requirements': 1000000, 'container_shortage': 200699, 'operation_number': 1733350}
#
# Collecting result:
# env summary (episode 70): {'order_requirements': 1000000, 'container_shortage': 225624, 'operation_number': 1807979}
#
# Evaluation result:
# env summary (episode 70): {'order_requirements': 1000000, 'container_shortage': 396484, 'operation_number': 1102860}
#
# Collecting result:
# env summary (episode 71): {'order_requirements': 1000000, 'container_shortage': 262980, 'operation_number': 1638014}
#
# Collecting result:
# env summary (episode 72): {'order_requirements': 1000000, 'container_shortage': 247199, 'operation_number': 1670054}
#
# Collecting result:
# env summary (episode 73): {'order_requirements': 1000000, 'container_shortage': 212380, 'operation_number': 1743838}
#
# Collecting result:
# env summary (episode 74): {'order_requirements': 1000000, 'container_shortage': 177203, 'operation_number': 1785560}
#
# Collecting result:
# env summary (episode 75): {'order_requirements': 1000000, 'container_shortage': 200495, 'operation_number': 1726446}
#
# Evaluation result:
# env summary (episode 75): {'order_requirements': 1000000, 'container_shortage': 325032, 'operation_number': 1122821}
#
# Collecting result:
# env summary (episode 76): {'order_requirements': 1000000, 'container_shortage': 191163, 'operation_number': 1798882}
#
# Collecting result:
# env summary (episode 77): {'order_requirements': 1000000, 'container_shortage': 195030, 'operation_number': 1734995}
#
# Collecting result:
# env summary (episode 78): {'order_requirements': 1000000, 'container_shortage': 191392, 'operation_number': 1750239}
#
# Collecting result:
# env summary (episode 79): {'order_requirements': 1000000, 'container_shortage': 252804, 'operation_number': 1626986}
#
# Collecting result:
# env summary (episode 80): {'order_requirements': 1000000, 'container_shortage': 153224, 'operation_number': 1802707}
#
# Evaluation result:
# env summary (episode 80): {'order_requirements': 1000000, 'container_shortage': 240525, 'operation_number': 1139192}
#
# Collecting result:
# env summary (episode 81): {'order_requirements': 1000000, 'container_shortage': 158574, 'operation_number': 1747506}
#
# Collecting result:
# env summary (episode 82): {'order_requirements': 1000000, 'container_shortage': 167034, 'operation_number': 1871565}
#
# Collecting result:
# env summary (episode 83): {'order_requirements': 1000000, 'container_shortage': 186679, 'operation_number': 1736800}
#
# Collecting result:
# env summary (episode 84): {'order_requirements': 1000000, 'container_shortage': 218801, 'operation_number': 1820936}
#
# Collecting result:
# env summary (episode 85): {'order_requirements': 1000000, 'container_shortage': 196510, 'operation_number': 1737216}
#
# Evaluation result:
# env summary (episode 85): {'order_requirements': 1000000, 'container_shortage': 228147, 'operation_number': 1133501}
#
# Collecting result:
# env summary (episode 86): {'order_requirements': 1000000, 'container_shortage': 183540, 'operation_number': 1679132}
#
# Collecting result:
# env summary (episode 87): {'order_requirements': 1000000, 'container_shortage': 213079, 'operation_number': 1731236}
#
# Collecting result:
# env summary (episode 88): {'order_requirements': 1000000, 'container_shortage': 181518, 'operation_number': 1786547}
#
# Collecting result:
# env summary (episode 89): {'order_requirements': 1000000, 'container_shortage': 173257, 'operation_number': 1864261}
#
# Collecting result:
# env summary (episode 90): {'order_requirements': 1000000, 'container_shortage': 150269, 'operation_number': 1852491}
#
# Evaluation result:
# env summary (episode 90): {'order_requirements': 1000000, 'container_shortage': 225238, 'operation_number': 1132252}
#
# Collecting result:
# env summary (episode 91): {'order_requirements': 1000000, 'container_shortage': 102209, 'operation_number': 1947324}
#
# Collecting result:
# env summary (episode 92): {'order_requirements': 1000000, 'container_shortage': 160830, 'operation_number': 1776323}
#
# Collecting result:
# env summary (episode 93): {'order_requirements': 1000000, 'container_shortage': 166793, 'operation_number': 1779206}
#
# Collecting result:
# env summary (episode 94): {'order_requirements': 1000000, 'container_shortage': 160948, 'operation_number': 1828936}
#
# Collecting result:
# env summary (episode 95): {'order_requirements': 1000000, 'container_shortage': 170839, 'operation_number': 1788600}
#
# Evaluation result:
# env summary (episode 95): {'order_requirements': 1000000, 'container_shortage': 306348, 'operation_number': 1145283}
#
# Collecting result:
# env summary (episode 96): {'order_requirements': 1000000, 'container_shortage': 199034, 'operation_number': 1743036}
#
# Collecting result:
# env summary (episode 97): {'order_requirements': 1000000, 'container_shortage': 121480, 'operation_number': 1923296}
#
# Collecting result:
# env summary (episode 98): {'order_requirements': 1000000, 'container_shortage': 179807, 'operation_number': 1787639}
#
# Collecting result:
# env summary (episode 99): {'order_requirements': 1000000, 'container_shortage': 151383, 'operation_number': 1879805}
#
# Collecting result:
# env summary (episode 100): {'order_requirements': 1000000, 'container_shortage': 158670, 'operation_number': 1805102}
#
# Evaluation result:
# env summary (episode 100): {'order_requirements': 1000000, 'container_shortage': 552556, 'operation_number': 746407}
#
# Collecting result:
# env summary (episode 101): {'order_requirements': 1000000, 'container_shortage': 118494, 'operation_number': 1830813}
#
# Collecting result:
# env summary (episode 102): {'order_requirements': 1000000, 'container_shortage': 154576, 'operation_number': 1824631}
#
# Collecting result:
# env summary (episode 103): {'order_requirements': 1000000, 'container_shortage': 159177, 'operation_number': 1856514}
#
# Collecting result:
# env summary (episode 104): {'order_requirements': 1000000, 'container_shortage': 194186, 'operation_number': 1798386}
#
# Collecting result:
# env summary (episode 105): {'order_requirements': 1000000, 'container_shortage': 148539, 'operation_number': 1749021}
#
# Evaluation result:
# env summary (episode 105): {'order_requirements': 1000000, 'container_shortage': 650228, 'operation_number': 598870}
#
# Collecting result:
# env summary (episode 106): {'order_requirements': 1000000, 'container_shortage': 120476, 'operation_number': 1941697}
#
# Collecting result:
# env summary (episode 107): {'order_requirements': 1000000, 'container_shortage': 123269, 'operation_number': 1814258}
#
# Collecting result:
# env summary (episode 108): {'order_requirements': 1000000, 'container_shortage': 168277, 'operation_number': 1784196}
#
# Collecting result:
# env summary (episode 109): {'order_requirements': 1000000, 'container_shortage': 181877, 'operation_number': 1689260}
#
# Collecting result:
# env summary (episode 110): {'order_requirements': 1000000, 'container_shortage': 77258, 'operation_number': 1931810}
#
# Evaluation result:
# env summary (episode 110): {'order_requirements': 1000000, 'container_shortage': 552556, 'operation_number': 746407}
#
# Collecting result:
# env summary (episode 111): {'order_requirements': 1000000, 'container_shortage': 201362, 'operation_number': 1705855}
#
# Collecting result:
# env summary (episode 112): {'order_requirements': 1000000, 'container_shortage': 108859, 'operation_number': 1836243}
#
# Collecting result:
# env summary (episode 113): {'order_requirements': 1000000, 'container_shortage': 115452, 'operation_number': 1859858}
#
# Collecting result:
# env summary (episode 114): {'order_requirements': 1000000, 'container_shortage': 199441, 'operation_number': 1729935}
#
# Collecting result:
# env summary (episode 115): {'order_requirements': 1000000, 'container_shortage': 98682, 'operation_number': 1879393}
#
# Evaluation result:
# env summary (episode 115): {'order_requirements': 1000000, 'container_shortage': 492340, 'operation_number': 836729}
#
# Collecting result:
# env summary (episode 116): {'order_requirements': 1000000, 'container_shortage': 166590, 'operation_number': 1779866}
#
# Collecting result:
# env summary (episode 117): {'order_requirements': 1000000, 'container_shortage': 125174, 'operation_number': 1815153}
#
# Collecting result:
# env summary (episode 118): {'order_requirements': 1000000, 'container_shortage': 158021, 'operation_number': 1821728}
#
# Collecting result:
# env summary (episode 119): {'order_requirements': 1000000, 'container_shortage': 92000, 'operation_number': 1899080}
#
# Collecting result:
# env summary (episode 120): {'order_requirements': 1000000, 'container_shortage': 105372, 'operation_number': 1918112}
#
# Evaluation result:
# env summary (episode 120): {'order_requirements': 1000000, 'container_shortage': 586776, 'operation_number': 691884}
#
# Collecting result:
# env summary (episode 121): {'order_requirements': 1000000, 'container_shortage': 146627, 'operation_number': 1823117}
#
# Collecting result:
# env summary (episode 122): {'order_requirements': 1000000, 'container_shortage': 93369, 'operation_number': 1859056}
#
# Collecting result:
# env summary (episode 123): {'order_requirements': 1000000, 'container_shortage': 139666, 'operation_number': 1796488}
#
# Collecting result:
# env summary (episode 124): {'order_requirements': 1000000, 'container_shortage': 81009, 'operation_number': 1902037}
#
# Collecting result:
# env summary (episode 125): {'order_requirements': 1000000, 'container_shortage': 120035, 'operation_number': 1800879}
#
# Evaluation result:
# env summary (episode 125): {'order_requirements': 1000000, 'container_shortage': 669626, 'operation_number': 561484}
#
# Collecting result:
# env summary (episode 126): {'order_requirements': 1000000, 'container_shortage': 79977, 'operation_number': 1911472}
#
# Collecting result:
# env summary (episode 127): {'order_requirements': 1000000, 'container_shortage': 122224, 'operation_number': 1816373}
#
# Collecting result:
# env summary (episode 128): {'order_requirements': 1000000, 'container_shortage': 126375, 'operation_number': 1813877}
#
# Collecting result:
# env summary (episode 129): {'order_requirements': 1000000, 'container_shortage': 119530, 'operation_number': 1834064}
#
# Collecting result:
# env summary (episode 130): {'order_requirements': 1000000, 'container_shortage': 88955, 'operation_number': 1868984}
#
# Evaluation result:
# env summary (episode 130): {'order_requirements': 1000000, 'container_shortage': 669626, 'operation_number': 561484}
#
# Collecting result:
# env summary (episode 131): {'order_requirements': 1000000, 'container_shortage': 99918, 'operation_number': 1843934}
#
# Collecting result:
# env summary (episode 132): {'order_requirements': 1000000, 'container_shortage': 91767, 'operation_number': 1848254}
#
# Collecting result:
# env summary (episode 133): {'order_requirements': 1000000, 'container_shortage': 94163, 'operation_number': 1866904}
#
# Collecting result:
# env summary (episode 134): {'order_requirements': 1000000, 'container_shortage': 128090, 'operation_number': 1817017}
#
# Collecting result:
# env summary (episode 135): {'order_requirements': 1000000, 'container_shortage': 112621, 'operation_number': 1905929}
#
# Evaluation result:
# env summary (episode 135): {'order_requirements': 1000000, 'container_shortage': 216184, 'operation_number': 1128370}
#
# Collecting result:
# env summary (episode 136): {'order_requirements': 1000000, 'container_shortage': 98061, 'operation_number': 1911749}
#
# Collecting result:
# env summary (episode 137): {'order_requirements': 1000000, 'container_shortage': 135404, 'operation_number': 1837588}
#
# Collecting result:
# env summary (episode 138): {'order_requirements': 1000000, 'container_shortage': 98392, 'operation_number': 1863854}
#
# Collecting result:
# env summary (episode 139): {'order_requirements': 1000000, 'container_shortage': 106853, 'operation_number': 1835855}
#
# Collecting result:
# env summary (episode 140): {'order_requirements': 1000000, 'container_shortage': 108165, 'operation_number': 1872739}
#
# Evaluation result:
# env summary (episode 140): {'order_requirements': 1000000, 'container_shortage': 216184, 'operation_number': 1128370}
#
# Collecting result:
# env summary (episode 141): {'order_requirements': 1000000, 'container_shortage': 85206, 'operation_number': 1921836}
#
# Collecting result:
# env summary (episode 142): {'order_requirements': 1000000, 'container_shortage': 64346, 'operation_number': 1916310}
#
# Collecting result:
# env summary (episode 143): {'order_requirements': 1000000, 'container_shortage': 85115, 'operation_number': 1882129}
#
# Collecting result:
# env summary (episode 144): {'order_requirements': 1000000, 'container_shortage': 103613, 'operation_number': 1872013}
#
# Collecting result:
# env summary (episode 145): {'order_requirements': 1000000, 'container_shortage': 117949, 'operation_number': 1813676}
#
# Evaluation result:
# env summary (episode 145): {'order_requirements': 1000000, 'container_shortage': 216184, 'operation_number': 1128370}
#
# Collecting result:
# env summary (episode 146): {'order_requirements': 1000000, 'container_shortage': 99318, 'operation_number': 1924363}
#
# Collecting result:
# env summary (episode 147): {'order_requirements': 1000000, 'container_shortage': 81841, 'operation_number': 1958812}
#
# Collecting result:
# env summary (episode 148): {'order_requirements': 1000000, 'container_shortage': 76346, 'operation_number': 1889048}
#
# Collecting result:
# env summary (episode 149): {'order_requirements': 1000000, 'container_shortage': 107673, 'operation_number': 1859582}
#
# Collecting result:
# env summary (episode 150): {'order_requirements': 1000000, 'container_shortage': 113657, 'operation_number': 1801128}
#
# Evaluation result:
# env summary (episode 150): {'order_requirements': 1000000, 'container_shortage': 216184, 'operation_number': 1128370}
#
# Collecting result:
# env summary (episode 151): {'order_requirements': 1000000, 'container_shortage': 79747, 'operation_number': 1896271}
#
# Collecting result:
# env summary (episode 152): {'order_requirements': 1000000, 'container_shortage': 89013, 'operation_number': 1877733}
#
# Collecting result:
# env summary (episode 153): {'order_requirements': 1000000, 'container_shortage': 51118, 'operation_number': 2001400}
#
# Collecting result:
# env summary (episode 154): {'order_requirements': 1000000, 'container_shortage': 75934, 'operation_number': 1861102}
#
# Collecting result:
# env summary (episode 155): {'order_requirements': 1000000, 'container_shortage': 52346, 'operation_number': 1916702}
#
# Evaluation result:
# env summary (episode 155): {'order_requirements': 1000000, 'container_shortage': 216184, 'operation_number': 1128370}
#
# Collecting result:
# env summary (episode 156): {'order_requirements': 1000000, 'container_shortage': 74764, 'operation_number': 1866726}
#
# Collecting result:
# env summary (episode 157): {'order_requirements': 1000000, 'container_shortage': 79157, 'operation_number': 1892369}
#
# Collecting result:
# env summary (episode 158): {'order_requirements': 1000000, 'container_shortage': 78650, 'operation_number': 1927598}
#
# Collecting result:
# env summary (episode 159): {'order_requirements': 1000000, 'container_shortage': 65376, 'operation_number': 1894955}
#
# Collecting result:
# env summary (episode 160): {'order_requirements': 1000000, 'container_shortage': 91113, 'operation_number': 1837624}
#
# Evaluation result:
# env summary (episode 160): {'order_requirements': 1000000, 'container_shortage': 216184, 'operation_number': 1128370}
#
# Collecting result:
# env summary (episode 161): {'order_requirements': 1000000, 'container_shortage': 65530, 'operation_number': 1933224}
#
# Collecting result:
# env summary (episode 162): {'order_requirements': 1000000, 'container_shortage': 34069, 'operation_number': 1942444}
#
# Collecting result:
# env summary (episode 163): {'order_requirements': 1000000, 'container_shortage': 99282, 'operation_number': 1853903}
#
# Collecting result:
# env summary (episode 164): {'order_requirements': 1000000, 'container_shortage': 54448, 'operation_number': 1958021}
#
# Collecting result:
# env summary (episode 165): {'order_requirements': 1000000, 'container_shortage': 48591, 'operation_number': 1923045}
#
# Evaluation result:
# env summary (episode 165): {'order_requirements': 1000000, 'container_shortage': 216184, 'operation_number': 1128370}
#
# Collecting result:
# env summary (episode 166): {'order_requirements': 1000000, 'container_shortage': 54741, 'operation_number': 1936338}
#
# Collecting result:
# env summary (episode 167): {'order_requirements': 1000000, 'container_shortage': 70557, 'operation_number': 1899498}
#
# Collecting result:
# env summary (episode 168): {'order_requirements': 1000000, 'container_shortage': 56958, 'operation_number': 1916341}
#
# Collecting result:
# env summary (episode 169): {'order_requirements': 1000000, 'container_shortage': 93790, 'operation_number': 1881497}
#
# Collecting result:
# env summary (episode 170): {'order_requirements': 1000000, 'container_shortage': 66449, 'operation_number': 1934678}
#
# Evaluation result:
# env summary (episode 170): {'order_requirements': 1000000, 'container_shortage': 216184, 'operation_number': 1128370}
#
# Collecting result:
# env summary (episode 171): {'order_requirements': 1000000, 'container_shortage': 104500, 'operation_number': 1868807}
#
# Collecting result:
# env summary (episode 172): {'order_requirements': 1000000, 'container_shortage': 57514, 'operation_number': 1917620}
#
# Collecting result:
# env summary (episode 173): {'order_requirements': 1000000, 'container_shortage': 99124, 'operation_number': 1901362}
#
# Collecting result:
# env summary (episode 174): {'order_requirements': 1000000, 'container_shortage': 27297, 'operation_number': 1965711}
#
# Collecting result:
# env summary (episode 175): {'order_requirements': 1000000, 'container_shortage': 68433, 'operation_number': 1914292}
#
# Evaluation result:
# env summary (episode 175): {'order_requirements': 1000000, 'container_shortage': 120894, 'operation_number': 1272904}
#
# Collecting result:
# env summary (episode 176): {'order_requirements': 1000000, 'container_shortage': 54486, 'operation_number': 1925628}
#
# Collecting result:
# env summary (episode 177): {'order_requirements': 1000000, 'container_shortage': 39549, 'operation_number': 1963956}
#
# Collecting result:
# env summary (episode 178): {'order_requirements': 1000000, 'container_shortage': 53170, 'operation_number': 1923215}
#
# Collecting result:
# env summary (episode 179): {'order_requirements': 1000000, 'container_shortage': 83511, 'operation_number': 1872632}
#
# Collecting result:
# env summary (episode 180): {'order_requirements': 1000000, 'container_shortage': 91298, 'operation_number': 1833151}
#
# Evaluation result:
# env summary (episode 180): {'order_requirements': 1000000, 'container_shortage': 120894, 'operation_number': 1391799}
#
# Collecting result:
# env summary (episode 181): {'order_requirements': 1000000, 'container_shortage': 34578, 'operation_number': 1982788}
#
# Collecting result:
# env summary (episode 182): {'order_requirements': 1000000, 'container_shortage': 77277, 'operation_number': 1879960}
#
# Collecting result:
# env summary (episode 183): {'order_requirements': 1000000, 'container_shortage': 79874, 'operation_number': 1874143}
#
# Collecting result:
# env summary (episode 184): {'order_requirements': 1000000, 'container_shortage': 48624, 'operation_number': 1935260}
#
# Collecting result:
# env summary (episode 185): {'order_requirements': 1000000, 'container_shortage': 50750, 'operation_number': 1914710}
#
# Evaluation result:
# env summary (episode 185): {'order_requirements': 1000000, 'container_shortage': 120894, 'operation_number': 1394838}
#
# Collecting result:
# env summary (episode 186): {'order_requirements': 1000000, 'container_shortage': 84280, 'operation_number': 1890329}
#
# Collecting result:
# env summary (episode 187): {'order_requirements': 1000000, 'container_shortage': 44335, 'operation_number': 1982296}
#
# Collecting result:
# env summary (episode 188): {'order_requirements': 1000000, 'container_shortage': 86742, 'operation_number': 1909194}
#
# Collecting result:
# env summary (episode 189): {'order_requirements': 1000000, 'container_shortage': 97869, 'operation_number': 1880758}
#
# Collecting result:
# env summary (episode 190): {'order_requirements': 1000000, 'container_shortage': 49958, 'operation_number': 1938274}
#
# Evaluation result:
# env summary (episode 190): {'order_requirements': 1000000, 'container_shortage': 120894, 'operation_number': 1394838}
#
# Collecting result:
# env summary (episode 191): {'order_requirements': 1000000, 'container_shortage': 101974, 'operation_number': 1827804}
#
# Collecting result:
# env summary (episode 192): {'order_requirements': 1000000, 'container_shortage': 89294, 'operation_number': 1852914}
#
# Collecting result:
# env summary (episode 193): {'order_requirements': 1000000, 'container_shortage': 104864, 'operation_number': 1855391}
#
# Collecting result:
# env summary (episode 194): {'order_requirements': 1000000, 'container_shortage': 152489, 'operation_number': 1705485}
#
# Collecting result:
# env summary (episode 195): {'order_requirements': 1000000, 'container_shortage': 112448, 'operation_number': 1811280}
#
# Evaluation result:
# env summary (episode 195): {'order_requirements': 1000000, 'container_shortage': 120894, 'operation_number': 1394838}
#
# Collecting result:
# env summary (episode 196): {'order_requirements': 1000000, 'container_shortage': 62147, 'operation_number': 1885177}
#
# Collecting result:
# env summary (episode 197): {'order_requirements': 1000000, 'container_shortage': 76507, 'operation_number': 1893040}
#
# Collecting result:
# env summary (episode 198): {'order_requirements': 1000000, 'container_shortage': 77087, 'operation_number': 1930965}
#
# Collecting result:
# env summary (episode 199): {'order_requirements': 1000000, 'container_shortage': 110437, 'operation_number': 1840313}
#
# Collecting result:
# env summary (episode 200): {'order_requirements': 1000000, 'container_shortage': 132237, 'operation_number': 1832414}
#
# Evaluation result:
# env summary (episode 200): {'order_requirements': 1000000, 'container_shortage': 661768, 'operation_number': 574887}
#
# Collecting result:
# env summary (episode 201): {'order_requirements': 1000000, 'container_shortage': 72341, 'operation_number': 1873862}
#
# Collecting result:
# env summary (episode 202): {'order_requirements': 1000000, 'container_shortage': 109323, 'operation_number': 1813417}
#
# Collecting result:
# env summary (episode 203): {'order_requirements': 1000000, 'container_shortage': 103563, 'operation_number': 1832153}
#
# Collecting result:
# env summary (episode 204): {'order_requirements': 1000000, 'container_shortage': 150177, 'operation_number': 1720063}
#
# Collecting result:
# env summary (episode 205): {'order_requirements': 1000000, 'container_shortage': 152708, 'operation_number': 1733616}
#
# Evaluation result:
# env summary (episode 205): {'order_requirements': 1000000, 'container_shortage': 661768, 'operation_number': 574887}
#
# Collecting result:
# env summary (episode 206): {'order_requirements': 1000000, 'container_shortage': 85595, 'operation_number': 1875484}
#
# Collecting result:
# env summary (episode 207): {'order_requirements': 1000000, 'container_shortage': 132942, 'operation_number': 1811005}
#
# Collecting result:
# env summary (episode 208): {'order_requirements': 1000000, 'container_shortage': 123961, 'operation_number': 1773990}
#
# Collecting result:
# env summary (episode 209): {'order_requirements': 1000000, 'container_shortage': 150195, 'operation_number': 1752464}
#
# Collecting result:
# env summary (episode 210): {'order_requirements': 1000000, 'container_shortage': 116235, 'operation_number': 1806807}
#
# Evaluation result:
# env summary (episode 210): {'order_requirements': 1000000, 'container_shortage': 661768, 'operation_number': 574887}
#
# Collecting result:
# env summary (episode 211): {'order_requirements': 1000000, 'container_shortage': 140287, 'operation_number': 1753561}
#
# Collecting result:
# env summary (episode 212): {'order_requirements': 1000000, 'container_shortage': 114700, 'operation_number': 1787360}
#
# Collecting result:
# env summary (episode 213): {'order_requirements': 1000000, 'container_shortage': 65874, 'operation_number': 1858493}
#
# Collecting result:
# env summary (episode 214): {'order_requirements': 1000000, 'container_shortage': 150477, 'operation_number': 1725096}
#
# Collecting result:
# env summary (episode 215): {'order_requirements': 1000000, 'container_shortage': 156062, 'operation_number': 1738510}
#
# Evaluation result:
# env summary (episode 215): {'order_requirements': 1000000, 'container_shortage': 661768, 'operation_number': 574887}
#
# Collecting result:
# env summary (episode 216): {'order_requirements': 1000000, 'container_shortage': 151955, 'operation_number': 1774589}
#
# Collecting result:
# env summary (episode 217): {'order_requirements': 1000000, 'container_shortage': 145639, 'operation_number': 1747167}
#
# Collecting result:
# env summary (episode 218): {'order_requirements': 1000000, 'container_shortage': 98085, 'operation_number': 1884180}
#
# Collecting result:
# env summary (episode 219): {'order_requirements': 1000000, 'container_shortage': 66040, 'operation_number': 1906564}
#
# Collecting result:
# env summary (episode 220): {'order_requirements': 1000000, 'container_shortage': 181858, 'operation_number': 1674362}
#
# Evaluation result:
# env summary (episode 220): {'order_requirements': 1000000, 'container_shortage': 560118, 'operation_number': 752811}
#
# Collecting result:
# env summary (episode 221): {'order_requirements': 1000000, 'container_shortage': 94529, 'operation_number': 1818811}
#
# Collecting result:
# env summary (episode 222): {'order_requirements': 1000000, 'container_shortage': 134253, 'operation_number': 1806111}
#
# Collecting result:
# env summary (episode 223): {'order_requirements': 1000000, 'container_shortage': 62853, 'operation_number': 1895256}
#
# Collecting result:
# env summary (episode 224): {'order_requirements': 1000000, 'container_shortage': 140768, 'operation_number': 1772660}
#
# Collecting result:
# env summary (episode 225): {'order_requirements': 1000000, 'container_shortage': 143323, 'operation_number': 1731613}
#
# Evaluation result:
# env summary (episode 225): {'order_requirements': 1000000, 'container_shortage': 307688, 'operation_number': 1272472}
#
# Collecting result:
# env summary (episode 226): {'order_requirements': 1000000, 'container_shortage': 106965, 'operation_number': 1850302}
#
# Collecting result:
# env summary (episode 227): {'order_requirements': 1000000, 'container_shortage': 155047, 'operation_number': 1690620}
#
# Collecting result:
# env summary (episode 228): {'order_requirements': 1000000, 'container_shortage': 165195, 'operation_number': 1733281}
#
# Collecting result:
# env summary (episode 229): {'order_requirements': 1000000, 'container_shortage': 163015, 'operation_number': 1713517}
#
# Collecting result:
# env summary (episode 230): {'order_requirements': 1000000, 'container_shortage': 138876, 'operation_number': 1761822}
#
# Evaluation result:
# env summary (episode 230): {'order_requirements': 1000000, 'container_shortage': 307688, 'operation_number': 1272472}
#
# Collecting result:
# env summary (episode 231): {'order_requirements': 1000000, 'container_shortage': 126720, 'operation_number': 1757553}
#
# Collecting result:
# env summary (episode 232): {'order_requirements': 1000000, 'container_shortage': 164188, 'operation_number': 1702635}
#
# Collecting result:
# env summary (episode 233): {'order_requirements': 1000000, 'container_shortage': 83085, 'operation_number': 1859957}
#
# Collecting result:
# env summary (episode 234): {'order_requirements': 1000000, 'container_shortage': 113032, 'operation_number': 1828087}
#
# Collecting result:
# env summary (episode 235): {'order_requirements': 1000000, 'container_shortage': 68474, 'operation_number': 1883023}
#
# Evaluation result:
# env summary (episode 235): {'order_requirements': 1000000, 'container_shortage': 307688, 'operation_number': 1272472}
#
# Collecting result:
# env summary (episode 236): {'order_requirements': 1000000, 'container_shortage': 99174, 'operation_number': 1889953}
#
# Collecting result:
# env summary (episode 237): {'order_requirements': 1000000, 'container_shortage': 107003, 'operation_number': 1806773}
#
# Collecting result:
# env summary (episode 238): {'order_requirements': 1000000, 'container_shortage': 168605, 'operation_number': 1810369}
#
# Collecting result:
# env summary (episode 239): {'order_requirements': 1000000, 'container_shortage': 104602, 'operation_number': 1837038}
#
# Collecting result:
# env summary (episode 240): {'order_requirements': 1000000, 'container_shortage': 83819, 'operation_number': 1896620}
#
# Evaluation result:
# env summary (episode 240): {'order_requirements': 1000000, 'container_shortage': 307688, 'operation_number': 1272472}
#
# Collecting result:
# env summary (episode 241): {'order_requirements': 1000000, 'container_shortage': 102823, 'operation_number': 1839207}
#
# Collecting result:
# env summary (episode 242): {'order_requirements': 1000000, 'container_shortage': 152093, 'operation_number': 1747884}
#
# Collecting result:
# env summary (episode 243): {'order_requirements': 1000000, 'container_shortage': 119254, 'operation_number': 1812341}
#
# Collecting result:
# env summary (episode 244): {'order_requirements': 1000000, 'container_shortage': 123585, 'operation_number': 1830517}
#
# Collecting result:
# env summary (episode 245): {'order_requirements': 1000000, 'container_shortage': 154415, 'operation_number': 1774294}
#
# Evaluation result:
# env summary (episode 245): {'order_requirements': 1000000, 'container_shortage': 578946, 'operation_number': 719459}
#
# Collecting result:
# env summary (episode 246): {'order_requirements': 1000000, 'container_shortage': 45521, 'operation_number': 1915666}
#
# Collecting result:
# env summary (episode 247): {'order_requirements': 1000000, 'container_shortage': 136063, 'operation_number': 1740693}
#
# Collecting result:
# env summary (episode 248): {'order_requirements': 1000000, 'container_shortage': 104767, 'operation_number': 1860437}
#
# Collecting result:
# env summary (episode 249): {'order_requirements': 1000000, 'container_shortage': 84146, 'operation_number': 1863549}
#
# Collecting result:
# env summary (episode 250): {'order_requirements': 1000000, 'container_shortage': 84578, 'operation_number': 1823287}
#
# Evaluation result:
# env summary (episode 250): {'order_requirements': 1000000, 'container_shortage': 661768, 'operation_number': 574887}
#
# Collecting result:
# env summary (episode 251): {'order_requirements': 1000000, 'container_shortage': 100375, 'operation_number': 1831199}
#
# Collecting result:
# env summary (episode 252): {'order_requirements': 1000000, 'container_shortage': 75888, 'operation_number': 1876982}
#
# Collecting result:
# env summary (episode 253): {'order_requirements': 1000000, 'container_shortage': 104657, 'operation_number': 1791261}
#
# Collecting result:
# env summary (episode 254): {'order_requirements': 1000000, 'container_shortage': 137214, 'operation_number': 1831434}
#
# Collecting result:
# env summary (episode 255): {'order_requirements': 1000000, 'container_shortage': 122578, 'operation_number': 1823637}
#
# Evaluation result:
# env summary (episode 255): {'order_requirements': 1000000, 'container_shortage': 661768, 'operation_number': 574887}
#
# Collecting result:
# env summary (episode 256): {'order_requirements': 1000000, 'container_shortage': 89783, 'operation_number': 1859919}
#
# Collecting result:
# env summary (episode 257): {'order_requirements': 1000000, 'container_shortage': 100153, 'operation_number': 1798101}
#
# Collecting result:
# env summary (episode 258): {'order_requirements': 1000000, 'container_shortage': 54293, 'operation_number': 1935962}
#
# Collecting result:
# env summary (episode 259): {'order_requirements': 1000000, 'container_shortage': 120628, 'operation_number': 1812330}
#
# Collecting result:
# env summary (episode 260): {'order_requirements': 1000000, 'container_shortage': 119307, 'operation_number': 1812669}
#
# Evaluation result:
# env summary (episode 260): {'order_requirements': 1000000, 'container_shortage': 661768, 'operation_number': 574887}
#
# Collecting result:
# env summary (episode 261): {'order_requirements': 1000000, 'container_shortage': 86095, 'operation_number': 1826447}
#
# Collecting result:
# env summary (episode 262): {'order_requirements': 1000000, 'container_shortage': 124811, 'operation_number': 1789255}
#
# Collecting result:
# env summary (episode 263): {'order_requirements': 1000000, 'container_shortage': 90865, 'operation_number': 1868112}
#
# Collecting result:
# env summary (episode 264): {'order_requirements': 1000000, 'container_shortage': 50499, 'operation_number': 1945577}
#
# Collecting result:
# env summary (episode 265): {'order_requirements': 1000000, 'container_shortage': 65270, 'operation_number': 1880685}
#
# Evaluation result:
# env summary (episode 265): {'order_requirements': 1000000, 'container_shortage': 490995, 'operation_number': 817857}
#
# Collecting result:
# env summary (episode 266): {'order_requirements': 1000000, 'container_shortage': 92466, 'operation_number': 1882281}
#
# Collecting result:
# env summary (episode 267): {'order_requirements': 1000000, 'container_shortage': 95301, 'operation_number': 1850878}
#
# Collecting result:
# env summary (episode 268): {'order_requirements': 1000000, 'container_shortage': 72358, 'operation_number': 1875186}
#
# Collecting result:
# env summary (episode 269): {'order_requirements': 1000000, 'container_shortage': 96686, 'operation_number': 1811240}
#
# Collecting result:
# env summary (episode 270): {'order_requirements': 1000000, 'container_shortage': 81422, 'operation_number': 1910750}
#
# Evaluation result:
# env summary (episode 270): {'order_requirements': 1000000, 'container_shortage': 367524, 'operation_number': 985994}
#
# Collecting result:
# env summary (episode 271): {'order_requirements': 1000000, 'container_shortage': 67521, 'operation_number': 1866168}
#
# Collecting result:
# env summary (episode 272): {'order_requirements': 1000000, 'container_shortage': 82501, 'operation_number': 1847291}
#
# Collecting result:
# env summary (episode 273): {'order_requirements': 1000000, 'container_shortage': 52866, 'operation_number': 1923807}
#
# Collecting result:
# env summary (episode 274): {'order_requirements': 1000000, 'container_shortage': 79657, 'operation_number': 1883211}
#
# Collecting result:
# env summary (episode 275): {'order_requirements': 1000000, 'container_shortage': 99529, 'operation_number': 1833356}
#
# Evaluation result:
# env summary (episode 275): {'order_requirements': 1000000, 'container_shortage': 120894, 'operation_number': 1376391}
#
# Collecting result:
# env summary (episode 276): {'order_requirements': 1000000, 'container_shortage': 63817, 'operation_number': 1883675}
#
# Collecting result:
# env summary (episode 277): {'order_requirements': 1000000, 'container_shortage': 103262, 'operation_number': 1795447}
#
# Collecting result:
# env summary (episode 278): {'order_requirements': 1000000, 'container_shortage': 49809, 'operation_number': 1908899}
#
# Collecting result:
# env summary (episode 279): {'order_requirements': 1000000, 'container_shortage': 105209, 'operation_number': 1848146}
#
# Collecting result:
# env summary (episode 280): {'order_requirements': 1000000, 'container_shortage': 123308, 'operation_number': 1772137}
#
# Evaluation result:
# env summary (episode 280): {'order_requirements': 1000000, 'container_shortage': 524360, 'operation_number': 783566}
#
# Collecting result:
# env summary (episode 281): {'order_requirements': 1000000, 'container_shortage': 96068, 'operation_number': 1834863}
#
# Collecting result:
# env summary (episode 282): {'order_requirements': 1000000, 'container_shortage': 78320, 'operation_number': 1852994}
#
# Collecting result:
# env summary (episode 283): {'order_requirements': 1000000, 'container_shortage': 54829, 'operation_number': 1885032}
#
# Collecting result:
# env summary (episode 284): {'order_requirements': 1000000, 'container_shortage': 107890, 'operation_number': 1812188}
#
# Collecting result:
# env summary (episode 285): {'order_requirements': 1000000, 'container_shortage': 89670, 'operation_number': 1854336}
#
# Evaluation result:
# env summary (episode 285): {'order_requirements': 1000000, 'container_shortage': 484813, 'operation_number': 844870}
#
# Collecting result:
# env summary (episode 286): {'order_requirements': 1000000, 'container_shortage': 104260, 'operation_number': 1803202}
#
# Collecting result:
# env summary (episode 287): {'order_requirements': 1000000, 'container_shortage': 58777, 'operation_number': 1874053}
#
# Collecting result:
# env summary (episode 288): {'order_requirements': 1000000, 'container_shortage': 86765, 'operation_number': 1830333}
#
# Collecting result:
# env summary (episode 289): {'order_requirements': 1000000, 'container_shortage': 83363, 'operation_number': 1839325}
#
# Collecting result:
# env summary (episode 290): {'order_requirements': 1000000, 'container_shortage': 60785, 'operation_number': 1882194}
#
# Evaluation result:
# env summary (episode 290): {'order_requirements': 1000000, 'container_shortage': 491063, 'operation_number': 838306}
#
# Collecting result:
# env summary (episode 291): {'order_requirements': 1000000, 'container_shortage': 102253, 'operation_number': 1806024}
#
# Collecting result:
# ...
# env summary (episode 705): {'order_requirements': 1000000, 'container_shortage': 269786, 'operation_number': 1488674}
#
# Evaluation result:
# env summary (episode 705): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 706): {'order_requirements': 1000000, 'container_shortage': 280479, 'operation_number': 1473310}
#
# Collecting result:
# env summary (episode 707): {'order_requirements': 1000000, 'container_shortage': 318093, 'operation_number': 1405861}
#
# Collecting result:
# env summary (episode 708): {'order_requirements': 1000000, 'container_shortage': 321602, 'operation_number': 1395064}
#
# Collecting result:
# env summary (episode 709): {'order_requirements': 1000000, 'container_shortage': 307549, 'operation_number': 1418145}
#
# Collecting result:
# env summary (episode 710): {'order_requirements': 1000000, 'container_shortage': 319270, 'operation_number': 1397715}
#
# Evaluation result:
# env summary (episode 710): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 711): {'order_requirements': 1000000, 'container_shortage': 268226, 'operation_number': 1499411}
#
# Collecting result:
# env summary (episode 712): {'order_requirements': 1000000, 'container_shortage': 301403, 'operation_number': 1434806}
#
# Collecting result:
# env summary (episode 713): {'order_requirements': 1000000, 'container_shortage': 309725, 'operation_number': 1425732}
#
# Collecting result:
# env summary (episode 714): {'order_requirements': 1000000, 'container_shortage': 311595, 'operation_number': 1403264}
#
# Collecting result:
# env summary (episode 715): {'order_requirements': 1000000, 'container_shortage': 299704, 'operation_number': 1439981}
#
# Evaluation result:
# env summary (episode 715): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 716): {'order_requirements': 1000000, 'container_shortage': 300926, 'operation_number': 1437523}
#
# Collecting result:
# env summary (episode 717): {'order_requirements': 1000000, 'container_shortage': 326082, 'operation_number': 1389735}
#
# Collecting result:
# env summary (episode 718): {'order_requirements': 1000000, 'container_shortage': 294788, 'operation_number': 1449984}
#
# Collecting result:
# env summary (episode 719): {'order_requirements': 1000000, 'container_shortage': 304917, 'operation_number': 1423599}
#
# Collecting result:
# env summary (episode 720): {'order_requirements': 1000000, 'container_shortage': 303995, 'operation_number': 1431661}
#
# Evaluation result:
# env summary (episode 720): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 721): {'order_requirements': 1000000, 'container_shortage': 321425, 'operation_number': 1396186}
#
# Collecting result:
# env summary (episode 722): {'order_requirements': 1000000, 'container_shortage': 314771, 'operation_number': 1410736}
#
# Collecting result:
# env summary (episode 723): {'order_requirements': 1000000, 'container_shortage': 290093, 'operation_number': 1449834}
#
# Collecting result:
# env summary (episode 724): {'order_requirements': 1000000, 'container_shortage': 298944, 'operation_number': 1438765}
#
# Collecting result:
# env summary (episode 725): {'order_requirements': 1000000, 'container_shortage': 294021, 'operation_number': 1453928}
#
# Evaluation result:
# env summary (episode 725): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 726): {'order_requirements': 1000000, 'container_shortage': 285440, 'operation_number': 1467173}
#
# Collecting result:
# env summary (episode 727): {'order_requirements': 1000000, 'container_shortage': 293572, 'operation_number': 1451696}
#
# Collecting result:
# env summary (episode 728): {'order_requirements': 1000000, 'container_shortage': 244870, 'operation_number': 1544553}
#
# Collecting result:
# env summary (episode 729): {'order_requirements': 1000000, 'container_shortage': 324756, 'operation_number': 1394731}
#
# Collecting result:
# env summary (episode 730): {'order_requirements': 1000000, 'container_shortage': 321073, 'operation_number': 1393815}
#
# Evaluation result:
# env summary (episode 730): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 731): {'order_requirements': 1000000, 'container_shortage': 306395, 'operation_number': 1427703}
#
# Collecting result:
# env summary (episode 732): {'order_requirements': 1000000, 'container_shortage': 267522, 'operation_number': 1498944}
#
# Collecting result:
# env summary (episode 733): {'order_requirements': 1000000, 'container_shortage': 296969, 'operation_number': 1447164}
#
# Collecting result:
# env summary (episode 734): {'order_requirements': 1000000, 'container_shortage': 327573, 'operation_number': 1385346}
#
# Collecting result:
# env summary (episode 735): {'order_requirements': 1000000, 'container_shortage': 282033, 'operation_number': 1470566}
#
# Evaluation result:
# env summary (episode 735): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 736): {'order_requirements': 1000000, 'container_shortage': 301661, 'operation_number': 1430337}
#
# Collecting result:
# env summary (episode 737): {'order_requirements': 1000000, 'container_shortage': 282131, 'operation_number': 1474239}
#
# Collecting result:
# env summary (episode 738): {'order_requirements': 1000000, 'container_shortage': 297335, 'operation_number': 1443242}
#
# Collecting result:
# env summary (episode 739): {'order_requirements': 1000000, 'container_shortage': 299683, 'operation_number': 1434948}
#
# Collecting result:
# env summary (episode 740): {'order_requirements': 1000000, 'container_shortage': 221091, 'operation_number': 1585440}
#
# Evaluation result:
# env summary (episode 740): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 741): {'order_requirements': 1000000, 'container_shortage': 291094, 'operation_number': 1455455}
#
# Collecting result:
# env summary (episode 742): {'order_requirements': 1000000, 'container_shortage': 248769, 'operation_number': 1537662}
#
# Collecting result:
# env summary (episode 743): {'order_requirements': 1000000, 'container_shortage': 271261, 'operation_number': 1498780}
#
# Collecting result:
# env summary (episode 744): {'order_requirements': 1000000, 'container_shortage': 221404, 'operation_number': 1588348}
#
# Collecting result:
# env summary (episode 745): {'order_requirements': 1000000, 'container_shortage': 298289, 'operation_number': 1446174}
#
# Evaluation result:
# env summary (episode 745): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 746): {'order_requirements': 1000000, 'container_shortage': 213576, 'operation_number': 1599635}
#
# Collecting result:
# env summary (episode 747): {'order_requirements': 1000000, 'container_shortage': 308996, 'operation_number': 1412565}
#
# Collecting result:
# env summary (episode 748): {'order_requirements': 1000000, 'container_shortage': 354260, 'operation_number': 1336526}
#
# Collecting result:
# env summary (episode 749): {'order_requirements': 1000000, 'container_shortage': 275239, 'operation_number': 1488478}
#
# Collecting result:
# env summary (episode 750): {'order_requirements': 1000000, 'container_shortage': 251106, 'operation_number': 1527078}
#
# Evaluation result:
# env summary (episode 750): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 751): {'order_requirements': 1000000, 'container_shortage': 238182, 'operation_number': 1538916}
#
# Collecting result:
# env summary (episode 752): {'order_requirements': 1000000, 'container_shortage': 295397, 'operation_number': 1449187}
#
# Collecting result:
# env summary (episode 753): {'order_requirements': 1000000, 'container_shortage': 179970, 'operation_number': 1671617}
#
# Collecting result:
# env summary (episode 754): {'order_requirements': 1000000, 'container_shortage': 262543, 'operation_number': 1527844}
#
# Collecting result:
# env summary (episode 755): {'order_requirements': 1000000, 'container_shortage': 210298, 'operation_number': 1591353}
#
# Evaluation result:
# env summary (episode 755): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 756): {'order_requirements': 1000000, 'container_shortage': 345470, 'operation_number': 1344165}
#
# Collecting result:
# env summary (episode 757): {'order_requirements': 1000000, 'container_shortage': 263786, 'operation_number': 1508654}
#
# Collecting result:
# env summary (episode 758): {'order_requirements': 1000000, 'container_shortage': 157233, 'operation_number': 1716737}
#
# Collecting result:
# env summary (episode 759): {'order_requirements': 1000000, 'container_shortage': 289387, 'operation_number': 1438986}
#
# Collecting result:
# env summary (episode 760): {'order_requirements': 1000000, 'container_shortage': 255494, 'operation_number': 1515001}
#
# Evaluation result:
# env summary (episode 760): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 761): {'order_requirements': 1000000, 'container_shortage': 284599, 'operation_number': 1458878}
#
# Collecting result:
# env summary (episode 762): {'order_requirements': 1000000, 'container_shortage': 123837, 'operation_number': 1763642}
#
# Collecting result:
# env summary (episode 763): {'order_requirements': 1000000, 'container_shortage': 296914, 'operation_number': 1440426}
#
# Collecting result:
# env summary (episode 764): {'order_requirements': 1000000, 'container_shortage': 296540, 'operation_number': 1442968}
#
# Collecting result:
# env summary (episode 765): {'order_requirements': 1000000, 'container_shortage': 307961, 'operation_number': 1426095}
#
# Evaluation result:
# env summary (episode 765): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 766): {'order_requirements': 1000000, 'container_shortage': 215325, 'operation_number': 1604941}
#
# Collecting result:
# env summary (episode 767): {'order_requirements': 1000000, 'container_shortage': 284610, 'operation_number': 1467514}
#
# Collecting result:
# env summary (episode 768): {'order_requirements': 1000000, 'container_shortage': 267752, 'operation_number': 1498652}
#
# Collecting result:
# env summary (episode 769): {'order_requirements': 1000000, 'container_shortage': 310126, 'operation_number': 1419470}
#
# Collecting result:
# env summary (episode 770): {'order_requirements': 1000000, 'container_shortage': 190700, 'operation_number': 1640353}
#
# Evaluation result:
# env summary (episode 770): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 771): {'order_requirements': 1000000, 'container_shortage': 197159, 'operation_number': 1635747}
#
# Collecting result:
# env summary (episode 772): {'order_requirements': 1000000, 'container_shortage': 300906, 'operation_number': 1521490}
#
# Collecting result:
# env summary (episode 773): {'order_requirements': 1000000, 'container_shortage': 301428, 'operation_number': 1440042}
#
# Collecting result:
# env summary (episode 774): {'order_requirements': 1000000, 'container_shortage': 262013, 'operation_number': 1507693}
#
# Collecting result:
# env summary (episode 775): {'order_requirements': 1000000, 'container_shortage': 267380, 'operation_number': 1495175}
#
# Evaluation result:
# env summary (episode 775): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 776): {'order_requirements': 1000000, 'container_shortage': 284746, 'operation_number': 1468044}
#
# Collecting result:
# env summary (episode 777): {'order_requirements': 1000000, 'container_shortage': 215669, 'operation_number': 1593220}
#
# Collecting result:
# env summary (episode 778): {'order_requirements': 1000000, 'container_shortage': 293418, 'operation_number': 1439655}
#
# Collecting result:
# env summary (episode 779): {'order_requirements': 1000000, 'container_shortage': 234597, 'operation_number': 1561345}
#
# Collecting result:
# env summary (episode 780): {'order_requirements': 1000000, 'container_shortage': 243785, 'operation_number': 1532164}
#
# Evaluation result:
# env summary (episode 780): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 781): {'order_requirements': 1000000, 'container_shortage': 281947, 'operation_number': 1478716}
#
# Collecting result:
# env summary (episode 782): {'order_requirements': 1000000, 'container_shortage': 278008, 'operation_number': 1476092}
#
# Collecting result:
# env summary (episode 783): {'order_requirements': 1000000, 'container_shortage': 214980, 'operation_number': 1601287}
#
# Collecting result:
# env summary (episode 784): {'order_requirements': 1000000, 'container_shortage': 288094, 'operation_number': 1448638}
#
# Collecting result:
# env summary (episode 785): {'order_requirements': 1000000, 'container_shortage': 187648, 'operation_number': 1646734}
#
# Evaluation result:
# env summary (episode 785): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 786): {'order_requirements': 1000000, 'container_shortage': 272975, 'operation_number': 1485667}
#
# Collecting result:
# env summary (episode 787): {'order_requirements': 1000000, 'container_shortage': 205379, 'operation_number': 1606727}
#
# Collecting result:
# env summary (episode 788): {'order_requirements': 1000000, 'container_shortage': 250922, 'operation_number': 1528679}
#
# Collecting result:
# env summary (episode 789): {'order_requirements': 1000000, 'container_shortage': 304679, 'operation_number': 1416725}
#
# Collecting result:
# env summary (episode 790): {'order_requirements': 1000000, 'container_shortage': 244857, 'operation_number': 1535266}
#
# Evaluation result:
# env summary (episode 790): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 791): {'order_requirements': 1000000, 'container_shortage': 287628, 'operation_number': 1464911}
#
# Collecting result:
# env summary (episode 792): {'order_requirements': 1000000, 'container_shortage': 270173, 'operation_number': 1484308}
#
# Collecting result:
# env summary (episode 793): {'order_requirements': 1000000, 'container_shortage': 268023, 'operation_number': 1489011}
#
# Collecting result:
# env summary (episode 794): {'order_requirements': 1000000, 'container_shortage': 203118, 'operation_number': 1604858}
#
# Collecting result:
# env summary (episode 795): {'order_requirements': 1000000, 'container_shortage': 202100, 'operation_number': 1623922}
#
# Evaluation result:
# env summary (episode 795): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
#
# Collecting result:
# env summary (episode 796): {'order_requirements': 1000000, 'container_shortage': 261508, 'operation_number': 1513663}
#
# Collecting result:
# env summary (episode 797): {'order_requirements': 1000000, 'container_shortage': 223118, 'operation_number': 1587565}
#
# Collecting result:
# env summary (episode 798): {'order_requirements': 1000000, 'container_shortage': 214653, 'operation_number': 1576619}
#
# Collecting result:
# env summary (episode 799): {'order_requirements': 1000000, 'container_shortage': 69183, 'operation_number': 1865738}
#
# Collecting result:
# env summary (episode 800): {'order_requirements': 1000000, 'container_shortage': 146548, 'operation_number': 1725135}
#
# Evaluation result:
# env summary (episode 800): {'order_requirements': 1000000, 'container_shortage': 289318, 'operation_number': 1197913}
