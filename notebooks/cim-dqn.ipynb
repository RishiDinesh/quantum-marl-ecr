# %%
# Import necessary packages
from typing import Any, Dict, List, Tuple, Union

import numpy as np
import torch
from torch.optim import Adam, RMSprop

from maro.rl.model import DiscreteQNet, FullyConnected, VNet
from maro.rl.policy import DiscretePolicyGradient
from maro.rl.rl_component.rl_component_bundle import RLComponentBundle
from maro.rl.rollout import AbsEnvSampler, CacheElement, ExpElement
from maro.rl.training import TrainingManager
from maro.rl.training.algorithms import PPOParams, PPOTrainer
from maro.simulator import Env
from maro.simulator.scenarios.cim.common import Action, ActionType, DecisionEvent

# %%
# env and shaping config
reward_shaping_conf = {
    "time_window": 99,
    "fulfillment_factor": 1.0,
    "shortage_factor": 1.0,
    "time_decay": 0.97,
}
state_shaping_conf = {
    "look_back": 7,
    "max_ports_downstream": 2,
}
port_attributes = ["empty", "full", "on_shipper", "on_consignee", "booking", "shortage", "fulfillment"]
vessel_attributes = ["empty", "full", "remaining_space"]
action_shaping_conf = {
    "action_space": [(i - 10) / 10 for i in range(21)],
    "finite_vessel_space": True,
    "has_early_discharge": True,
}

# %%
class CIMEnvSampler(AbsEnvSampler):
    def _get_global_and_agent_state_impl(
        self,
        event: DecisionEvent,
        tick: int = None,
    ) -> Tuple[Union[None, np.ndarray, List[object]], Dict[Any, Union[np.ndarray, List[object]]]]:
        tick = self._env.tick
        vessel_snapshots, port_snapshots = self._env.snapshot_list["vessels"], self._env.snapshot_list["ports"]
        port_idx, vessel_idx = event.port_idx, event.vessel_idx
        ticks = [max(0, tick - rt) for rt in range(state_shaping_conf["look_back"] - 1)]
        future_port_list = vessel_snapshots[tick:vessel_idx:"future_stop_list"].astype("int")
        state = np.concatenate(
            [
                port_snapshots[ticks : [port_idx] + list(future_port_list) : port_attributes],
                vessel_snapshots[tick:vessel_idx:vessel_attributes],
            ],
        )
        return state, {port_idx: state}

    def _translate_to_env_action(
        self,
        action_dict: Dict[Any, Union[np.ndarray, List[object]]],
        event: DecisionEvent,
    ) -> Dict[Any, object]:
        action_space = action_shaping_conf["action_space"]
        finite_vsl_space = action_shaping_conf["finite_vessel_space"]
        has_early_discharge = action_shaping_conf["has_early_discharge"]

        port_idx, model_action = list(action_dict.items()).pop()

        vsl_idx, action_scope = event.vessel_idx, event.action_scope
        vsl_snapshots = self._env.snapshot_list["vessels"]
        vsl_space = vsl_snapshots[self._env.tick : vsl_idx : vessel_attributes][2] if finite_vsl_space else float("inf")

        percent = abs(action_space[model_action[0]])
        zero_action_idx = len(action_space) / 2  # index corresponding to value zero.
        if model_action < zero_action_idx:
            action_type = ActionType.LOAD
            actual_action = min(round(percent * action_scope.load), vsl_space)
        elif model_action > zero_action_idx:
            action_type = ActionType.DISCHARGE
            early_discharge = (
                vsl_snapshots[self._env.tick : vsl_idx : "early_discharge"][0] if has_early_discharge else 0
            )
            plan_action = percent * (action_scope.discharge + early_discharge) - early_discharge
            actual_action = round(plan_action) if plan_action > 0 else round(percent * action_scope.discharge)
        else:
            actual_action, action_type = 0, None

        return {port_idx: Action(vsl_idx, int(port_idx), actual_action, action_type)}

    def _get_reward(self, env_action_dict: Dict[Any, object], event: DecisionEvent, tick: int) -> Dict[Any, float]:
        start_tick = tick + 1
        ticks = list(range(start_tick, start_tick + reward_shaping_conf["time_window"]))

        # Get the ports that took actions at the given tick
        ports = [int(port) for port in list(env_action_dict.keys())]
        port_snapshots = self._env.snapshot_list["ports"]
        future_fulfillment = port_snapshots[ticks:ports:"fulfillment"].reshape(len(ticks), -1)
        future_shortage = port_snapshots[ticks:ports:"shortage"].reshape(len(ticks), -1)

        decay_list = [reward_shaping_conf["time_decay"] ** i for i in range(reward_shaping_conf["time_window"])]
        rewards = np.float32(
            reward_shaping_conf["fulfillment_factor"] * np.dot(future_fulfillment.T, decay_list)
            - reward_shaping_conf["shortage_factor"] * np.dot(future_shortage.T, decay_list),
        )
        return {agent_id: reward for agent_id, reward in zip(ports, rewards)}

    def _post_step(self, cache_element: CacheElement) -> None:
        self._info["env_metric"] = self._env.metrics

    def _post_eval_step(self, cache_element: CacheElement) -> None:
        self._post_step(cache_element)

    def post_collect(self, info_list: list, ep: int) -> None:
        # print the env metric from each rollout worker
        for info in info_list:
            print(f"env summary (episode {ep}): {info['env_metric']}")

        # average env metric
        metric_keys, num_envs = info_list[0]["env_metric"].keys(), len(info_list)
        avg_metric = {key: sum(info["env_metric"][key] for info in info_list) / num_envs for key in metric_keys}
        print(f"average env summary (episode {ep}): {avg_metric}")

        self.metrics.update(avg_metric)
        self.metrics = {k: v for k, v in self.metrics.items() if not k.startswith("val/")}

    def post_evaluate(self, info_list: list, ep: int) -> None:
        # print the env metric from each rollout worker
        for info in info_list:
            print(f"env summary (episode {ep}): {info['env_metric']}")

        # average env metric
        metric_keys, num_envs = info_list[0]["env_metric"].keys(), len(info_list)
        avg_metric = {key: sum(info["env_metric"][key] for info in info_list) / num_envs for key in metric_keys}
        print(f"average env summary (episode {ep}): {avg_metric}")

        self.metrics.update({"val/" + k: v for k, v in avg_metric.items()})

    def monitor_metrics(self) -> float:
        return -self.metrics["val/container_shortage"]

# %%
from typing import Optional, Tuple

import torch
from torch.optim import RMSprop
from maro.rl import exploration
from maro.rl.exploration import epsilon_greedy
from maro.rl.model import DiscreteQNet, FullyConnected
from maro.rl.policy import ValueBasedPolicy
from maro.rl.training.algorithms import DQNParams, DQNTrainer

state_dim = ((state_shaping_conf["look_back"] + 1) * (state_shaping_conf["max_ports_downstream"] + 1) * len(port_attributes)
    + len(vessel_attributes)
)
action_num = len(action_shaping_conf["action_space"])

# %%
q_net_conf = {
    "hidden_dims": [256, 128, 64, 32],
    "activation": torch.nn.LeakyReLU,
    "output_activation": torch.nn.LeakyReLU,
    "softmax": False,
    "batch_norm": True,
    "skip_connection": False,
    "head": True,
    "dropout_p": 0.0,
}
learning_rate = 0.05


class MyQNet(DiscreteQNet):
    def __init__(
        self,
        state_dim: int,
        action_num: int,
        dueling_param: Optional[Tuple[dict, dict]] = None,
    ) -> None:
        super(MyQNet, self).__init__(state_dim=state_dim, action_num=action_num)

        self._use_dueling = dueling_param is not None
        self._fc = FullyConnected(input_dim=state_dim, output_dim=1 if self._use_dueling else action_num, **q_net_conf)
        if self._use_dueling:
            q_kwargs, v_kwargs = dueling_param
            self._q = FullyConnected(input_dim=self._fc.output_dim, output_dim=action_num, **q_kwargs)
            self._v = FullyConnected(input_dim=self._fc.output_dim, output_dim=1, **v_kwargs)

        self._optim = RMSprop(self.parameters(), lr=learning_rate)

    def _get_q_values_for_all_actions(self, states: torch.Tensor) -> torch.Tensor:
        logits = self._fc(states)
        if self._use_dueling:
            q = self._q(logits)
            v = self._v(logits)
            logits = q - q.mean(dim=1, keepdim=True) + v
        return logits


def get_dqn_policy(state_dim: int, action_num: int, name: str) -> ValueBasedPolicy:
    q_kwargs = {
        "hidden_dims": [128],
        "activation": torch.nn.LeakyReLU,
        "output_activation": torch.nn.LeakyReLU,
        "softmax": False,
        "batch_norm": True,
        "skip_connection": False,
        "head": True,
        "dropout_p": 0.0,
    }
    v_kwargs = {
        "hidden_dims": [128],
        "activation": torch.nn.LeakyReLU,
        "output_activation": None,
        "softmax": False,
        "batch_norm": True,
        "skip_connection": False,
        "head": True,
        "dropout_p": 0.0,
    }

    return ValueBasedPolicy(
        name=name,
        q_net=MyQNet(
            state_dim,
            action_num,
            dueling_param=(q_kwargs, v_kwargs),
        ),
        exploration_strategy=(epsilon_greedy, {"epsilon": 0.4}),
        warmup=100,
    )


def get_dqn(name: str) -> DQNTrainer:
    return DQNTrainer(
        name=name,
        reward_discount=0.0,
        replay_memory_capacity=10000,
        batch_size=32,
        params=DQNParams(
            update_target_every=5,
            num_epochs=10,
            soft_update_coef=0.1,
            double=False
        ),
    )

# %%
learn_env = Env(scenario="cim", topology="toy.4p_ssdd_l0.0", durations=500,options={"enable-dump-snapshot": "./dqn_learn"})
test_env = Env(scenario="cim", topology="toy.4p_ssdd_l0.1", durations=500,options={"enable-dump-snapshot": "./dqn_test"})
num_agents = len(learn_env.agent_idx_list)
agent2policy = {agent: f"dqn_{agent}.policy" for agent in learn_env.agent_idx_list}
policies = [get_dqn_policy(state_dim, action_num, f"dqn_{i}.policy") for i in range(num_agents)]
trainers = [get_dqn(f"dqn_{i}") for i in range(num_agents)]

# %%
rl_component_bundle = RLComponentBundle(
    env_sampler=CIMEnvSampler(
        learn_env=learn_env,
        test_env=test_env,
        policies=policies,
        agent2policy=agent2policy,
        reward_eval_delay=reward_shaping_conf["time_window"],
    ),
    agent2policy=agent2policy,
    policies=policies,
    trainers=trainers,
)

# %%
env_sampler = rl_component_bundle.env_sampler

num_episodes = 1000
eval_schedule = [5*i for i in range(1,201)]
eval_point_index = 0

training_manager = TrainingManager(rl_component_bundle=rl_component_bundle)
for ep in range(1, num_episodes + 1):
    result = env_sampler.sample()
    experiences: List[List[ExpElement]] = result["experiences"]
    info_list: List[dict] = result["info"]
        
    print("Collecting result:")
    env_sampler.post_collect(info_list, ep)
    print()

    training_manager.record_experiences(experiences)
    training_manager.train_step()

    if ep == eval_schedule[eval_point_index]:
        eval_point_index += 1
        result = env_sampler.eval()
        
        print("Evaluation result:")
        env_sampler.post_evaluate(result["info"], ep)
        print()

training_manager.exit()
# Out:
# Collecting result:
# env summary (episode 1): {'order_requirements': 1000000, 'container_shortage': 687462, 'operation_number': 1697826}
# average env summary (episode 1): {'order_requirements': 1000000.0, 'container_shortage': 687462.0, 'operation_number': 1697826.0}
#
# Collecting result:
# env summary (episode 2): {'order_requirements': 1000000, 'container_shortage': 722299, 'operation_number': 1271650}
# average env summary (episode 2): {'order_requirements': 1000000.0, 'container_shortage': 722299.0, 'operation_number': 1271650.0}
#
# Collecting result:
# env summary (episode 3): {'order_requirements': 1000000, 'container_shortage': 963812, 'operation_number': 130799}
# average env summary (episode 3): {'order_requirements': 1000000.0, 'container_shortage': 963812.0, 'operation_number': 130799.0}
#
# Collecting result:
# env summary (episode 4): {'order_requirements': 1000000, 'container_shortage': 973653, 'operation_number': 102286}
# average env summary (episode 4): {'order_requirements': 1000000.0, 'container_shortage': 973653.0, 'operation_number': 102286.0}
#
# Collecting result:
# env summary (episode 5): {'order_requirements': 1000000, 'container_shortage': 961379, 'operation_number': 79438}
# average env summary (episode 5): {'order_requirements': 1000000.0, 'container_shortage': 961379.0, 'operation_number': 79438.0}
#
# Evaluation result:
# env summary (episode 5): {'order_requirements': 1000000, 'container_shortage': 896540, 'operation_number': 64216}
# average env summary (episode 5): {'order_requirements': 1000000.0, 'container_shortage': 896540.0, 'operation_number': 64216.0}
#
# Collecting result:
# env summary (episode 6): {'order_requirements': 1000000, 'container_shortage': 966235, 'operation_number': 87278}
# average env summary (episode 6): {'order_requirements': 1000000.0, 'container_shortage': 966235.0, 'operation_number': 87278.0}
#
# Collecting result:
# env summary (episode 7): {'order_requirements': 1000000, 'container_shortage': 969023, 'operation_number': 105799}
# average env summary (episode 7): {'order_requirements': 1000000.0, 'container_shortage': 969023.0, 'operation_number': 105799.0}
#
# Collecting result:
# env summary (episode 8): {'order_requirements': 1000000, 'container_shortage': 554018, 'operation_number': 1261902}
# average env summary (episode 8): {'order_requirements': 1000000.0, 'container_shortage': 554018.0, 'operation_number': 1261902.0}
#
# Collecting result:
# env summary (episode 9): {'order_requirements': 1000000, 'container_shortage': 924689, 'operation_number': 291616}
# average env summary (episode 9): {'order_requirements': 1000000.0, 'container_shortage': 924689.0, 'operation_number': 291616.0}
#
# Collecting result:
# env summary (episode 10): {'order_requirements': 1000000, 'container_shortage': 954495, 'operation_number': 233195}
# average env summary (episode 10): {'order_requirements': 1000000.0, 'container_shortage': 954495.0, 'operation_number': 233195.0}
#
# Evaluation result:
# env summary (episode 10): {'order_requirements': 1000000, 'container_shortage': 572052, 'operation_number': 548807}
# average env summary (episode 10): {'order_requirements': 1000000.0, 'container_shortage': 572052.0, 'operation_number': 548807.0}
#
# Collecting result:
# env summary (episode 11): {'order_requirements': 1000000, 'container_shortage': 976524, 'operation_number': 203947}
# average env summary (episode 11): {'order_requirements': 1000000.0, 'container_shortage': 976524.0, 'operation_number': 203947.0}
#
# Collecting result:
# env summary (episode 12): {'order_requirements': 1000000, 'container_shortage': 973869, 'operation_number': 177919}
# average env summary (episode 12): {'order_requirements': 1000000.0, 'container_shortage': 973869.0, 'operation_number': 177919.0}
#
# Collecting result:
# env summary (episode 13): {'order_requirements': 1000000, 'container_shortage': 962027, 'operation_number': 214917}
# average env summary (episode 13): {'order_requirements': 1000000.0, 'container_shortage': 962027.0, 'operation_number': 214917.0}
#
# Collecting result:
# env summary (episode 14): {'order_requirements': 1000000, 'container_shortage': 964773, 'operation_number': 220045}
# average env summary (episode 14): {'order_requirements': 1000000.0, 'container_shortage': 964773.0, 'operation_number': 220045.0}
#
# Collecting result:
# env summary (episode 15): {'order_requirements': 1000000, 'container_shortage': 973640, 'operation_number': 142663}
# average env summary (episode 15): {'order_requirements': 1000000.0, 'container_shortage': 973640.0, 'operation_number': 142663.0}
#
# Evaluation result:
# env summary (episode 15): {'order_requirements': 1000000, 'container_shortage': 291368, 'operation_number': 1041532}
# average env summary (episode 15): {'order_requirements': 1000000.0, 'container_shortage': 291368.0, 'operation_number': 1041532.0}
#
# Collecting result:
# env summary (episode 16): {'order_requirements': 1000000, 'container_shortage': 953360, 'operation_number': 461968}
# average env summary (episode 16): {'order_requirements': 1000000.0, 'container_shortage': 953360.0, 'operation_number': 461968.0}
#
# Collecting result:
# env summary (episode 17): {'order_requirements': 1000000, 'container_shortage': 972390, 'operation_number': 111086}
# average env summary (episode 17): {'order_requirements': 1000000.0, 'container_shortage': 972390.0, 'operation_number': 111086.0}
#
# Collecting result:
# env summary (episode 18): {'order_requirements': 1000000, 'container_shortage': 963681, 'operation_number': 178389}
# average env summary (episode 18): {'order_requirements': 1000000.0, 'container_shortage': 963681.0, 'operation_number': 178389.0}
#
# Collecting result:
# env summary (episode 19): {'order_requirements': 1000000, 'container_shortage': 968312, 'operation_number': 134301}
# average env summary (episode 19): {'order_requirements': 1000000.0, 'container_shortage': 968312.0, 'operation_number': 134301.0}
#
# Collecting result:
# env summary (episode 20): {'order_requirements': 1000000, 'container_shortage': 943265, 'operation_number': 141385}
# average env summary (episode 20): {'order_requirements': 1000000.0, 'container_shortage': 943265.0, 'operation_number': 141385.0}
#
# Evaluation result:
# env summary (episode 20): {'order_requirements': 1000000, 'container_shortage': 853759, 'operation_number': 248738}
# average env summary (episode 20): {'order_requirements': 1000000.0, 'container_shortage': 853759.0, 'operation_number': 248738.0}
#
# Collecting result:
# env summary (episode 21): {'order_requirements': 1000000, 'container_shortage': 971147, 'operation_number': 193824}
# average env summary (episode 21): {'order_requirements': 1000000.0, 'container_shortage': 971147.0, 'operation_number': 193824.0}
#
# Collecting result:
# env summary (episode 22): {'order_requirements': 1000000, 'container_shortage': 955746, 'operation_number': 160084}
# average env summary (episode 22): {'order_requirements': 1000000.0, 'container_shortage': 955746.0, 'operation_number': 160084.0}
#
# Collecting result:
# env summary (episode 23): {'order_requirements': 1000000, 'container_shortage': 948650, 'operation_number': 189653}
# average env summary (episode 23): {'order_requirements': 1000000.0, 'container_shortage': 948650.0, 'operation_number': 189653.0}
#
# Collecting result:
# env summary (episode 24): {'order_requirements': 1000000, 'container_shortage': 951895, 'operation_number': 160236}
# average env summary (episode 24): {'order_requirements': 1000000.0, 'container_shortage': 951895.0, 'operation_number': 160236.0}
#
# Collecting result:
# env summary (episode 25): {'order_requirements': 1000000, 'container_shortage': 941082, 'operation_number': 184804}
# average env summary (episode 25): {'order_requirements': 1000000.0, 'container_shortage': 941082.0, 'operation_number': 184804.0}
#
# Evaluation result:
# env summary (episode 25): {'order_requirements': 1000000, 'container_shortage': 930573, 'operation_number': 133323}
# average env summary (episode 25): {'order_requirements': 1000000.0, 'container_shortage': 930573.0, 'operation_number': 133323.0}
#
# Collecting result:
# env summary (episode 26): {'order_requirements': 1000000, 'container_shortage': 948744, 'operation_number': 145332}
# average env summary (episode 26): {'order_requirements': 1000000.0, 'container_shortage': 948744.0, 'operation_number': 145332.0}
#
# Collecting result:
# env summary (episode 27): {'order_requirements': 1000000, 'container_shortage': 931326, 'operation_number': 157735}
# average env summary (episode 27): {'order_requirements': 1000000.0, 'container_shortage': 931326.0, 'operation_number': 157735.0}
#
# Collecting result:
# env summary (episode 28): {'order_requirements': 1000000, 'container_shortage': 941331, 'operation_number': 159261}
# average env summary (episode 28): {'order_requirements': 1000000.0, 'container_shortage': 941331.0, 'operation_number': 159261.0}
#
# Collecting result:
# env summary (episode 29): {'order_requirements': 1000000, 'container_shortage': 946768, 'operation_number': 161544}
# average env summary (episode 29): {'order_requirements': 1000000.0, 'container_shortage': 946768.0, 'operation_number': 161544.0}
#
# Collecting result:
# env summary (episode 30): {'order_requirements': 1000000, 'container_shortage': 939739, 'operation_number': 160074}
# average env summary (episode 30): {'order_requirements': 1000000.0, 'container_shortage': 939739.0, 'operation_number': 160074.0}
#
# Evaluation result:
# env summary (episode 30): {'order_requirements': 1000000, 'container_shortage': 914832, 'operation_number': 158509}
# average env summary (episode 30): {'order_requirements': 1000000.0, 'container_shortage': 914832.0, 'operation_number': 158509.0}
#
# Collecting result:
# env summary (episode 31): {'order_requirements': 1000000, 'container_shortage': 951036, 'operation_number': 159974}
# average env summary (episode 31): {'order_requirements': 1000000.0, 'container_shortage': 951036.0, 'operation_number': 159974.0}
#
# Collecting result:
# env summary (episode 32): {'order_requirements': 1000000, 'container_shortage': 946117, 'operation_number': 159048}
# average env summary (episode 32): {'order_requirements': 1000000.0, 'container_shortage': 946117.0, 'operation_number': 159048.0}
#
# Collecting result:
# env summary (episode 33): {'order_requirements': 1000000, 'container_shortage': 952937, 'operation_number': 158696}
# average env summary (episode 33): {'order_requirements': 1000000.0, 'container_shortage': 952937.0, 'operation_number': 158696.0}
#
# Collecting result:
# env summary (episode 34): {'order_requirements': 1000000, 'container_shortage': 949211, 'operation_number': 143449}
# average env summary (episode 34): {'order_requirements': 1000000.0, 'container_shortage': 949211.0, 'operation_number': 143449.0}
#
# Collecting result:
# env summary (episode 35): {'order_requirements': 1000000, 'container_shortage': 948313, 'operation_number': 141613}
# average env summary (episode 35): {'order_requirements': 1000000.0, 'container_shortage': 948313.0, 'operation_number': 141613.0}
#
# Evaluation result:
# env summary (episode 35): {'order_requirements': 1000000, 'container_shortage': 939212, 'operation_number': 124156}
# average env summary (episode 35): {'order_requirements': 1000000.0, 'container_shortage': 939212.0, 'operation_number': 124156.0}
#
# Collecting result:
# env summary (episode 36): {'order_requirements': 1000000, 'container_shortage': 956525, 'operation_number': 159456}
# average env summary (episode 36): {'order_requirements': 1000000.0, 'container_shortage': 956525.0, 'operation_number': 159456.0}
#
# Collecting result:
# env summary (episode 37): {'order_requirements': 1000000, 'container_shortage': 955646, 'operation_number': 168834}
# average env summary (episode 37): {'order_requirements': 1000000.0, 'container_shortage': 955646.0, 'operation_number': 168834.0}
#
# Collecting result:
# env summary (episode 38): {'order_requirements': 1000000, 'container_shortage': 944126, 'operation_number': 172774}
# average env summary (episode 38): {'order_requirements': 1000000.0, 'container_shortage': 944126.0, 'operation_number': 172774.0}
#
# Collecting result:
# env summary (episode 39): {'order_requirements': 1000000, 'container_shortage': 945230, 'operation_number': 125622}
# average env summary (episode 39): {'order_requirements': 1000000.0, 'container_shortage': 945230.0, 'operation_number': 125622.0}
#
# Collecting result:
# env summary (episode 40): {'order_requirements': 1000000, 'container_shortage': 944418, 'operation_number': 183095}
# average env summary (episode 40): {'order_requirements': 1000000.0, 'container_shortage': 944418.0, 'operation_number': 183095.0}
#
# Evaluation result:
# env summary (episode 40): {'order_requirements': 1000000, 'container_shortage': 872470, 'operation_number': 218280}
# average env summary (episode 40): {'order_requirements': 1000000.0, 'container_shortage': 872470.0, 'operation_number': 218280.0}
#
# Collecting result:
# env summary (episode 41): {'order_requirements': 1000000, 'container_shortage': 952353, 'operation_number': 165180}
# average env summary (episode 41): {'order_requirements': 1000000.0, 'container_shortage': 952353.0, 'operation_number': 165180.0}
#
# Collecting result:
# env summary (episode 42): {'order_requirements': 1000000, 'container_shortage': 951894, 'operation_number': 145695}
# average env summary (episode 42): {'order_requirements': 1000000.0, 'container_shortage': 951894.0, 'operation_number': 145695.0}
#
# Collecting result:
# env summary (episode 43): {'order_requirements': 1000000, 'container_shortage': 947575, 'operation_number': 151997}
# average env summary (episode 43): {'order_requirements': 1000000.0, 'container_shortage': 947575.0, 'operation_number': 151997.0}
#
# Collecting result:
# env summary (episode 44): {'order_requirements': 1000000, 'container_shortage': 945081, 'operation_number': 160141}
# average env summary (episode 44): {'order_requirements': 1000000.0, 'container_shortage': 945081.0, 'operation_number': 160141.0}
#
# Collecting result:
# env summary (episode 45): {'order_requirements': 1000000, 'container_shortage': 938503, 'operation_number': 200245}
# average env summary (episode 45): {'order_requirements': 1000000.0, 'container_shortage': 938503.0, 'operation_number': 200245.0}
#
# Evaluation result:
# env summary (episode 45): {'order_requirements': 1000000, 'container_shortage': 872142, 'operation_number': 222519}
# average env summary (episode 45): {'order_requirements': 1000000.0, 'container_shortage': 872142.0, 'operation_number': 222519.0}
#
# Collecting result:
# env summary (episode 46): {'order_requirements': 1000000, 'container_shortage': 949189, 'operation_number': 153847}
# average env summary (episode 46): {'order_requirements': 1000000.0, 'container_shortage': 949189.0, 'operation_number': 153847.0}
#
# Collecting result:
# env summary (episode 47): {'order_requirements': 1000000, 'container_shortage': 971525, 'operation_number': 114483}
# average env summary (episode 47): {'order_requirements': 1000000.0, 'container_shortage': 971525.0, 'operation_number': 114483.0}
#
# Collecting result:
# env summary (episode 48): {'order_requirements': 1000000, 'container_shortage': 957687, 'operation_number': 100375}
# average env summary (episode 48): {'order_requirements': 1000000.0, 'container_shortage': 957687.0, 'operation_number': 100375.0}
#
# Collecting result:
# env summary (episode 49): {'order_requirements': 1000000, 'container_shortage': 957687, 'operation_number': 82567}
# average env summary (episode 49): {'order_requirements': 1000000.0, 'container_shortage': 957687.0, 'operation_number': 82567.0}
#
# Collecting result:
# env summary (episode 50): {'order_requirements': 1000000, 'container_shortage': 957131, 'operation_number': 106458}
# average env summary (episode 50): {'order_requirements': 1000000.0, 'container_shortage': 957131.0, 'operation_number': 106458.0}
#
# Evaluation result:
# env summary (episode 50): {'order_requirements': 1000000, 'container_shortage': 887422, 'operation_number': 202388}
# average env summary (episode 50): {'order_requirements': 1000000.0, 'container_shortage': 887422.0, 'operation_number': 202388.0}
#
# Collecting result:
# env summary (episode 51): {'order_requirements': 1000000, 'container_shortage': 972660, 'operation_number': 112517}
# average env summary (episode 51): {'order_requirements': 1000000.0, 'container_shortage': 972660.0, 'operation_number': 112517.0}
#
# Collecting result:
# env summary (episode 52): {'order_requirements': 1000000, 'container_shortage': 957131, 'operation_number': 81455}
# average env summary (episode 52): {'order_requirements': 1000000.0, 'container_shortage': 957131.0, 'operation_number': 81455.0}
#
# Collecting result:
# env summary (episode 53): {'order_requirements': 1000000, 'container_shortage': 953591, 'operation_number': 73690}
# average env summary (episode 53): {'order_requirements': 1000000.0, 'container_shortage': 953591.0, 'operation_number': 73690.0}
#
# Collecting result:
# env summary (episode 54): {'order_requirements': 1000000, 'container_shortage': 949779, 'operation_number': 136483}
# average env summary (episode 54): {'order_requirements': 1000000.0, 'container_shortage': 949779.0, 'operation_number': 136483.0}
#
# Collecting result:
# env summary (episode 55): {'order_requirements': 1000000, 'container_shortage': 972660, 'operation_number': 122841}
# average env summary (episode 55): {'order_requirements': 1000000.0, 'container_shortage': 972660.0, 'operation_number': 122841.0}
#
# Evaluation result:
# env summary (episode 55): {'order_requirements': 1000000, 'container_shortage': 872328, 'operation_number': 220944}
# average env summary (episode 55): {'order_requirements': 1000000.0, 'container_shortage': 872328.0, 'operation_number': 220944.0}
#
# Collecting result:
# env summary (episode 56): {'order_requirements': 1000000, 'container_shortage': 961695, 'operation_number': 115946}
# average env summary (episode 56): {'order_requirements': 1000000.0, 'container_shortage': 961695.0, 'operation_number': 115946.0}
#
# Collecting result:
# env summary (episode 57): {'order_requirements': 1000000, 'container_shortage': 972660, 'operation_number': 147784}
# average env summary (episode 57): {'order_requirements': 1000000.0, 'container_shortage': 972660.0, 'operation_number': 147784.0}
#
# Collecting result:
# env summary (episode 58): {'order_requirements': 1000000, 'container_shortage': 957131, 'operation_number': 81759}
# average env summary (episode 58): {'order_requirements': 1000000.0, 'container_shortage': 957131.0, 'operation_number': 81759.0}
#
# Collecting result:
# env summary (episode 59): {'order_requirements': 1000000, 'container_shortage': 958111, 'operation_number': 70595}
# average env summary (episode 59): {'order_requirements': 1000000.0, 'container_shortage': 958111.0, 'operation_number': 70595.0}
#
# Collecting result:
# env summary (episode 60): {'order_requirements': 1000000, 'container_shortage': 971680, 'operation_number': 144176}
# average env summary (episode 60): {'order_requirements': 1000000.0, 'container_shortage': 971680.0, 'operation_number': 144176.0}
#
# Evaluation result:
# env summary (episode 60): {'order_requirements': 1000000, 'container_shortage': 874423, 'operation_number': 214406}
# average env summary (episode 60): {'order_requirements': 1000000.0, 'container_shortage': 874423.0, 'operation_number': 214406.0}
#
# Collecting result:
# env summary (episode 61): {'order_requirements': 1000000, 'container_shortage': 950441, 'operation_number': 74323}
# average env summary (episode 61): {'order_requirements': 1000000.0, 'container_shortage': 950441.0, 'operation_number': 74323.0}
#
# Collecting result:
# env summary (episode 62): {'order_requirements': 1000000, 'container_shortage': 966558, 'operation_number': 119539}
# average env summary (episode 62): {'order_requirements': 1000000.0, 'container_shortage': 966558.0, 'operation_number': 119539.0}
#
# Collecting result:
# env summary (episode 63): {'order_requirements': 1000000, 'container_shortage': 947162, 'operation_number': 74854}
# average env summary (episode 63): {'order_requirements': 1000000.0, 'container_shortage': 947162.0, 'operation_number': 74854.0}
#
# Collecting result:
# env summary (episode 64): {'order_requirements': 1000000, 'container_shortage': 954903, 'operation_number': 95405}
# average env summary (episode 64): {'order_requirements': 1000000.0, 'container_shortage': 954903.0, 'operation_number': 95405.0}
#
# Collecting result:
# env summary (episode 65): {'order_requirements': 1000000, 'container_shortage': 948652, 'operation_number': 137735}
# average env summary (episode 65): {'order_requirements': 1000000.0, 'container_shortage': 948652.0, 'operation_number': 137735.0}
#
# Evaluation result:
# env summary (episode 65): {'order_requirements': 1000000, 'container_shortage': 869724, 'operation_number': 217503}
# average env summary (episode 65): {'order_requirements': 1000000.0, 'container_shortage': 869724.0, 'operation_number': 217503.0}
#
# Collecting result:
# env summary (episode 66): {'order_requirements': 1000000, 'container_shortage': 954790, 'operation_number': 80110}
# average env summary (episode 66): {'order_requirements': 1000000.0, 'container_shortage': 954790.0, 'operation_number': 80110.0}
#
# Collecting result:
# env summary (episode 67): {'order_requirements': 1000000, 'container_shortage': 906392, 'operation_number': 347589}
# average env summary (episode 67): {'order_requirements': 1000000.0, 'container_shortage': 906392.0, 'operation_number': 347589.0}
#
# Collecting result:
# env summary (episode 68): {'order_requirements': 1000000, 'container_shortage': 337299, 'operation_number': 1364859}
# average env summary (episode 68): {'order_requirements': 1000000.0, 'container_shortage': 337299.0, 'operation_number': 1364859.0}
#
# Collecting result:
# env summary (episode 69): {'order_requirements': 1000000, 'container_shortage': 969636, 'operation_number': 146855}
# average env summary (episode 69): {'order_requirements': 1000000.0, 'container_shortage': 969636.0, 'operation_number': 146855.0}
#
# Collecting result:
# env summary (episode 70): {'order_requirements': 1000000, 'container_shortage': 970617, 'operation_number': 126784}
# average env summary (episode 70): {'order_requirements': 1000000.0, 'container_shortage': 970617.0, 'operation_number': 126784.0}
#
# Evaluation result:
# env summary (episode 70): {'order_requirements': 1000000, 'container_shortage': 662181, 'operation_number': 588593}
# average env summary (episode 70): {'order_requirements': 1000000.0, 'container_shortage': 662181.0, 'operation_number': 588593.0}
#
# Collecting result:
# env summary (episode 71): {'order_requirements': 1000000, 'container_shortage': 961385, 'operation_number': 146449}
# average env summary (episode 71): {'order_requirements': 1000000.0, 'container_shortage': 961385.0, 'operation_number': 146449.0}
#
# Collecting result:
# env summary (episode 72): {'order_requirements': 1000000, 'container_shortage': 968355, 'operation_number': 152469}
# average env summary (episode 72): {'order_requirements': 1000000.0, 'container_shortage': 968355.0, 'operation_number': 152469.0}
#
# Collecting result:
# env summary (episode 73): {'order_requirements': 1000000, 'container_shortage': 955980, 'operation_number': 382034}
# average env summary (episode 73): {'order_requirements': 1000000.0, 'container_shortage': 955980.0, 'operation_number': 382034.0}
#
# Collecting result:
# env summary (episode 74): {'order_requirements': 1000000, 'container_shortage': 412584, 'operation_number': 1260503}
# average env summary (episode 74): {'order_requirements': 1000000.0, 'container_shortage': 412584.0, 'operation_number': 1260503.0}
#
# Collecting result:
# env summary (episode 75): {'order_requirements': 1000000, 'container_shortage': 668912, 'operation_number': 896484}
# average env summary (episode 75): {'order_requirements': 1000000.0, 'container_shortage': 668912.0, 'operation_number': 896484.0}
#
# Evaluation result:
# env summary (episode 75): {'order_requirements': 1000000, 'container_shortage': 653466, 'operation_number': 582730}
# average env summary (episode 75): {'order_requirements': 1000000.0, 'container_shortage': 653466.0, 'operation_number': 582730.0}
#
# Collecting result:
# env summary (episode 76): {'order_requirements': 1000000, 'container_shortage': 548033, 'operation_number': 1410275}
# average env summary (episode 76): {'order_requirements': 1000000.0, 'container_shortage': 548033.0, 'operation_number': 1410275.0}
#
# Collecting result:
# env summary (episode 77): {'order_requirements': 1000000, 'container_shortage': 622993, 'operation_number': 1239394}
# average env summary (episode 77): {'order_requirements': 1000000.0, 'container_shortage': 622993.0, 'operation_number': 1239394.0}
#
# Collecting result:
# env summary (episode 78): {'order_requirements': 1000000, 'container_shortage': 623522, 'operation_number': 1171596}
# average env summary (episode 78): {'order_requirements': 1000000.0, 'container_shortage': 623522.0, 'operation_number': 1171596.0}
#
# Collecting result:
# env summary (episode 79): {'order_requirements': 1000000, 'container_shortage': 880877, 'operation_number': 409879}
# average env summary (episode 79): {'order_requirements': 1000000.0, 'container_shortage': 880877.0, 'operation_number': 409879.0}
#
# Collecting result:
# env summary (episode 80): {'order_requirements': 1000000, 'container_shortage': 581529, 'operation_number': 1370304}
# average env summary (episode 80): {'order_requirements': 1000000.0, 'container_shortage': 581529.0, 'operation_number': 1370304.0}
#
# Evaluation result:
# env summary (episode 80): {'order_requirements': 1000000, 'container_shortage': 878467, 'operation_number': 205917}
# average env summary (episode 80): {'order_requirements': 1000000.0, 'container_shortage': 878467.0, 'operation_number': 205917.0}
#
# Collecting result:
# env summary (episode 81): {'order_requirements': 1000000, 'container_shortage': 966757, 'operation_number': 91737}
# average env summary (episode 81): {'order_requirements': 1000000.0, 'container_shortage': 966757.0, 'operation_number': 91737.0}
#
# Collecting result:
# env summary (episode 82): {'order_requirements': 1000000, 'container_shortage': 685500, 'operation_number': 1075046}
# average env summary (episode 82): {'order_requirements': 1000000.0, 'container_shortage': 685500.0, 'operation_number': 1075046.0}
#
# Collecting result:
# env summary (episode 83): {'order_requirements': 1000000, 'container_shortage': 653568, 'operation_number': 795047}
# average env summary (episode 83): {'order_requirements': 1000000.0, 'container_shortage': 653568.0, 'operation_number': 795047.0}
#
# Collecting result:
# env summary (episode 84): {'order_requirements': 1000000, 'container_shortage': 972361, 'operation_number': 142833}
# average env summary (episode 84): {'order_requirements': 1000000.0, 'container_shortage': 972361.0, 'operation_number': 142833.0}
#
# Collecting result:
# env summary (episode 85): {'order_requirements': 1000000, 'container_shortage': 661713, 'operation_number': 810658}
# average env summary (episode 85): {'order_requirements': 1000000.0, 'container_shortage': 661713.0, 'operation_number': 810658.0}
#
# Evaluation result:
# env summary (episode 85): {'order_requirements': 1000000, 'container_shortage': 630351, 'operation_number': 615193}
# average env summary (episode 85): {'order_requirements': 1000000.0, 'container_shortage': 630351.0, 'operation_number': 615193.0}
#
# Collecting result:
# env summary (episode 86): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 161471}
# average env summary (episode 86): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 161471.0}
#
# Collecting result:
# env summary (episode 87): {'order_requirements': 1000000, 'container_shortage': 871957, 'operation_number': 382867}
# average env summary (episode 87): {'order_requirements': 1000000.0, 'container_shortage': 871957.0, 'operation_number': 382867.0}
#
# Collecting result:
# env summary (episode 88): {'order_requirements': 1000000, 'container_shortage': 660997, 'operation_number': 863518}
# average env summary (episode 88): {'order_requirements': 1000000.0, 'container_shortage': 660997.0, 'operation_number': 863518.0}
#
# Collecting result:
# env summary (episode 89): {'order_requirements': 1000000, 'container_shortage': 968262, 'operation_number': 228018}
# average env summary (episode 89): {'order_requirements': 1000000.0, 'container_shortage': 968262.0, 'operation_number': 228018.0}
#
# Collecting result:
# env summary (episode 90): {'order_requirements': 1000000, 'container_shortage': 661220, 'operation_number': 861835}
# average env summary (episode 90): {'order_requirements': 1000000.0, 'container_shortage': 661220.0, 'operation_number': 861835.0}
#
# Evaluation result:
# env summary (episode 90): {'order_requirements': 1000000, 'container_shortage': 617786, 'operation_number': 745232}
# average env summary (episode 90): {'order_requirements': 1000000.0, 'container_shortage': 617786.0, 'operation_number': 745232.0}
#
# Collecting result:
# env summary (episode 91): {'order_requirements': 1000000, 'container_shortage': 660821, 'operation_number': 854977}
# average env summary (episode 91): {'order_requirements': 1000000.0, 'container_shortage': 660821.0, 'operation_number': 854977.0}
#
# Collecting result:
# env summary (episode 92): {'order_requirements': 1000000, 'container_shortage': 944331, 'operation_number': 162622}
# average env summary (episode 92): {'order_requirements': 1000000.0, 'container_shortage': 944331.0, 'operation_number': 162622.0}
#
# Collecting result:
# env summary (episode 93): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 227102}
# average env summary (episode 93): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 227102.0}
#
# Collecting result:
# env summary (episode 94): {'order_requirements': 1000000, 'container_shortage': 965568, 'operation_number': 425530}
# average env summary (episode 94): {'order_requirements': 1000000.0, 'container_shortage': 965568.0, 'operation_number': 425530.0}
#
# Collecting result:
# env summary (episode 95): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 220690}
# average env summary (episode 95): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 220690.0}
#
# Evaluation result:
# env summary (episode 95): {'order_requirements': 1000000, 'container_shortage': 888335, 'operation_number': 242587}
# average env summary (episode 95): {'order_requirements': 1000000.0, 'container_shortage': 888335.0, 'operation_number': 242587.0}
#
# Collecting result:
# env summary (episode 96): {'order_requirements': 1000000, 'container_shortage': 702509, 'operation_number': 865389}
# average env summary (episode 96): {'order_requirements': 1000000.0, 'container_shortage': 702509.0, 'operation_number': 865389.0}
#
# Collecting result:
# env summary (episode 97): {'order_requirements': 1000000, 'container_shortage': 976668, 'operation_number': 167322}
# average env summary (episode 97): {'order_requirements': 1000000.0, 'container_shortage': 976668.0, 'operation_number': 167322.0}
#
# Collecting result:
# env summary (episode 98): {'order_requirements': 1000000, 'container_shortage': 965568, 'operation_number': 239329}
# average env summary (episode 98): {'order_requirements': 1000000.0, 'container_shortage': 965568.0, 'operation_number': 239329.0}
#
# Collecting result:
# env summary (episode 99): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 194190}
# average env summary (episode 99): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 194190.0}
#
# Collecting result:
# env summary (episode 100): {'order_requirements': 1000000, 'container_shortage': 973501, 'operation_number': 255115}
# average env summary (episode 100): {'order_requirements': 1000000.0, 'container_shortage': 973501.0, 'operation_number': 255115.0}
#
# Evaluation result:
# env summary (episode 100): {'order_requirements': 1000000, 'container_shortage': 743565, 'operation_number': 662437}
# average env summary (episode 100): {'order_requirements': 1000000.0, 'container_shortage': 743565.0, 'operation_number': 662437.0}
#
# Collecting result:
# env summary (episode 101): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 486054}
# average env summary (episode 101): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 486054.0}
#
# Collecting result:
# env summary (episode 102): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 177258}
# average env summary (episode 102): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 177258.0}
#
# Collecting result:
# env summary (episode 103): {'order_requirements': 1000000, 'container_shortage': 972429, 'operation_number': 193772}
# average env summary (episode 103): {'order_requirements': 1000000.0, 'container_shortage': 972429.0, 'operation_number': 193772.0}
#
# Collecting result:
# env summary (episode 104): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 201156}
# average env summary (episode 104): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 201156.0}
#
# Collecting result:
# env summary (episode 105): {'order_requirements': 1000000, 'container_shortage': 970592, 'operation_number': 185214}
# average env summary (episode 105): {'order_requirements': 1000000.0, 'container_shortage': 970592.0, 'operation_number': 185214.0}
#
# Evaluation result:
# env summary (episode 105): {'order_requirements': 1000000, 'container_shortage': 694949, 'operation_number': 616785}
# average env summary (episode 105): {'order_requirements': 1000000.0, 'container_shortage': 694949.0, 'operation_number': 616785.0}
#
# Collecting result:
# env summary (episode 106): {'order_requirements': 1000000, 'container_shortage': 659280, 'operation_number': 819840}
# average env summary (episode 106): {'order_requirements': 1000000.0, 'container_shortage': 659280.0, 'operation_number': 819840.0}
#
# Collecting result:
# env summary (episode 107): {'order_requirements': 1000000, 'container_shortage': 947803, 'operation_number': 767976}
# average env summary (episode 107): {'order_requirements': 1000000.0, 'container_shortage': 947803.0, 'operation_number': 767976.0}
#
# Collecting result:
# env summary (episode 108): {'order_requirements': 1000000, 'container_shortage': 960138, 'operation_number': 416917}
# average env summary (episode 108): {'order_requirements': 1000000.0, 'container_shortage': 960138.0, 'operation_number': 416917.0}
#
# Collecting result:
# env summary (episode 109): {'order_requirements': 1000000, 'container_shortage': 976126, 'operation_number': 184224}
# average env summary (episode 109): {'order_requirements': 1000000.0, 'container_shortage': 976126.0, 'operation_number': 184224.0}
#
# Collecting result:
# env summary (episode 110): {'order_requirements': 1000000, 'container_shortage': 392216, 'operation_number': 1277056}
# average env summary (episode 110): {'order_requirements': 1000000.0, 'container_shortage': 392216.0, 'operation_number': 1277056.0}
#
# Evaluation result:
# env summary (episode 110): {'order_requirements': 1000000, 'container_shortage': 623192, 'operation_number': 723100}
# average env summary (episode 110): {'order_requirements': 1000000.0, 'container_shortage': 623192.0, 'operation_number': 723100.0}
#
# Collecting result:
# env summary (episode 111): {'order_requirements': 1000000, 'container_shortage': 977563, 'operation_number': 348330}
# average env summary (episode 111): {'order_requirements': 1000000.0, 'container_shortage': 977563.0, 'operation_number': 348330.0}
#
# Collecting result:
# env summary (episode 112): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 123289}
# average env summary (episode 112): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 123289.0}
#
# Collecting result:
# env summary (episode 113): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 128289}
# average env summary (episode 113): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 128289.0}
#
# Collecting result:
# env summary (episode 114): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 123289}
# average env summary (episode 114): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 123289.0}
#
# Collecting result:
# env summary (episode 115): {'order_requirements': 1000000, 'container_shortage': 974411, 'operation_number': 132789}
# average env summary (episode 115): {'order_requirements': 1000000.0, 'container_shortage': 974411.0, 'operation_number': 132789.0}
#
# Evaluation result:
# env summary (episode 115): {'order_requirements': 1000000, 'container_shortage': 940578, 'operation_number': 41818}
# average env summary (episode 115): {'order_requirements': 1000000.0, 'container_shortage': 940578.0, 'operation_number': 41818.0}
#
# Collecting result:
# env summary (episode 116): {'order_requirements': 1000000, 'container_shortage': 975483, 'operation_number': 123289}
# average env summary (episode 116): {'order_requirements': 1000000.0, 'container_shortage': 975483.0, 'operation_number': 123289.0}
#
# Collecting result:
# env summary (episode 117): {'order_requirements': 1000000, 'container_shortage': 977455, 'operation_number': 123291}
# average env summary (episode 117): {'order_requirements': 1000000.0, 'container_shortage': 977455.0, 'operation_number': 123291.0}
#
# Collecting result:
# env summary (episode 118): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 132789}
# average env summary (episode 118): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 132789.0}
#
# Collecting result:
# env summary (episode 119): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 186207}
# average env summary (episode 119): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 186207.0}
#
# Collecting result:
# env summary (episode 120): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 123289}
# average env summary (episode 120): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 123289.0}
#
# Evaluation result:
# env summary (episode 120): {'order_requirements': 1000000, 'container_shortage': 916937, 'operation_number': 140916}
# average env summary (episode 120): {'order_requirements': 1000000.0, 'container_shortage': 916937.0, 'operation_number': 140916.0}
#
# Collecting result:
# env summary (episode 121): {'order_requirements': 1000000, 'container_shortage': 977372, 'operation_number': 123289}
# average env summary (episode 121): {'order_requirements': 1000000.0, 'container_shortage': 977372.0, 'operation_number': 123289.0}
#
# Collecting result:
# env summary (episode 122): {'order_requirements': 1000000, 'container_shortage': 975226, 'operation_number': 123289}
# average env summary (episode 122): {'order_requirements': 1000000.0, 'container_shortage': 975226.0, 'operation_number': 123289.0}
#
# Collecting result:
# env summary (episode 123): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 1353076}
# average env summary (episode 123): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 1353076.0}
#
# Collecting result:
# env summary (episode 124): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 113791}
# average env summary (episode 124): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 113791.0}
#
# Collecting result:
# env summary (episode 125): {'order_requirements': 1000000, 'container_shortage': 978073, 'operation_number': 111425}
# average env summary (episode 125): {'order_requirements': 1000000.0, 'container_shortage': 978073.0, 'operation_number': 111425.0}
#
# Evaluation result:
# env summary (episode 125): {'order_requirements': 1000000, 'container_shortage': 926237, 'operation_number': 129482}
# average env summary (episode 125): {'order_requirements': 1000000.0, 'container_shortage': 926237.0, 'operation_number': 129482.0}
#
# Collecting result:
# env summary (episode 126): {'order_requirements': 1000000, 'container_shortage': 977583, 'operation_number': 123291}
# average env summary (episode 126): {'order_requirements': 1000000.0, 'container_shortage': 977583.0, 'operation_number': 123291.0}
#
# Collecting result:
# env summary (episode 127): {'order_requirements': 1000000, 'container_shortage': 975376, 'operation_number': 123291}
# average env summary (episode 127): {'order_requirements': 1000000.0, 'container_shortage': 975376.0, 'operation_number': 123291.0}
#
# Collecting result:
# env summary (episode 128): {'order_requirements': 1000000, 'container_shortage': 973986, 'operation_number': 123291}
# average env summary (episode 128): {'order_requirements': 1000000.0, 'container_shortage': 973986.0, 'operation_number': 123291.0}
#
# Collecting result:
# env summary (episode 129): {'order_requirements': 1000000, 'container_shortage': 849280, 'operation_number': 1503402}
# average env summary (episode 129): {'order_requirements': 1000000.0, 'container_shortage': 849280.0, 'operation_number': 1503402.0}
#
# Collecting result:
# env summary (episode 130): {'order_requirements': 1000000, 'container_shortage': 941913, 'operation_number': 1595937}
# average env summary (episode 130): {'order_requirements': 1000000.0, 'container_shortage': 941913.0, 'operation_number': 1595937.0}
#
# Evaluation result:
# env summary (episode 130): {'order_requirements': 1000000, 'container_shortage': 878444, 'operation_number': 269592}
# average env summary (episode 130): {'order_requirements': 1000000.0, 'container_shortage': 878444.0, 'operation_number': 269592.0}
#
# Collecting result:
# env summary (episode 131): {'order_requirements': 1000000, 'container_shortage': 975452, 'operation_number': 123289}
# average env summary (episode 131): {'order_requirements': 1000000.0, 'container_shortage': 975452.0, 'operation_number': 123289.0}
#
# Collecting result:
# env summary (episode 132): {'order_requirements': 1000000, 'container_shortage': 974132, 'operation_number': 138289}
# average env summary (episode 132): {'order_requirements': 1000000.0, 'container_shortage': 974132.0, 'operation_number': 138289.0}
#
# Collecting result:
# env summary (episode 133): {'order_requirements': 1000000, 'container_shortage': 973131, 'operation_number': 123274}
# average env summary (episode 133): {'order_requirements': 1000000.0, 'container_shortage': 973131.0, 'operation_number': 123274.0}
#
# Collecting result:
# env summary (episode 134): {'order_requirements': 1000000, 'container_shortage': 974427, 'operation_number': 123279}
# average env summary (episode 134): {'order_requirements': 1000000.0, 'container_shortage': 974427.0, 'operation_number': 123279.0}
#
# Collecting result:
# env summary (episode 135): {'order_requirements': 1000000, 'container_shortage': 974427, 'operation_number': 123279}
# average env summary (episode 135): {'order_requirements': 1000000.0, 'container_shortage': 974427.0, 'operation_number': 123279.0}
#
# Evaluation result:
# env summary (episode 135): {'order_requirements': 1000000, 'container_shortage': 909208, 'operation_number': 166705}
# average env summary (episode 135): {'order_requirements': 1000000.0, 'container_shortage': 909208.0, 'operation_number': 166705.0}
#
# Collecting result:
# env summary (episode 136): {'order_requirements': 1000000, 'container_shortage': 970894, 'operation_number': 120599}
# average env summary (episode 136): {'order_requirements': 1000000.0, 'container_shortage': 970894.0, 'operation_number': 120599.0}
#
# Collecting result:
# env summary (episode 137): {'order_requirements': 1000000, 'container_shortage': 975617, 'operation_number': 123291}
# average env summary (episode 137): {'order_requirements': 1000000.0, 'container_shortage': 975617.0, 'operation_number': 123291.0}
#
# Collecting result:
# env summary (episode 138): {'order_requirements': 1000000, 'container_shortage': 973700, 'operation_number': 76144}
# average env summary (episode 138): {'order_requirements': 1000000.0, 'container_shortage': 973700.0, 'operation_number': 76144.0}
#
# Collecting result:
# env summary (episode 139): {'order_requirements': 1000000, 'container_shortage': 973687, 'operation_number': 123296}
# average env summary (episode 139): {'order_requirements': 1000000.0, 'container_shortage': 973687.0, 'operation_number': 123296.0}
#
# Collecting result:
# env summary (episode 140): {'order_requirements': 1000000, 'container_shortage': 976893, 'operation_number': 76146}
# average env summary (episode 140): {'order_requirements': 1000000.0, 'container_shortage': 976893.0, 'operation_number': 76146.0}
#
# Evaluation result:
# env summary (episode 140): {'order_requirements': 1000000, 'container_shortage': 893470, 'operation_number': 186978}
# average env summary (episode 140): {'order_requirements': 1000000.0, 'container_shortage': 893470.0, 'operation_number': 186978.0}
#
# Collecting result:
# env summary (episode 141): {'order_requirements': 1000000, 'container_shortage': 977000, 'operation_number': 174184}
# average env summary (episode 141): {'order_requirements': 1000000.0, 'container_shortage': 977000.0, 'operation_number': 174184.0}
#
# Collecting result:
# env summary (episode 142): {'order_requirements': 1000000, 'container_shortage': 974204, 'operation_number': 120230}
# average env summary (episode 142): {'order_requirements': 1000000.0, 'container_shortage': 974204.0, 'operation_number': 120230.0}
#
# Collecting result:
# env summary (episode 143): {'order_requirements': 1000000, 'container_shortage': 977738, 'operation_number': 170650}
# average env summary (episode 143): {'order_requirements': 1000000.0, 'container_shortage': 977738.0, 'operation_number': 170650.0}
#
# Collecting result:
# env summary (episode 144): {'order_requirements': 1000000, 'container_shortage': 977000, 'operation_number': 81146}
# average env summary (episode 144): {'order_requirements': 1000000.0, 'container_shortage': 977000.0, 'operation_number': 81146.0}
#
# Collecting result:
# env summary (episode 145): {'order_requirements': 1000000, 'container_shortage': 974455, 'operation_number': 123296}
# average env summary (episode 145): {'order_requirements': 1000000.0, 'container_shortage': 974455.0, 'operation_number': 123296.0}
#
# Evaluation result:
# env summary (episode 145): {'order_requirements': 1000000, 'container_shortage': 897890, 'operation_number': 182500}
# average env summary (episode 145): {'order_requirements': 1000000.0, 'container_shortage': 897890.0, 'operation_number': 182500.0}
#
# Collecting result:
# env summary (episode 146): {'order_requirements': 1000000, 'container_shortage': 968743, 'operation_number': 120616}
# average env summary (episode 146): {'order_requirements': 1000000.0, 'container_shortage': 968743.0, 'operation_number': 120616.0}
#
# Collecting result:
# env summary (episode 147): {'order_requirements': 1000000, 'container_shortage': 961300, 'operation_number': 247383}
# average env summary (episode 147): {'order_requirements': 1000000.0, 'container_shortage': 961300.0, 'operation_number': 247383.0}
#
# Collecting result:
# env summary (episode 148): {'order_requirements': 1000000, 'container_shortage': 969569, 'operation_number': 130081}
# average env summary (episode 148): {'order_requirements': 1000000.0, 'container_shortage': 969569.0, 'operation_number': 130081.0}
#
# Collecting result:
# env summary (episode 149): {'order_requirements': 1000000, 'container_shortage': 971360, 'operation_number': 166050}
# average env summary (episode 149): {'order_requirements': 1000000.0, 'container_shortage': 971360.0, 'operation_number': 166050.0}
#
# Collecting result:
# env summary (episode 150): {'order_requirements': 1000000, 'container_shortage': 973233, 'operation_number': 132791}
# average env summary (episode 150): {'order_requirements': 1000000.0, 'container_shortage': 973233.0, 'operation_number': 132791.0}
#
# Evaluation result:
# env summary (episode 150): {'order_requirements': 1000000, 'container_shortage': 826864, 'operation_number': 322283}
# average env summary (episode 150): {'order_requirements': 1000000.0, 'container_shortage': 826864.0, 'operation_number': 322283.0}
#
# Collecting result:
# ...
# average env summary (episode 384): {'order_requirements': 1000000.0, 'container_shortage': 977744.0, 'operation_number': 374656.0}
#
# Collecting result:
# env summary (episode 385): {'order_requirements': 1000000, 'container_shortage': 967748, 'operation_number': 349986}
# average env summary (episode 385): {'order_requirements': 1000000.0, 'container_shortage': 967748.0, 'operation_number': 349986.0}
#
# Evaluation result:
# env summary (episode 385): {'order_requirements': 1000000, 'container_shortage': 811898, 'operation_number': 382085}
# average env summary (episode 385): {'order_requirements': 1000000.0, 'container_shortage': 811898.0, 'operation_number': 382085.0}
#
# Collecting result:
# env summary (episode 386): {'order_requirements': 1000000, 'container_shortage': 977744, 'operation_number': 685672}
# average env summary (episode 386): {'order_requirements': 1000000.0, 'container_shortage': 977744.0, 'operation_number': 685672.0}
#
# Collecting result:
# env summary (episode 387): {'order_requirements': 1000000, 'container_shortage': 950076, 'operation_number': 603171}
# average env summary (episode 387): {'order_requirements': 1000000.0, 'container_shortage': 950076.0, 'operation_number': 603171.0}
#
# Collecting result:
# env summary (episode 388): {'order_requirements': 1000000, 'container_shortage': 974769, 'operation_number': 629970}
# average env summary (episode 388): {'order_requirements': 1000000.0, 'container_shortage': 974769.0, 'operation_number': 629970.0}
#
# Collecting result:
# env summary (episode 389): {'order_requirements': 1000000, 'container_shortage': 975096, 'operation_number': 532178}
# average env summary (episode 389): {'order_requirements': 1000000.0, 'container_shortage': 975096.0, 'operation_number': 532178.0}
#
# Collecting result:
# env summary (episode 390): {'order_requirements': 1000000, 'container_shortage': 966374, 'operation_number': 535929}
# average env summary (episode 390): {'order_requirements': 1000000.0, 'container_shortage': 966374.0, 'operation_number': 535929.0}
#
# Evaluation result:
# env summary (episode 390): {'order_requirements': 1000000, 'container_shortage': 870928, 'operation_number': 337724}
# average env summary (episode 390): {'order_requirements': 1000000.0, 'container_shortage': 870928.0, 'operation_number': 337724.0}
#
# Collecting result:
# env summary (episode 391): {'order_requirements': 1000000, 'container_shortage': 963726, 'operation_number': 473086}
# average env summary (episode 391): {'order_requirements': 1000000.0, 'container_shortage': 963726.0, 'operation_number': 473086.0}
#
# Collecting result:
# env summary (episode 392): {'order_requirements': 1000000, 'container_shortage': 979716, 'operation_number': 99998}
# average env summary (episode 392): {'order_requirements': 1000000.0, 'container_shortage': 979716.0, 'operation_number': 99998.0}
#
# Collecting result:
# env summary (episode 393): {'order_requirements': 1000000, 'container_shortage': 975096, 'operation_number': 99998}
# average env summary (episode 393): {'order_requirements': 1000000.0, 'container_shortage': 975096.0, 'operation_number': 99998.0}
#
# Collecting result:
# env summary (episode 394): {'order_requirements': 1000000, 'container_shortage': 730016, 'operation_number': 567552}
# average env summary (episode 394): {'order_requirements': 1000000.0, 'container_shortage': 730016.0, 'operation_number': 567552.0}
#
# Collecting result:
# env summary (episode 395): {'order_requirements': 1000000, 'container_shortage': 977744, 'operation_number': 99999}
# average env summary (episode 395): {'order_requirements': 1000000.0, 'container_shortage': 977744.0, 'operation_number': 99999.0}
#
# Evaluation result:
# env summary (episode 395): {'order_requirements': 1000000, 'container_shortage': 955860, 'operation_number': 92253}
# average env summary (episode 395): {'order_requirements': 1000000.0, 'container_shortage': 955860.0, 'operation_number': 92253.0}
#
# Collecting result:
# env summary (episode 396): {'order_requirements': 1000000, 'container_shortage': 977744, 'operation_number': 135491}
# average env summary (episode 396): {'order_requirements': 1000000.0, 'container_shortage': 977744.0, 'operation_number': 135491.0}
#
# Collecting result:
# env summary (episode 397): {'order_requirements': 1000000, 'container_shortage': 977744, 'operation_number': 1115169}
# average env summary (episode 397): {'order_requirements': 1000000.0, 'container_shortage': 977744.0, 'operation_number': 1115169.0}
#
# Collecting result:
# env summary (episode 398): {'order_requirements': 1000000, 'container_shortage': 977744, 'operation_number': 950709}
# average env summary (episode 398): {'order_requirements': 1000000.0, 'container_shortage': 977744.0, 'operation_number': 950709.0}
#
# Collecting result:
# env summary (episode 399): {'order_requirements': 1000000, 'container_shortage': 904556, 'operation_number': 615424}
# average env summary (episode 399): {'order_requirements': 1000000.0, 'container_shortage': 904556.0, 'operation_number': 615424.0}
#
# Collecting result:
# env summary (episode 400): {'order_requirements': 1000000, 'container_shortage': 516937, 'operation_number': 1495032}
# average env summary (episode 400): {'order_requirements': 1000000.0, 'container_shortage': 516937.0, 'operation_number': 1495032.0}
#
# Evaluation result:
# env summary (episode 400): {'order_requirements': 1000000, 'container_shortage': 887721, 'operation_number': 233070}
# average env summary (episode 400): {'order_requirements': 1000000.0, 'container_shortage': 887721.0, 'operation_number': 233070.0}
#
# Collecting result:
# env summary (episode 401): {'order_requirements': 1000000, 'container_shortage': 603037, 'operation_number': 1242433}
# average env summary (episode 401): {'order_requirements': 1000000.0, 'container_shortage': 603037.0, 'operation_number': 1242433.0}
#
# Collecting result:
# env summary (episode 402): {'order_requirements': 1000000, 'container_shortage': 700993, 'operation_number': 1142420}
# average env summary (episode 402): {'order_requirements': 1000000.0, 'container_shortage': 700993.0, 'operation_number': 1142420.0}
#
# Collecting result:
# env summary (episode 403): {'order_requirements': 1000000, 'container_shortage': 605281, 'operation_number': 1244800}
# average env summary (episode 403): {'order_requirements': 1000000.0, 'container_shortage': 605281.0, 'operation_number': 1244800.0}
#
# Collecting result:
# env summary (episode 404): {'order_requirements': 1000000, 'container_shortage': 877744, 'operation_number': 303958}
# average env summary (episode 404): {'order_requirements': 1000000.0, 'container_shortage': 877744.0, 'operation_number': 303958.0}
#
# Collecting result:
# env summary (episode 405): {'order_requirements': 1000000, 'container_shortage': 977744, 'operation_number': 690556}
# average env summary (episode 405): {'order_requirements': 1000000.0, 'container_shortage': 977744.0, 'operation_number': 690556.0}
#
# Evaluation result:
# env summary (episode 405): {'order_requirements': 1000000, 'container_shortage': 916218, 'operation_number': 228128}
# average env summary (episode 405): {'order_requirements': 1000000.0, 'container_shortage': 916218.0, 'operation_number': 228128.0}
#
# Collecting result:
# env summary (episode 406): {'order_requirements': 1000000, 'container_shortage': 785284, 'operation_number': 887833}
# average env summary (episode 406): {'order_requirements': 1000000.0, 'container_shortage': 785284.0, 'operation_number': 887833.0}
#
# Collecting result:
# env summary (episode 407): {'order_requirements': 1000000, 'container_shortage': 337557, 'operation_number': 1385125}
# average env summary (episode 407): {'order_requirements': 1000000.0, 'container_shortage': 337557.0, 'operation_number': 1385125.0}
#
# Collecting result:
# env summary (episode 408): {'order_requirements': 1000000, 'container_shortage': 903399, 'operation_number': 258376}
# average env summary (episode 408): {'order_requirements': 1000000.0, 'container_shortage': 903399.0, 'operation_number': 258376.0}
#
# Collecting result:
# env summary (episode 409): {'order_requirements': 1000000, 'container_shortage': 939632, 'operation_number': 228820}
# average env summary (episode 409): {'order_requirements': 1000000.0, 'container_shortage': 939632.0, 'operation_number': 228820.0}
#
# Collecting result:
# env summary (episode 410): {'order_requirements': 1000000, 'container_shortage': 903026, 'operation_number': 201880}
# average env summary (episode 410): {'order_requirements': 1000000.0, 'container_shortage': 903026.0, 'operation_number': 201880.0}
#
# Evaluation result:
# env summary (episode 410): {'order_requirements': 1000000, 'container_shortage': 949847, 'operation_number': 102403}
# average env summary (episode 410): {'order_requirements': 1000000.0, 'container_shortage': 949847.0, 'operation_number': 102403.0}
#
# Collecting result:
# env summary (episode 411): {'order_requirements': 1000000, 'container_shortage': 977744, 'operation_number': 146852}
# average env summary (episode 411): {'order_requirements': 1000000.0, 'container_shortage': 977744.0, 'operation_number': 146852.0}
#
# Collecting result:
# env summary (episode 412): {'order_requirements': 1000000, 'container_shortage': 911554, 'operation_number': 225501}
# average env summary (episode 412): {'order_requirements': 1000000.0, 'container_shortage': 911554.0, 'operation_number': 225501.0}
#
# Collecting result:
# env summary (episode 413): {'order_requirements': 1000000, 'container_shortage': 896091, 'operation_number': 252286}
# average env summary (episode 413): {'order_requirements': 1000000.0, 'container_shortage': 896091.0, 'operation_number': 252286.0}
#
# Collecting result:
# env summary (episode 414): {'order_requirements': 1000000, 'container_shortage': 907298, 'operation_number': 226436}
# average env summary (episode 414): {'order_requirements': 1000000.0, 'container_shortage': 907298.0, 'operation_number': 226436.0}
#
# Collecting result:
# env summary (episode 415): {'order_requirements': 1000000, 'container_shortage': 933526, 'operation_number': 185666}
# average env summary (episode 415): {'order_requirements': 1000000.0, 'container_shortage': 933526.0, 'operation_number': 185666.0}
#
# Evaluation result:
# env summary (episode 415): {'order_requirements': 1000000, 'container_shortage': 821131, 'operation_number': 311080}
# average env summary (episode 415): {'order_requirements': 1000000.0, 'container_shortage': 821131.0, 'operation_number': 311080.0}
#
# Collecting result:
# env summary (episode 416): {'order_requirements': 1000000, 'container_shortage': 883709, 'operation_number': 257020}
# average env summary (episode 416): {'order_requirements': 1000000.0, 'container_shortage': 883709.0, 'operation_number': 257020.0}
#
# Collecting result:
# env summary (episode 417): {'order_requirements': 1000000, 'container_shortage': 936591, 'operation_number': 120115}
# average env summary (episode 417): {'order_requirements': 1000000.0, 'container_shortage': 936591.0, 'operation_number': 120115.0}
#
# Collecting result:
# env summary (episode 418): {'order_requirements': 1000000, 'container_shortage': 882491, 'operation_number': 248336}
# average env summary (episode 418): {'order_requirements': 1000000.0, 'container_shortage': 882491.0, 'operation_number': 248336.0}
#
# Collecting result:
# env summary (episode 419): {'order_requirements': 1000000, 'container_shortage': 854852, 'operation_number': 262677}
# average env summary (episode 419): {'order_requirements': 1000000.0, 'container_shortage': 854852.0, 'operation_number': 262677.0}
#
# Collecting result:
# env summary (episode 420): {'order_requirements': 1000000, 'container_shortage': 847057, 'operation_number': 236456}
# average env summary (episode 420): {'order_requirements': 1000000.0, 'container_shortage': 847057.0, 'operation_number': 236456.0}
#
# Evaluation result:
# env summary (episode 420): {'order_requirements': 1000000, 'container_shortage': 891996, 'operation_number': 175386}
# average env summary (episode 420): {'order_requirements': 1000000.0, 'container_shortage': 891996.0, 'operation_number': 175386.0}
#
# Collecting result:
# env summary (episode 421): {'order_requirements': 1000000, 'container_shortage': 842857, 'operation_number': 241914}
# average env summary (episode 421): {'order_requirements': 1000000.0, 'container_shortage': 842857.0, 'operation_number': 241914.0}
#
# Collecting result:
# env summary (episode 422): {'order_requirements': 1000000, 'container_shortage': 793918, 'operation_number': 351465}
# average env summary (episode 422): {'order_requirements': 1000000.0, 'container_shortage': 793918.0, 'operation_number': 351465.0}
#
# Collecting result:
# env summary (episode 423): {'order_requirements': 1000000, 'container_shortage': 907015, 'operation_number': 191897}
# average env summary (episode 423): {'order_requirements': 1000000.0, 'container_shortage': 907015.0, 'operation_number': 191897.0}
#
# Collecting result:
# env summary (episode 424): {'order_requirements': 1000000, 'container_shortage': 899531, 'operation_number': 230328}
# average env summary (episode 424): {'order_requirements': 1000000.0, 'container_shortage': 899531.0, 'operation_number': 230328.0}
#
# Collecting result:
# env summary (episode 425): {'order_requirements': 1000000, 'container_shortage': 915268, 'operation_number': 177519}
# average env summary (episode 425): {'order_requirements': 1000000.0, 'container_shortage': 915268.0, 'operation_number': 177519.0}
#
# Evaluation result:
# env summary (episode 425): {'order_requirements': 1000000, 'container_shortage': 881334, 'operation_number': 197247}
# average env summary (episode 425): {'order_requirements': 1000000.0, 'container_shortage': 881334.0, 'operation_number': 197247.0}
#
# Collecting result:
# env summary (episode 426): {'order_requirements': 1000000, 'container_shortage': 881783, 'operation_number': 194097}
# average env summary (episode 426): {'order_requirements': 1000000.0, 'container_shortage': 881783.0, 'operation_number': 194097.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\KARTHA~1\AppData\Local\Temp/ipykernel_29636/786919443.py in <module>
#       7 training_manager = TrainingManager(rl_component_bundle=rl_component_bundle)
#       8 for ep in range(1, num_episodes + 1):
# ----> 9     result = env_sampler.sample()
#      10     experiences: List[List[ExpElement]] = result["experiences"]
#      11     info_list: List[dict] = result["info"]
#
# ~\anaconda3\lib\site-packages\maro\rl\rollout\env_sampler.py in sample(self, policy_state, num_steps)
#     506
#     507                 # Update env and get new states (global & agent)
# --> 508                 self._step(list(env_action_dict.values()))
#     509                 cache_element.next_state = self._state
#     510
#
# ~\anaconda3\lib\site-packages\maro\rl\rollout\env_sampler.py in _step(self, actions)
#     391         _, self._event, self._end_of_episode = self.env.step(actions)
#     392         self._state, self._agent_state_dict = (
# --> 393             (None, {}) if self._end_of_episode else self._get_global_and_agent_state(self._event, self.env.tick)
#     394         )
#     395
#
# ~\anaconda3\lib\site-packages\maro\rl\rollout\env_sampler.py in _get_global_and_agent_state(self, event, tick)
#     340                 its state is a Numpy array. Otherwise, its state is a list of objects.
#     341         """
# --> 342         global_state, agent_state_dict = self._get_global_and_agent_state_impl(event, tick)
#     343         for agent_name, state in agent_state_dict.items():
#     344             policy_name = self._agent2policy[agent_name]
#
# C:\Users\KARTHA~1\AppData\Local\Temp/ipykernel_29636/4157593818.py in _get_global_and_agent_state_impl(self, event, tick)
#      12         state = np.concatenate(
#      13             [
# ---> 14                 port_snapshots[ticks : [port_idx] + list(future_port_list) : port_attributes],
#      15                 vessel_snapshots[tick:vessel_idx:vessel_attributes],
#      16             ],
#
# KeyboardInterrupt:
