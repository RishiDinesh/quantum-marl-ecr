# %%
# Import necessary packages
from typing import Any, Dict, List, Tuple, Union

import numpy as np
import torch
from torch.optim import Adam, RMSprop

from maro.rl.model import DiscreteACBasedNet, FullyConnected, VNet
from maro.rl.policy import DiscretePolicyGradient
from maro.rl.rl_component.rl_component_bundle import RLComponentBundle
from maro.rl.rollout import AbsEnvSampler, CacheElement, ExpElement
from maro.rl.training import TrainingManager
from maro.rl.training.algorithms import PPOParams, PPOTrainer
from maro.simulator import Env
from maro.simulator.scenarios.cim.common import Action, ActionType, DecisionEvent

# %%
# env and shaping config
reward_shaping_conf = {
    "time_window": 99,
    "fulfillment_factor": 1.0,
    "shortage_factor": 1.0,
    "time_decay": 0.97,
}
state_shaping_conf = {
    "look_back": 7,
    "max_ports_downstream": 2,
}
port_attributes = ["empty", "full", "on_shipper", "on_consignee", "booking", "shortage", "fulfillment"]
vessel_attributes = ["empty", "full", "remaining_space"]
action_shaping_conf = {
    "action_space": [(i - 10) / 10 for i in range(21)],
    "finite_vessel_space": True,
    "has_early_discharge": True,
}

# %%
class CIM_ACSampler(AbsEnvSampler):
    def _get_global_and_agent_state_impl(
        self,
        event: DecisionEvent,
        tick: int = None,
    ) -> Tuple[Union[None, np.ndarray, List[object]], Dict[Any, Union[np.ndarray, List[object]]]]:
        tick = self._env.tick
        vessel_snapshots, port_snapshots = self._env.snapshot_list["vessels"], self._env.snapshot_list["ports"]
        port_idx, vessel_idx = event.port_idx, event.vessel_idx
        ticks = [max(0, tick - rt) for rt in range(state_shaping_conf["look_back"] - 1)]
        future_port_list = vessel_snapshots[tick:vessel_idx:"future_stop_list"].astype("int")
        state = np.concatenate(
            [
                port_snapshots[ticks : [port_idx] + list(future_port_list) : port_attributes],
                vessel_snapshots[tick:vessel_idx:vessel_attributes],
            ],
        )
        return state, {port_idx: state}

    def _translate_to_env_action(
        self,
        action_dict: Dict[Any, Union[np.ndarray, List[object]]],
        event: DecisionEvent,
    ) -> Dict[Any, object]:
        action_space = action_shaping_conf["action_space"]
        finite_vsl_space = action_shaping_conf["finite_vessel_space"]
        has_early_discharge = action_shaping_conf["has_early_discharge"]

        port_idx, model_action = list(action_dict.items()).pop()

        vsl_idx, action_scope = event.vessel_idx, event.action_scope
        vsl_snapshots = self._env.snapshot_list["vessels"]
        vsl_space = vsl_snapshots[self._env.tick : vsl_idx : vessel_attributes][2] if finite_vsl_space else float("inf")

        percent = abs(action_space[model_action[0]])
        zero_action_idx = len(action_space) / 2  # index corresponding to value zero.
        if model_action < zero_action_idx:
            action_type = ActionType.LOAD
            actual_action = min(round(percent * action_scope.load), vsl_space)
        elif model_action > zero_action_idx:
            action_type = ActionType.DISCHARGE
            early_discharge = (
                vsl_snapshots[self._env.tick : vsl_idx : "early_discharge"][0] if has_early_discharge else 0
            )
            plan_action = percent * (action_scope.discharge + early_discharge) - early_discharge
            actual_action = round(plan_action) if plan_action > 0 else round(percent * action_scope.discharge)
        else:
            actual_action, action_type = 0, None

        return {port_idx: Action(vsl_idx, int(port_idx), actual_action, action_type)}

    def _get_reward(self, env_action_dict: Dict[Any, object], event: DecisionEvent, tick: int) -> Dict[Any, float]:
        start_tick = tick + 1
        ticks = list(range(start_tick, start_tick + reward_shaping_conf["time_window"]))

        # Get the ports that took actions at the given tick
        ports = [int(port) for port in list(env_action_dict.keys())]
        port_snapshots = self._env.snapshot_list["ports"]
        future_fulfillment = port_snapshots[ticks:ports:"fulfillment"].reshape(len(ticks), -1)
        future_shortage = port_snapshots[ticks:ports:"shortage"].reshape(len(ticks), -1)

        decay_list = [reward_shaping_conf["time_decay"] ** i for i in range(reward_shaping_conf["time_window"])]
        rewards = np.float32(
            reward_shaping_conf["fulfillment_factor"] * np.dot(future_fulfillment.T, decay_list)
            - reward_shaping_conf["shortage_factor"] * np.dot(future_shortage.T, decay_list),
        )
        return {agent_id: reward for agent_id, reward in zip(ports, rewards)}

    def _post_step(self, cache_element: CacheElement) -> None:
        self._info["env_metric"] = self._env.metrics

    def _post_eval_step(self, cache_element: CacheElement) -> None:
        self._post_step(cache_element)

    def post_collect(self, info_list: list, ep: int) -> None:
        # print the env metric from each rollout worker
        for info in info_list:
            print(f"env summary (episode {ep}): {info['env_metric']}")

        # average env metric
        metric_keys, num_envs = info_list[0]["env_metric"].keys(), len(info_list)
        avg_metric = {key: sum(info["env_metric"][key] for info in info_list) / num_envs for key in metric_keys}
        print(f"average env summary (episode {ep}): {avg_metric}")

        self.metrics.update(avg_metric)
        self.metrics = {k: v for k, v in self.metrics.items() if not k.startswith("val/")}

    def post_evaluate(self, info_list: list, ep: int) -> None:
        # print the env metric from each rollout worker
        for info in info_list:
            print(f"env summary (episode {ep}): {info['env_metric']}")

        # average env metric
        metric_keys, num_envs = info_list[0]["env_metric"].keys(), len(info_list)
        avg_metric = {key: sum(info["env_metric"][key] for info in info_list) / num_envs for key in metric_keys}
        print(f"average env summary (episode {ep}): {avg_metric}")

        self.metrics.update({"val/" + k: v for k, v in avg_metric.items()})

    def monitor_metrics(self) -> float:
        return -self.metrics["val/container_shortage"]

# %%
import torch
from torch.optim import Adam, RMSprop

from maro.rl.model import DiscreteACBasedNet, FullyConnected, VNet
from maro.rl.policy import DiscretePolicyGradient
from maro.rl.training.algorithms import ActorCriticParams, ActorCriticTrainer

state_dim = (
    (state_shaping_conf["look_back"] + 1) * (state_shaping_conf["max_ports_downstream"] + 1) * len(port_attributes)
    + len(vessel_attributes)
)
action_num = len(action_shaping_conf["action_space"])

actor_net_conf = {
    "hidden_dims": [256, 128, 64],
    "activation": torch.nn.Tanh,
    "output_activation": torch.nn.Tanh,
    "softmax": True,
    "batch_norm": False,
    "head": True,
}
critic_net_conf = {
    "hidden_dims": [256, 128, 64],
    "output_dim": 1,
    "activation": torch.nn.LeakyReLU,
    "output_activation": torch.nn.LeakyReLU,
    "softmax": False,
    "batch_norm": True,
    "head": True,
}
actor_learning_rate = 0.001
critic_learning_rate = 0.001


class MyActorNet(DiscreteACBasedNet):
    def __init__(self, state_dim: int, action_num: int) -> None:
        super(MyActorNet, self).__init__(state_dim=state_dim, action_num=action_num)
        self._actor = FullyConnected(input_dim=state_dim, output_dim=action_num, **actor_net_conf)
        self._optim = Adam(self._actor.parameters(), lr=actor_learning_rate)

    def _get_action_probs_impl(self, states: torch.Tensor) -> torch.Tensor:
        return self._actor(states)


class MyCriticNet(VNet):
    def __init__(self, state_dim: int) -> None:
        super(MyCriticNet, self).__init__(state_dim=state_dim)
        self._critic = FullyConnected(input_dim=state_dim, **critic_net_conf)
        self._optim = RMSprop(self._critic.parameters(), lr=critic_learning_rate)

    def _get_v_values(self, states: torch.Tensor) -> torch.Tensor:
        return self._critic(states).squeeze(-1)


def get_ac_policy(state_dim: int, action_num: int, name: str) -> DiscretePolicyGradient:
    return DiscretePolicyGradient(name=name, policy_net=MyActorNet(state_dim, action_num))


def get_ac(state_dim: int, name: str) -> ActorCriticTrainer:
    return ActorCriticTrainer(
        name=name,
        reward_discount=0.0,
        params=ActorCriticParams(
            get_v_critic_net_func=lambda: MyCriticNet(state_dim),
            grad_iters=10,
            critic_loss_cls=torch.nn.SmoothL1Loss,
            min_logp=None,
            lam=0.0,
        ),
    )

# %%
learn_env = Env(scenario="cim", topology="toy.4p_ssdd_l0.0", durations=500,options={"enable-dump-snapshot": "./ac_learn"})
test_env = Env(scenario="cim", topology="toy.4p_ssdd_l0.1", durations=500,options={"enable-dump-snapshot": "./ac_test"})

num_agents = len(learn_env.agent_idx_list)
agent2policy = {agent: f"ac_{agent}.policy" for agent in learn_env.agent_idx_list}
policies = [get_ac_policy(state_dim, action_num, f"ac_{i}.policy") for i in range(num_agents)]
trainers = [get_ac(state_dim, f"ac_{i}") for i in range(num_agents)]

# %%
rl_component_bundle = RLComponentBundle(
    env_sampler=CIM_ACSampler(
        learn_env=learn_env,
        test_env=test_env,
        policies=policies,
        agent2policy=agent2policy,
        reward_eval_delay=reward_shaping_conf["time_window"],
    ),
    agent2policy=agent2policy,
    policies=policies,
    trainers=trainers,
)

# %%
env_sampler = rl_component_bundle.env_sampler

num_episodes = 800
eval_schedule = [5*i for i in range(1,161)]
eval_point_index = 0

training_manager = TrainingManager(rl_component_bundle=rl_component_bundle)

# main loop
for ep in range(1, num_episodes + 1):
    result = env_sampler.sample()
    experiences: List[List[ExpElement]] = result["experiences"]
    info_list: List[dict] = result["info"]
        
    print("Collecting result:")
    env_sampler.post_collect(info_list, ep)
    print()

    training_manager.record_experiences(experiences)
    training_manager.train_step()

    if ep == eval_schedule[eval_point_index]:
        eval_point_index += 1
        result = env_sampler.eval()
        
        print("Evaluation result:")
        env_sampler.post_evaluate(result["info"], ep)
        print()

training_manager.exit()
# Out:
# Collecting result:
# env summary (episode 1): {'order_requirements': 1000000, 'container_shortage': 697657, 'operation_number': 1853626}
# average env summary (episode 1): {'order_requirements': 1000000.0, 'container_shortage': 697657.0, 'operation_number': 1853626.0}
#
# Collecting result:
# env summary (episode 2): {'order_requirements': 1000000, 'container_shortage': 731797, 'operation_number': 1899536}
# average env summary (episode 2): {'order_requirements': 1000000.0, 'container_shortage': 731797.0, 'operation_number': 1899536.0}
#
# Collecting result:
# env summary (episode 3): {'order_requirements': 1000000, 'container_shortage': 614319, 'operation_number': 1800642}
# average env summary (episode 3): {'order_requirements': 1000000.0, 'container_shortage': 614319.0, 'operation_number': 1800642.0}
#
# Collecting result:
# env summary (episode 4): {'order_requirements': 1000000, 'container_shortage': 648801, 'operation_number': 1505576}
# average env summary (episode 4): {'order_requirements': 1000000.0, 'container_shortage': 648801.0, 'operation_number': 1505576.0}
#
# Collecting result:
# env summary (episode 5): {'order_requirements': 1000000, 'container_shortage': 605449, 'operation_number': 1673347}
# average env summary (episode 5): {'order_requirements': 1000000.0, 'container_shortage': 605449.0, 'operation_number': 1673347.0}
#
# Evaluation result:
# env summary (episode 5): {'order_requirements': 1000000, 'container_shortage': 833682, 'operation_number': 282941}
# average env summary (episode 5): {'order_requirements': 1000000.0, 'container_shortage': 833682.0, 'operation_number': 282941.0}
#
# Collecting result:
# env summary (episode 6): {'order_requirements': 1000000, 'container_shortage': 606577, 'operation_number': 1739307}
# average env summary (episode 6): {'order_requirements': 1000000.0, 'container_shortage': 606577.0, 'operation_number': 1739307.0}
#
# Collecting result:
# env summary (episode 7): {'order_requirements': 1000000, 'container_shortage': 559283, 'operation_number': 2052445}
# average env summary (episode 7): {'order_requirements': 1000000.0, 'container_shortage': 559283.0, 'operation_number': 2052445.0}
#
# Collecting result:
# env summary (episode 8): {'order_requirements': 1000000, 'container_shortage': 491004, 'operation_number': 1908775}
# average env summary (episode 8): {'order_requirements': 1000000.0, 'container_shortage': 491004.0, 'operation_number': 1908775.0}
#
# Collecting result:
# env summary (episode 9): {'order_requirements': 1000000, 'container_shortage': 513475, 'operation_number': 1854343}
# average env summary (episode 9): {'order_requirements': 1000000.0, 'container_shortage': 513475.0, 'operation_number': 1854343.0}
#
# Collecting result:
# env summary (episode 10): {'order_requirements': 1000000, 'container_shortage': 567621, 'operation_number': 1886140}
# average env summary (episode 10): {'order_requirements': 1000000.0, 'container_shortage': 567621.0, 'operation_number': 1886140.0}
#
# Evaluation result:
# env summary (episode 10): {'order_requirements': 1000000, 'container_shortage': 613218, 'operation_number': 676320}
# average env summary (episode 10): {'order_requirements': 1000000.0, 'container_shortage': 613218.0, 'operation_number': 676320.0}
#
# Collecting result:
# env summary (episode 11): {'order_requirements': 1000000, 'container_shortage': 481800, 'operation_number': 1973266}
# average env summary (episode 11): {'order_requirements': 1000000.0, 'container_shortage': 481800.0, 'operation_number': 1973266.0}
#
# Collecting result:
# env summary (episode 12): {'order_requirements': 1000000, 'container_shortage': 358584, 'operation_number': 1890111}
# average env summary (episode 12): {'order_requirements': 1000000.0, 'container_shortage': 358584.0, 'operation_number': 1890111.0}
#
# Collecting result:
# env summary (episode 13): {'order_requirements': 1000000, 'container_shortage': 406898, 'operation_number': 2033085}
# average env summary (episode 13): {'order_requirements': 1000000.0, 'container_shortage': 406898.0, 'operation_number': 2033085.0}
#
# Collecting result:
# env summary (episode 14): {'order_requirements': 1000000, 'container_shortage': 412660, 'operation_number': 1921075}
# average env summary (episode 14): {'order_requirements': 1000000.0, 'container_shortage': 412660.0, 'operation_number': 1921075.0}
#
# Collecting result:
# env summary (episode 15): {'order_requirements': 1000000, 'container_shortage': 390776, 'operation_number': 1894819}
# average env summary (episode 15): {'order_requirements': 1000000.0, 'container_shortage': 390776.0, 'operation_number': 1894819.0}
#
# Evaluation result:
# env summary (episode 15): {'order_requirements': 1000000, 'container_shortage': 615391, 'operation_number': 670348}
# average env summary (episode 15): {'order_requirements': 1000000.0, 'container_shortage': 615391.0, 'operation_number': 670348.0}
#
# Collecting result:
# env summary (episode 16): {'order_requirements': 1000000, 'container_shortage': 327396, 'operation_number': 1820433}
# average env summary (episode 16): {'order_requirements': 1000000.0, 'container_shortage': 327396.0, 'operation_number': 1820433.0}
#
# Collecting result:
# env summary (episode 17): {'order_requirements': 1000000, 'container_shortage': 386689, 'operation_number': 1674457}
# average env summary (episode 17): {'order_requirements': 1000000.0, 'container_shortage': 386689.0, 'operation_number': 1674457.0}
#
# Collecting result:
# env summary (episode 18): {'order_requirements': 1000000, 'container_shortage': 308341, 'operation_number': 1853839}
# average env summary (episode 18): {'order_requirements': 1000000.0, 'container_shortage': 308341.0, 'operation_number': 1853839.0}
#
# Collecting result:
# env summary (episode 19): {'order_requirements': 1000000, 'container_shortage': 254687, 'operation_number': 1945124}
# average env summary (episode 19): {'order_requirements': 1000000.0, 'container_shortage': 254687.0, 'operation_number': 1945124.0}
#
# Collecting result:
# env summary (episode 20): {'order_requirements': 1000000, 'container_shortage': 236797, 'operation_number': 1826079}
# average env summary (episode 20): {'order_requirements': 1000000.0, 'container_shortage': 236797.0, 'operation_number': 1826079.0}
#
# Evaluation result:
# env summary (episode 20): {'order_requirements': 1000000, 'container_shortage': 612663, 'operation_number': 676739}
# average env summary (episode 20): {'order_requirements': 1000000.0, 'container_shortage': 612663.0, 'operation_number': 676739.0}
#
# Collecting result:
# env summary (episode 21): {'order_requirements': 1000000, 'container_shortage': 312771, 'operation_number': 1882800}
# average env summary (episode 21): {'order_requirements': 1000000.0, 'container_shortage': 312771.0, 'operation_number': 1882800.0}
#
# Collecting result:
# env summary (episode 22): {'order_requirements': 1000000, 'container_shortage': 310979, 'operation_number': 1711871}
# average env summary (episode 22): {'order_requirements': 1000000.0, 'container_shortage': 310979.0, 'operation_number': 1711871.0}
#
# Collecting result:
# env summary (episode 23): {'order_requirements': 1000000, 'container_shortage': 254139, 'operation_number': 1816780}
# average env summary (episode 23): {'order_requirements': 1000000.0, 'container_shortage': 254139.0, 'operation_number': 1816780.0}
#
# Collecting result:
# env summary (episode 24): {'order_requirements': 1000000, 'container_shortage': 312997, 'operation_number': 1863900}
# average env summary (episode 24): {'order_requirements': 1000000.0, 'container_shortage': 312997.0, 'operation_number': 1863900.0}
#
# Collecting result:
# env summary (episode 25): {'order_requirements': 1000000, 'container_shortage': 259112, 'operation_number': 1878331}
# average env summary (episode 25): {'order_requirements': 1000000.0, 'container_shortage': 259112.0, 'operation_number': 1878331.0}
#
# Evaluation result:
# env summary (episode 25): {'order_requirements': 1000000, 'container_shortage': 396168, 'operation_number': 922998}
# average env summary (episode 25): {'order_requirements': 1000000.0, 'container_shortage': 396168.0, 'operation_number': 922998.0}
#
# Collecting result:
# env summary (episode 26): {'order_requirements': 1000000, 'container_shortage': 227262, 'operation_number': 1888581}
# average env summary (episode 26): {'order_requirements': 1000000.0, 'container_shortage': 227262.0, 'operation_number': 1888581.0}
#
# Collecting result:
# env summary (episode 27): {'order_requirements': 1000000, 'container_shortage': 231025, 'operation_number': 1896113}
# average env summary (episode 27): {'order_requirements': 1000000.0, 'container_shortage': 231025.0, 'operation_number': 1896113.0}
#
# Collecting result:
# env summary (episode 28): {'order_requirements': 1000000, 'container_shortage': 220242, 'operation_number': 1999363}
# average env summary (episode 28): {'order_requirements': 1000000.0, 'container_shortage': 220242.0, 'operation_number': 1999363.0}
#
# Collecting result:
# env summary (episode 29): {'order_requirements': 1000000, 'container_shortage': 246154, 'operation_number': 1904982}
# average env summary (episode 29): {'order_requirements': 1000000.0, 'container_shortage': 246154.0, 'operation_number': 1904982.0}
#
# Collecting result:
# env summary (episode 30): {'order_requirements': 1000000, 'container_shortage': 214153, 'operation_number': 1950263}
# average env summary (episode 30): {'order_requirements': 1000000.0, 'container_shortage': 214153.0, 'operation_number': 1950263.0}
#
# Evaluation result:
# env summary (episode 30): {'order_requirements': 1000000, 'container_shortage': 263374, 'operation_number': 1081816}
# average env summary (episode 30): {'order_requirements': 1000000.0, 'container_shortage': 263374.0, 'operation_number': 1081816.0}
#
# Collecting result:
# env summary (episode 31): {'order_requirements': 1000000, 'container_shortage': 169908, 'operation_number': 1902297}
# average env summary (episode 31): {'order_requirements': 1000000.0, 'container_shortage': 169908.0, 'operation_number': 1902297.0}
#
# Collecting result:
# env summary (episode 32): {'order_requirements': 1000000, 'container_shortage': 215412, 'operation_number': 1729295}
# average env summary (episode 32): {'order_requirements': 1000000.0, 'container_shortage': 215412.0, 'operation_number': 1729295.0}
#
# Collecting result:
# env summary (episode 33): {'order_requirements': 1000000, 'container_shortage': 170774, 'operation_number': 1839123}
# average env summary (episode 33): {'order_requirements': 1000000.0, 'container_shortage': 170774.0, 'operation_number': 1839123.0}
#
# Collecting result:
# env summary (episode 34): {'order_requirements': 1000000, 'container_shortage': 182432, 'operation_number': 1916472}
# average env summary (episode 34): {'order_requirements': 1000000.0, 'container_shortage': 182432.0, 'operation_number': 1916472.0}
#
# Collecting result:
# env summary (episode 35): {'order_requirements': 1000000, 'container_shortage': 237677, 'operation_number': 1958781}
# average env summary (episode 35): {'order_requirements': 1000000.0, 'container_shortage': 237677.0, 'operation_number': 1958781.0}
#
# Evaluation result:
# env summary (episode 35): {'order_requirements': 1000000, 'container_shortage': 551622, 'operation_number': 765875}
# average env summary (episode 35): {'order_requirements': 1000000.0, 'container_shortage': 551622.0, 'operation_number': 765875.0}
#
# Collecting result:
# env summary (episode 36): {'order_requirements': 1000000, 'container_shortage': 203601, 'operation_number': 1862455}
# average env summary (episode 36): {'order_requirements': 1000000.0, 'container_shortage': 203601.0, 'operation_number': 1862455.0}
#
# Collecting result:
# env summary (episode 37): {'order_requirements': 1000000, 'container_shortage': 188953, 'operation_number': 2041249}
# average env summary (episode 37): {'order_requirements': 1000000.0, 'container_shortage': 188953.0, 'operation_number': 2041249.0}
#
# Collecting result:
# env summary (episode 38): {'order_requirements': 1000000, 'container_shortage': 185088, 'operation_number': 1940576}
# average env summary (episode 38): {'order_requirements': 1000000.0, 'container_shortage': 185088.0, 'operation_number': 1940576.0}
#
# Collecting result:
# env summary (episode 39): {'order_requirements': 1000000, 'container_shortage': 188366, 'operation_number': 1843125}
# average env summary (episode 39): {'order_requirements': 1000000.0, 'container_shortage': 188366.0, 'operation_number': 1843125.0}
#
# Collecting result:
# env summary (episode 40): {'order_requirements': 1000000, 'container_shortage': 174914, 'operation_number': 1893453}
# average env summary (episode 40): {'order_requirements': 1000000.0, 'container_shortage': 174914.0, 'operation_number': 1893453.0}
#
# Evaluation result:
# env summary (episode 40): {'order_requirements': 1000000, 'container_shortage': 558375, 'operation_number': 766295}
# average env summary (episode 40): {'order_requirements': 1000000.0, 'container_shortage': 558375.0, 'operation_number': 766295.0}
#
# Collecting result:
# env summary (episode 41): {'order_requirements': 1000000, 'container_shortage': 187923, 'operation_number': 1875302}
# average env summary (episode 41): {'order_requirements': 1000000.0, 'container_shortage': 187923.0, 'operation_number': 1875302.0}
#
# Collecting result:
# env summary (episode 42): {'order_requirements': 1000000, 'container_shortage': 170492, 'operation_number': 1826331}
# average env summary (episode 42): {'order_requirements': 1000000.0, 'container_shortage': 170492.0, 'operation_number': 1826331.0}
#
# Collecting result:
# env summary (episode 43): {'order_requirements': 1000000, 'container_shortage': 267656, 'operation_number': 1673354}
# average env summary (episode 43): {'order_requirements': 1000000.0, 'container_shortage': 267656.0, 'operation_number': 1673354.0}
#
# Collecting result:
# env summary (episode 44): {'order_requirements': 1000000, 'container_shortage': 209367, 'operation_number': 1867448}
# average env summary (episode 44): {'order_requirements': 1000000.0, 'container_shortage': 209367.0, 'operation_number': 1867448.0}
#
# Collecting result:
# env summary (episode 45): {'order_requirements': 1000000, 'container_shortage': 214732, 'operation_number': 1849157}
# average env summary (episode 45): {'order_requirements': 1000000.0, 'container_shortage': 214732.0, 'operation_number': 1849157.0}
#
# Evaluation result:
# env summary (episode 45): {'order_requirements': 1000000, 'container_shortage': 438484, 'operation_number': 823835}
# average env summary (episode 45): {'order_requirements': 1000000.0, 'container_shortage': 438484.0, 'operation_number': 823835.0}
#
# Collecting result:
# env summary (episode 46): {'order_requirements': 1000000, 'container_shortage': 185948, 'operation_number': 1916714}
# average env summary (episode 46): {'order_requirements': 1000000.0, 'container_shortage': 185948.0, 'operation_number': 1916714.0}
#
# Collecting result:
# env summary (episode 47): {'order_requirements': 1000000, 'container_shortage': 267571, 'operation_number': 1813739}
# average env summary (episode 47): {'order_requirements': 1000000.0, 'container_shortage': 267571.0, 'operation_number': 1813739.0}
#
# Collecting result:
# env summary (episode 48): {'order_requirements': 1000000, 'container_shortage': 312769, 'operation_number': 1579344}
# average env summary (episode 48): {'order_requirements': 1000000.0, 'container_shortage': 312769.0, 'operation_number': 1579344.0}
#
# Collecting result:
# env summary (episode 49): {'order_requirements': 1000000, 'container_shortage': 202597, 'operation_number': 1815281}
# average env summary (episode 49): {'order_requirements': 1000000.0, 'container_shortage': 202597.0, 'operation_number': 1815281.0}
#
# Collecting result:
# env summary (episode 50): {'order_requirements': 1000000, 'container_shortage': 381901, 'operation_number': 1558117}
# average env summary (episode 50): {'order_requirements': 1000000.0, 'container_shortage': 381901.0, 'operation_number': 1558117.0}
#
# Evaluation result:
# env summary (episode 50): {'order_requirements': 1000000, 'container_shortage': 434250, 'operation_number': 824474}
# average env summary (episode 50): {'order_requirements': 1000000.0, 'container_shortage': 434250.0, 'operation_number': 824474.0}
#
# Collecting result:
# env summary (episode 51): {'order_requirements': 1000000, 'container_shortage': 239281, 'operation_number': 1826445}
# average env summary (episode 51): {'order_requirements': 1000000.0, 'container_shortage': 239281.0, 'operation_number': 1826445.0}
#
# Collecting result:
# env summary (episode 52): {'order_requirements': 1000000, 'container_shortage': 255284, 'operation_number': 1743709}
# average env summary (episode 52): {'order_requirements': 1000000.0, 'container_shortage': 255284.0, 'operation_number': 1743709.0}
#
# Collecting result:
# env summary (episode 53): {'order_requirements': 1000000, 'container_shortage': 303844, 'operation_number': 1739387}
# average env summary (episode 53): {'order_requirements': 1000000.0, 'container_shortage': 303844.0, 'operation_number': 1739387.0}
#
# Collecting result:
# env summary (episode 54): {'order_requirements': 1000000, 'container_shortage': 273737, 'operation_number': 1716971}
# average env summary (episode 54): {'order_requirements': 1000000.0, 'container_shortage': 273737.0, 'operation_number': 1716971.0}
#
# Collecting result:
# env summary (episode 55): {'order_requirements': 1000000, 'container_shortage': 371864, 'operation_number': 1637353}
# average env summary (episode 55): {'order_requirements': 1000000.0, 'container_shortage': 371864.0, 'operation_number': 1637353.0}
#
# Evaluation result:
# env summary (episode 55): {'order_requirements': 1000000, 'container_shortage': 475026, 'operation_number': 807523}
# average env summary (episode 55): {'order_requirements': 1000000.0, 'container_shortage': 475026.0, 'operation_number': 807523.0}
#
# Collecting result:
# env summary (episode 56): {'order_requirements': 1000000, 'container_shortage': 260795, 'operation_number': 1728145}
# average env summary (episode 56): {'order_requirements': 1000000.0, 'container_shortage': 260795.0, 'operation_number': 1728145.0}
#
# Collecting result:
# env summary (episode 57): {'order_requirements': 1000000, 'container_shortage': 254805, 'operation_number': 1826520}
# average env summary (episode 57): {'order_requirements': 1000000.0, 'container_shortage': 254805.0, 'operation_number': 1826520.0}
#
# Collecting result:
# env summary (episode 58): {'order_requirements': 1000000, 'container_shortage': 299414, 'operation_number': 1673423}
# average env summary (episode 58): {'order_requirements': 1000000.0, 'container_shortage': 299414.0, 'operation_number': 1673423.0}
#
# Collecting result:
# env summary (episode 59): {'order_requirements': 1000000, 'container_shortage': 269239, 'operation_number': 1640238}
# average env summary (episode 59): {'order_requirements': 1000000.0, 'container_shortage': 269239.0, 'operation_number': 1640238.0}
#
# Collecting result:
# env summary (episode 60): {'order_requirements': 1000000, 'container_shortage': 280239, 'operation_number': 1633957}
# average env summary (episode 60): {'order_requirements': 1000000.0, 'container_shortage': 280239.0, 'operation_number': 1633957.0}
#
# Evaluation result:
# env summary (episode 60): {'order_requirements': 1000000, 'container_shortage': 628527, 'operation_number': 657478}
# average env summary (episode 60): {'order_requirements': 1000000.0, 'container_shortage': 628527.0, 'operation_number': 657478.0}
#
# Collecting result:
# env summary (episode 61): {'order_requirements': 1000000, 'container_shortage': 276356, 'operation_number': 1662340}
# average env summary (episode 61): {'order_requirements': 1000000.0, 'container_shortage': 276356.0, 'operation_number': 1662340.0}
#
# Collecting result:
# env summary (episode 62): {'order_requirements': 1000000, 'container_shortage': 291018, 'operation_number': 1636048}
# average env summary (episode 62): {'order_requirements': 1000000.0, 'container_shortage': 291018.0, 'operation_number': 1636048.0}
#
# Collecting result:
# env summary (episode 63): {'order_requirements': 1000000, 'container_shortage': 288966, 'operation_number': 1600196}
# average env summary (episode 63): {'order_requirements': 1000000.0, 'container_shortage': 288966.0, 'operation_number': 1600196.0}
#
# Collecting result:
# env summary (episode 64): {'order_requirements': 1000000, 'container_shortage': 320721, 'operation_number': 1556355}
# average env summary (episode 64): {'order_requirements': 1000000.0, 'container_shortage': 320721.0, 'operation_number': 1556355.0}
#
# Collecting result:
# env summary (episode 65): {'order_requirements': 1000000, 'container_shortage': 315616, 'operation_number': 1739995}
# average env summary (episode 65): {'order_requirements': 1000000.0, 'container_shortage': 315616.0, 'operation_number': 1739995.0}
#
# Evaluation result:
# env summary (episode 65): {'order_requirements': 1000000, 'container_shortage': 618937, 'operation_number': 673714}
# average env summary (episode 65): {'order_requirements': 1000000.0, 'container_shortage': 618937.0, 'operation_number': 673714.0}
#
# Collecting result:
# env summary (episode 66): {'order_requirements': 1000000, 'container_shortage': 271786, 'operation_number': 1711834}
# average env summary (episode 66): {'order_requirements': 1000000.0, 'container_shortage': 271786.0, 'operation_number': 1711834.0}
#
# Collecting result:
# env summary (episode 67): {'order_requirements': 1000000, 'container_shortage': 290840, 'operation_number': 1648330}
# average env summary (episode 67): {'order_requirements': 1000000.0, 'container_shortage': 290840.0, 'operation_number': 1648330.0}
#
# Collecting result:
# env summary (episode 68): {'order_requirements': 1000000, 'container_shortage': 278497, 'operation_number': 1616362}
# average env summary (episode 68): {'order_requirements': 1000000.0, 'container_shortage': 278497.0, 'operation_number': 1616362.0}
#
# Collecting result:
# env summary (episode 69): {'order_requirements': 1000000, 'container_shortage': 255167, 'operation_number': 1743194}
# average env summary (episode 69): {'order_requirements': 1000000.0, 'container_shortage': 255167.0, 'operation_number': 1743194.0}
#
# Collecting result:
# env summary (episode 70): {'order_requirements': 1000000, 'container_shortage': 344564, 'operation_number': 1565770}
# average env summary (episode 70): {'order_requirements': 1000000.0, 'container_shortage': 344564.0, 'operation_number': 1565770.0}
#
# Evaluation result:
# env summary (episode 70): {'order_requirements': 1000000, 'container_shortage': 625058, 'operation_number': 661713}
# average env summary (episode 70): {'order_requirements': 1000000.0, 'container_shortage': 625058.0, 'operation_number': 661713.0}
#
# Collecting result:
# env summary (episode 71): {'order_requirements': 1000000, 'container_shortage': 248023, 'operation_number': 1606530}
# average env summary (episode 71): {'order_requirements': 1000000.0, 'container_shortage': 248023.0, 'operation_number': 1606530.0}
#
# Collecting result:
# env summary (episode 72): {'order_requirements': 1000000, 'container_shortage': 282912, 'operation_number': 1599115}
# average env summary (episode 72): {'order_requirements': 1000000.0, 'container_shortage': 282912.0, 'operation_number': 1599115.0}
#
# Collecting result:
# env summary (episode 73): {'order_requirements': 1000000, 'container_shortage': 413007, 'operation_number': 1332468}
# average env summary (episode 73): {'order_requirements': 1000000.0, 'container_shortage': 413007.0, 'operation_number': 1332468.0}
#
# Collecting result:
# env summary (episode 74): {'order_requirements': 1000000, 'container_shortage': 313368, 'operation_number': 1556731}
# average env summary (episode 74): {'order_requirements': 1000000.0, 'container_shortage': 313368.0, 'operation_number': 1556731.0}
#
# Collecting result:
# env summary (episode 75): {'order_requirements': 1000000, 'container_shortage': 286097, 'operation_number': 1562483}
# average env summary (episode 75): {'order_requirements': 1000000.0, 'container_shortage': 286097.0, 'operation_number': 1562483.0}
#
# Evaluation result:
# env summary (episode 75): {'order_requirements': 1000000, 'container_shortage': 775344, 'operation_number': 370266}
# average env summary (episode 75): {'order_requirements': 1000000.0, 'container_shortage': 775344.0, 'operation_number': 370266.0}
#
# Collecting result:
# env summary (episode 76): {'order_requirements': 1000000, 'container_shortage': 445694, 'operation_number': 1199222}
# average env summary (episode 76): {'order_requirements': 1000000.0, 'container_shortage': 445694.0, 'operation_number': 1199222.0}
#
# Collecting result:
# env summary (episode 77): {'order_requirements': 1000000, 'container_shortage': 386037, 'operation_number': 1409046}
# average env summary (episode 77): {'order_requirements': 1000000.0, 'container_shortage': 386037.0, 'operation_number': 1409046.0}
#
# Collecting result:
# env summary (episode 78): {'order_requirements': 1000000, 'container_shortage': 356444, 'operation_number': 1447003}
# average env summary (episode 78): {'order_requirements': 1000000.0, 'container_shortage': 356444.0, 'operation_number': 1447003.0}
#
# Collecting result:
# env summary (episode 79): {'order_requirements': 1000000, 'container_shortage': 294977, 'operation_number': 1532617}
# average env summary (episode 79): {'order_requirements': 1000000.0, 'container_shortage': 294977.0, 'operation_number': 1532617.0}
#
# Collecting result:
# env summary (episode 80): {'order_requirements': 1000000, 'container_shortage': 291635, 'operation_number': 1522101}
# average env summary (episode 80): {'order_requirements': 1000000.0, 'container_shortage': 291635.0, 'operation_number': 1522101.0}
#
# Evaluation result:
# env summary (episode 80): {'order_requirements': 1000000, 'container_shortage': 738241, 'operation_number': 432967}
# average env summary (episode 80): {'order_requirements': 1000000.0, 'container_shortage': 738241.0, 'operation_number': 432967.0}
#
# Collecting result:
# env summary (episode 81): {'order_requirements': 1000000, 'container_shortage': 301663, 'operation_number': 1585375}
# average env summary (episode 81): {'order_requirements': 1000000.0, 'container_shortage': 301663.0, 'operation_number': 1585375.0}
#
# Collecting result:
# env summary (episode 82): {'order_requirements': 1000000, 'container_shortage': 317819, 'operation_number': 1564422}
# average env summary (episode 82): {'order_requirements': 1000000.0, 'container_shortage': 317819.0, 'operation_number': 1564422.0}
#
# Collecting result:
# env summary (episode 83): {'order_requirements': 1000000, 'container_shortage': 407895, 'operation_number': 1251229}
# average env summary (episode 83): {'order_requirements': 1000000.0, 'container_shortage': 407895.0, 'operation_number': 1251229.0}
#
# Collecting result:
# env summary (episode 84): {'order_requirements': 1000000, 'container_shortage': 432080, 'operation_number': 1357651}
# average env summary (episode 84): {'order_requirements': 1000000.0, 'container_shortage': 432080.0, 'operation_number': 1357651.0}
#
# Collecting result:
# env summary (episode 85): {'order_requirements': 1000000, 'container_shortage': 391251, 'operation_number': 1439903}
# average env summary (episode 85): {'order_requirements': 1000000.0, 'container_shortage': 391251.0, 'operation_number': 1439903.0}
#
# Evaluation result:
# env summary (episode 85): {'order_requirements': 1000000, 'container_shortage': 738241, 'operation_number': 432967}
# average env summary (episode 85): {'order_requirements': 1000000.0, 'container_shortage': 738241.0, 'operation_number': 432967.0}
#
# Collecting result:
# env summary (episode 86): {'order_requirements': 1000000, 'container_shortage': 337797, 'operation_number': 1467539}
# average env summary (episode 86): {'order_requirements': 1000000.0, 'container_shortage': 337797.0, 'operation_number': 1467539.0}
#
# Collecting result:
# env summary (episode 87): {'order_requirements': 1000000, 'container_shortage': 336156, 'operation_number': 1479132}
# average env summary (episode 87): {'order_requirements': 1000000.0, 'container_shortage': 336156.0, 'operation_number': 1479132.0}
#
# Collecting result:
# env summary (episode 88): {'order_requirements': 1000000, 'container_shortage': 387198, 'operation_number': 1337454}
# average env summary (episode 88): {'order_requirements': 1000000.0, 'container_shortage': 387198.0, 'operation_number': 1337454.0}
#
# Collecting result:
# env summary (episode 89): {'order_requirements': 1000000, 'container_shortage': 400335, 'operation_number': 1287760}
# average env summary (episode 89): {'order_requirements': 1000000.0, 'container_shortage': 400335.0, 'operation_number': 1287760.0}
#
# Collecting result:
# env summary (episode 90): {'order_requirements': 1000000, 'container_shortage': 441135, 'operation_number': 1268275}
# average env summary (episode 90): {'order_requirements': 1000000.0, 'container_shortage': 441135.0, 'operation_number': 1268275.0}
#
# Evaluation result:
# env summary (episode 90): {'order_requirements': 1000000, 'container_shortage': 738241, 'operation_number': 432967}
# average env summary (episode 90): {'order_requirements': 1000000.0, 'container_shortage': 738241.0, 'operation_number': 432967.0}
#
# Collecting result:
# env summary (episode 91): {'order_requirements': 1000000, 'container_shortage': 441390, 'operation_number': 1369896}
# average env summary (episode 91): {'order_requirements': 1000000.0, 'container_shortage': 441390.0, 'operation_number': 1369896.0}
#
# Collecting result:
# env summary (episode 92): {'order_requirements': 1000000, 'container_shortage': 458953, 'operation_number': 1344261}
# average env summary (episode 92): {'order_requirements': 1000000.0, 'container_shortage': 458953.0, 'operation_number': 1344261.0}
#
# Collecting result:
# env summary (episode 93): {'order_requirements': 1000000, 'container_shortage': 288983, 'operation_number': 1607461}
# average env summary (episode 93): {'order_requirements': 1000000.0, 'container_shortage': 288983.0, 'operation_number': 1607461.0}
#
# Collecting result:
# env summary (episode 94): {'order_requirements': 1000000, 'container_shortage': 423182, 'operation_number': 1380597}
# average env summary (episode 94): {'order_requirements': 1000000.0, 'container_shortage': 423182.0, 'operation_number': 1380597.0}
#
# Collecting result:
# env summary (episode 95): {'order_requirements': 1000000, 'container_shortage': 363208, 'operation_number': 1402789}
# average env summary (episode 95): {'order_requirements': 1000000.0, 'container_shortage': 363208.0, 'operation_number': 1402789.0}
#
# Evaluation result:
# env summary (episode 95): {'order_requirements': 1000000, 'container_shortage': 746410, 'operation_number': 416038}
# average env summary (episode 95): {'order_requirements': 1000000.0, 'container_shortage': 746410.0, 'operation_number': 416038.0}
#
# Collecting result:
# env summary (episode 96): {'order_requirements': 1000000, 'container_shortage': 279777, 'operation_number': 1595528}
# average env summary (episode 96): {'order_requirements': 1000000.0, 'container_shortage': 279777.0, 'operation_number': 1595528.0}
#
# Collecting result:
# env summary (episode 97): {'order_requirements': 1000000, 'container_shortage': 307176, 'operation_number': 1481259}
# average env summary (episode 97): {'order_requirements': 1000000.0, 'container_shortage': 307176.0, 'operation_number': 1481259.0}
#
# Collecting result:
# env summary (episode 98): {'order_requirements': 1000000, 'container_shortage': 339831, 'operation_number': 1398244}
# average env summary (episode 98): {'order_requirements': 1000000.0, 'container_shortage': 339831.0, 'operation_number': 1398244.0}
#
# Collecting result:
# env summary (episode 99): {'order_requirements': 1000000, 'container_shortage': 390832, 'operation_number': 1425310}
# average env summary (episode 99): {'order_requirements': 1000000.0, 'container_shortage': 390832.0, 'operation_number': 1425310.0}
#
# Collecting result:
# env summary (episode 100): {'order_requirements': 1000000, 'container_shortage': 359317, 'operation_number': 1460409}
# average env summary (episode 100): {'order_requirements': 1000000.0, 'container_shortage': 359317.0, 'operation_number': 1460409.0}
#
# Evaluation result:
# env summary (episode 100): {'order_requirements': 1000000, 'container_shortage': 789174, 'operation_number': 335637}
# average env summary (episode 100): {'order_requirements': 1000000.0, 'container_shortage': 789174.0, 'operation_number': 335637.0}
#
# Collecting result:
# env summary (episode 101): {'order_requirements': 1000000, 'container_shortage': 491103, 'operation_number': 1098283}
# average env summary (episode 101): {'order_requirements': 1000000.0, 'container_shortage': 491103.0, 'operation_number': 1098283.0}
#
# Collecting result:
# env summary (episode 102): {'order_requirements': 1000000, 'container_shortage': 402829, 'operation_number': 1297198}
# average env summary (episode 102): {'order_requirements': 1000000.0, 'container_shortage': 402829.0, 'operation_number': 1297198.0}
#
# Collecting result:
# env summary (episode 103): {'order_requirements': 1000000, 'container_shortage': 475033, 'operation_number': 1214982}
# average env summary (episode 103): {'order_requirements': 1000000.0, 'container_shortage': 475033.0, 'operation_number': 1214982.0}
#
# Collecting result:
# env summary (episode 104): {'order_requirements': 1000000, 'container_shortage': 320362, 'operation_number': 1494384}
# average env summary (episode 104): {'order_requirements': 1000000.0, 'container_shortage': 320362.0, 'operation_number': 1494384.0}
#
# Collecting result:
# env summary (episode 105): {'order_requirements': 1000000, 'container_shortage': 457457, 'operation_number': 1191369}
# average env summary (episode 105): {'order_requirements': 1000000.0, 'container_shortage': 457457.0, 'operation_number': 1191369.0}
#
# Evaluation result:
# env summary (episode 105): {'order_requirements': 1000000, 'container_shortage': 787926, 'operation_number': 334960}
# average env summary (episode 105): {'order_requirements': 1000000.0, 'container_shortage': 787926.0, 'operation_number': 334960.0}
#
# Collecting result:
# env summary (episode 106): {'order_requirements': 1000000, 'container_shortage': 423592, 'operation_number': 1316302}
# average env summary (episode 106): {'order_requirements': 1000000.0, 'container_shortage': 423592.0, 'operation_number': 1316302.0}
#
# Collecting result:
# env summary (episode 107): {'order_requirements': 1000000, 'container_shortage': 385213, 'operation_number': 1295454}
# average env summary (episode 107): {'order_requirements': 1000000.0, 'container_shortage': 385213.0, 'operation_number': 1295454.0}
#
# Collecting result:
# env summary (episode 108): {'order_requirements': 1000000, 'container_shortage': 402971, 'operation_number': 1396629}
# average env summary (episode 108): {'order_requirements': 1000000.0, 'container_shortage': 402971.0, 'operation_number': 1396629.0}
#
# Collecting result:
# env summary (episode 109): {'order_requirements': 1000000, 'container_shortage': 658111, 'operation_number': 684354}
# average env summary (episode 109): {'order_requirements': 1000000.0, 'container_shortage': 658111.0, 'operation_number': 684354.0}
#
# Collecting result:
# env summary (episode 110): {'order_requirements': 1000000, 'container_shortage': 446714, 'operation_number': 1212815}
# average env summary (episode 110): {'order_requirements': 1000000.0, 'container_shortage': 446714.0, 'operation_number': 1212815.0}
#
# Evaluation result:
# env summary (episode 110): {'order_requirements': 1000000, 'container_shortage': 684226, 'operation_number': 435041}
# average env summary (episode 110): {'order_requirements': 1000000.0, 'container_shortage': 684226.0, 'operation_number': 435041.0}
#
# Collecting result:
# env summary (episode 111): {'order_requirements': 1000000, 'container_shortage': 497849, 'operation_number': 1086468}
# average env summary (episode 111): {'order_requirements': 1000000.0, 'container_shortage': 497849.0, 'operation_number': 1086468.0}
#
# Collecting result:
# env summary (episode 112): {'order_requirements': 1000000, 'container_shortage': 508257, 'operation_number': 1189332}
# average env summary (episode 112): {'order_requirements': 1000000.0, 'container_shortage': 508257.0, 'operation_number': 1189332.0}
#
# Collecting result:
# env summary (episode 113): {'order_requirements': 1000000, 'container_shortage': 513041, 'operation_number': 1087474}
# average env summary (episode 113): {'order_requirements': 1000000.0, 'container_shortage': 513041.0, 'operation_number': 1087474.0}
#
# Collecting result:
# env summary (episode 114): {'order_requirements': 1000000, 'container_shortage': 573522, 'operation_number': 881748}
# average env summary (episode 114): {'order_requirements': 1000000.0, 'container_shortage': 573522.0, 'operation_number': 881748.0}
#
# Collecting result:
# env summary (episode 115): {'order_requirements': 1000000, 'container_shortage': 536420, 'operation_number': 1040835}
# average env summary (episode 115): {'order_requirements': 1000000.0, 'container_shortage': 536420.0, 'operation_number': 1040835.0}
#
# Evaluation result:
# env summary (episode 115): {'order_requirements': 1000000, 'container_shortage': 842055, 'operation_number': 238042}
# average env summary (episode 115): {'order_requirements': 1000000.0, 'container_shortage': 842055.0, 'operation_number': 238042.0}
#
# Collecting result:
# env summary (episode 116): {'order_requirements': 1000000, 'container_shortage': 524346, 'operation_number': 1061280}
# average env summary (episode 116): {'order_requirements': 1000000.0, 'container_shortage': 524346.0, 'operation_number': 1061280.0}
#
# Collecting result:
# env summary (episode 117): {'order_requirements': 1000000, 'container_shortage': 600466, 'operation_number': 826682}
# average env summary (episode 117): {'order_requirements': 1000000.0, 'container_shortage': 600466.0, 'operation_number': 826682.0}
#
# Collecting result:
# env summary (episode 118): {'order_requirements': 1000000, 'container_shortage': 500696, 'operation_number': 1044941}
# average env summary (episode 118): {'order_requirements': 1000000.0, 'container_shortage': 500696.0, 'operation_number': 1044941.0}
#
# Collecting result:
# env summary (episode 119): {'order_requirements': 1000000, 'container_shortage': 533925, 'operation_number': 1036544}
# average env summary (episode 119): {'order_requirements': 1000000.0, 'container_shortage': 533925.0, 'operation_number': 1036544.0}
#
# Collecting result:
# env summary (episode 120): {'order_requirements': 1000000, 'container_shortage': 590510, 'operation_number': 924583}
# average env summary (episode 120): {'order_requirements': 1000000.0, 'container_shortage': 590510.0, 'operation_number': 924583.0}
#
# Evaluation result:
# env summary (episode 120): {'order_requirements': 1000000, 'container_shortage': 844616, 'operation_number': 232930}
# average env summary (episode 120): {'order_requirements': 1000000.0, 'container_shortage': 844616.0, 'operation_number': 232930.0}
#
# Collecting result:
# env summary (episode 121): {'order_requirements': 1000000, 'container_shortage': 610728, 'operation_number': 913286}
# average env summary (episode 121): {'order_requirements': 1000000.0, 'container_shortage': 610728.0, 'operation_number': 913286.0}
#
# Collecting result:
# env summary (episode 122): {'order_requirements': 1000000, 'container_shortage': 555138, 'operation_number': 910971}
# average env summary (episode 122): {'order_requirements': 1000000.0, 'container_shortage': 555138.0, 'operation_number': 910971.0}
#
# Collecting result:
# env summary (episode 123): {'order_requirements': 1000000, 'container_shortage': 556836, 'operation_number': 1000481}
# average env summary (episode 123): {'order_requirements': 1000000.0, 'container_shortage': 556836.0, 'operation_number': 1000481.0}
#
# Collecting result:
# env summary (episode 124): {'order_requirements': 1000000, 'container_shortage': 470333, 'operation_number': 1129225}
# average env summary (episode 124): {'order_requirements': 1000000.0, 'container_shortage': 470333.0, 'operation_number': 1129225.0}
#
# Collecting result:
# env summary (episode 125): {'order_requirements': 1000000, 'container_shortage': 475855, 'operation_number': 1194118}
# average env summary (episode 125): {'order_requirements': 1000000.0, 'container_shortage': 475855.0, 'operation_number': 1194118.0}
#
# Evaluation result:
# env summary (episode 125): {'order_requirements': 1000000, 'container_shortage': 840806, 'operation_number': 240543}
# average env summary (episode 125): {'order_requirements': 1000000.0, 'container_shortage': 840806.0, 'operation_number': 240543.0}
#
# Collecting result:
# env summary (episode 126): {'order_requirements': 1000000, 'container_shortage': 449983, 'operation_number': 1158307}
# average env summary (episode 126): {'order_requirements': 1000000.0, 'container_shortage': 449983.0, 'operation_number': 1158307.0}
#
# Collecting result:
# env summary (episode 127): {'order_requirements': 1000000, 'container_shortage': 614612, 'operation_number': 973504}
# average env summary (episode 127): {'order_requirements': 1000000.0, 'container_shortage': 614612.0, 'operation_number': 973504.0}
#
# Collecting result:
# env summary (episode 128): {'order_requirements': 1000000, 'container_shortage': 582427, 'operation_number': 879129}
# average env summary (episode 128): {'order_requirements': 1000000.0, 'container_shortage': 582427.0, 'operation_number': 879129.0}
#
# Collecting result:
# env summary (episode 129): {'order_requirements': 1000000, 'container_shortage': 480623, 'operation_number': 1275323}
# average env summary (episode 129): {'order_requirements': 1000000.0, 'container_shortage': 480623.0, 'operation_number': 1275323.0}
#
# Collecting result:
# env summary (episode 130): {'order_requirements': 1000000, 'container_shortage': 370793, 'operation_number': 1404411}
# average env summary (episode 130): {'order_requirements': 1000000.0, 'container_shortage': 370793.0, 'operation_number': 1404411.0}
#
# Evaluation result:
# env summary (episode 130): {'order_requirements': 1000000, 'container_shortage': 828963, 'operation_number': 264236}
# average env summary (episode 130): {'order_requirements': 1000000.0, 'container_shortage': 828963.0, 'operation_number': 264236.0}
#
# Collecting result:
# env summary (episode 131): {'order_requirements': 1000000, 'container_shortage': 506916, 'operation_number': 1120941}
# average env summary (episode 131): {'order_requirements': 1000000.0, 'container_shortage': 506916.0, 'operation_number': 1120941.0}
#
# Collecting result:
# env summary (episode 132): {'order_requirements': 1000000, 'container_shortage': 473339, 'operation_number': 1217438}
# average env summary (episode 132): {'order_requirements': 1000000.0, 'container_shortage': 473339.0, 'operation_number': 1217438.0}
#
# Collecting result:
# env summary (episode 133): {'order_requirements': 1000000, 'container_shortage': 442912, 'operation_number': 1190232}
# average env summary (episode 133): {'order_requirements': 1000000.0, 'container_shortage': 442912.0, 'operation_number': 1190232.0}
#
# Collecting result:
# env summary (episode 134): {'order_requirements': 1000000, 'container_shortage': 524577, 'operation_number': 1113399}
# average env summary (episode 134): {'order_requirements': 1000000.0, 'container_shortage': 524577.0, 'operation_number': 1113399.0}
#
# Collecting result:
# env summary (episode 135): {'order_requirements': 1000000, 'container_shortage': 447817, 'operation_number': 1344671}
# average env summary (episode 135): {'order_requirements': 1000000.0, 'container_shortage': 447817.0, 'operation_number': 1344671.0}
#
# Evaluation result:
# env summary (episode 135): {'order_requirements': 1000000, 'container_shortage': 828963, 'operation_number': 264236}
# average env summary (episode 135): {'order_requirements': 1000000.0, 'container_shortage': 828963.0, 'operation_number': 264236.0}
#
# Collecting result:
# env summary (episode 136): {'order_requirements': 1000000, 'container_shortage': 440469, 'operation_number': 1279507}
# average env summary (episode 136): {'order_requirements': 1000000.0, 'container_shortage': 440469.0, 'operation_number': 1279507.0}
#
# Collecting result:
# env summary (episode 137): {'order_requirements': 1000000, 'container_shortage': 528049, 'operation_number': 1049765}
# average env summary (episode 137): {'order_requirements': 1000000.0, 'container_shortage': 528049.0, 'operation_number': 1049765.0}
#
# Collecting result:
# env summary (episode 138): {'order_requirements': 1000000, 'container_shortage': 437595, 'operation_number': 1257630}
# average env summary (episode 138): {'order_requirements': 1000000.0, 'container_shortage': 437595.0, 'operation_number': 1257630.0}
#
# Collecting result:
# env summary (episode 139): {'order_requirements': 1000000, 'container_shortage': 448501, 'operation_number': 1275202}
# average env summary (episode 139): {'order_requirements': 1000000.0, 'container_shortage': 448501.0, 'operation_number': 1275202.0}
#
# Collecting result:
# env summary (episode 140): {'order_requirements': 1000000, 'container_shortage': 396831, 'operation_number': 1476987}
# average env summary (episode 140): {'order_requirements': 1000000.0, 'container_shortage': 396831.0, 'operation_number': 1476987.0}
#
# Evaluation result:
# env summary (episode 140): {'order_requirements': 1000000, 'container_shortage': 828963, 'operation_number': 264236}
# average env summary (episode 140): {'order_requirements': 1000000.0, 'container_shortage': 828963.0, 'operation_number': 264236.0}
#
# Collecting result:
# env summary (episode 141): {'order_requirements': 1000000, 'container_shortage': 322212, 'operation_number': 1583822}
# average env summary (episode 141): {'order_requirements': 1000000.0, 'container_shortage': 322212.0, 'operation_number': 1583822.0}
#
# Collecting result:
# env summary (episode 142): {'order_requirements': 1000000, 'container_shortage': 387470, 'operation_number': 1461016}
# average env summary (episode 142): {'order_requirements': 1000000.0, 'container_shortage': 387470.0, 'operation_number': 1461016.0}
#
# Collecting result:
# env summary (episode 143): {'order_requirements': 1000000, 'container_shortage': 314466, 'operation_number': 1553326}
# average env summary (episode 143): {'order_requirements': 1000000.0, 'container_shortage': 314466.0, 'operation_number': 1553326.0}
#
# Collecting result:
# env summary (episode 144): {'order_requirements': 1000000, 'container_shortage': 408954, 'operation_number': 1321140}
# average env summary (episode 144): {'order_requirements': 1000000.0, 'container_shortage': 408954.0, 'operation_number': 1321140.0}
#
# Collecting result:
# env summary (episode 145): {'order_requirements': 1000000, 'container_shortage': 325838, 'operation_number': 1509208}
# average env summary (episode 145): {'order_requirements': 1000000.0, 'container_shortage': 325838.0, 'operation_number': 1509208.0}
#
# Evaluation result:
# env summary (episode 145): {'order_requirements': 1000000, 'container_shortage': 828963, 'operation_number': 264236}
# average env summary (episode 145): {'order_requirements': 1000000.0, 'container_shortage': 828963.0, 'operation_number': 264236.0}
#
# Collecting result:
# env summary (episode 146): {'order_requirements': 1000000, 'container_shortage': 445189, 'operation_number': 1240684}
# average env summary (episode 146): {'order_requirements': 1000000.0, 'container_shortage': 445189.0, 'operation_number': 1240684.0}
#
# Collecting result:
# env summary (episode 147): {'order_requirements': 1000000, 'container_shortage': 316105, 'operation_number': 1507986}
# average env summary (episode 147): {'order_requirements': 1000000.0, 'container_shortage': 316105.0, 'operation_number': 1507986.0}
#
# Collecting result:
# env summary (episode 148): {'order_requirements': 1000000, 'container_shortage': 543836, 'operation_number': 997282}
# average env summary (episode 148): {'order_requirements': 1000000.0, 'container_shortage': 543836.0, 'operation_number': 997282.0}
#
# Collecting result:
# env summary (episode 149): {'order_requirements': 1000000, 'container_shortage': 433972, 'operation_number': 1230270}
# average env summary (episode 149): {'order_requirements': 1000000.0, 'container_shortage': 433972.0, 'operation_number': 1230270.0}
#
# Collecting result:
# env summary (episode 150): {'order_requirements': 1000000, 'container_shortage': 478633, 'operation_number': 1269717}
# average env summary (episode 150): {'order_requirements': 1000000.0, 'container_shortage': 478633.0, 'operation_number': 1269717.0}
#
# ...
# average env summary (episode 751): {'order_requirements': 1000000.0, 'container_shortage': 807955.0, 'operation_number': 308665.0}
#
# Collecting result:
# env summary (episode 752): {'order_requirements': 1000000, 'container_shortage': 652743, 'operation_number': 648384}
# average env summary (episode 752): {'order_requirements': 1000000.0, 'container_shortage': 652743.0, 'operation_number': 648384.0}
#
# Collecting result:
# env summary (episode 753): {'order_requirements': 1000000, 'container_shortage': 750080, 'operation_number': 432850}
# average env summary (episode 753): {'order_requirements': 1000000.0, 'container_shortage': 750080.0, 'operation_number': 432850.0}
#
# Collecting result:
# env summary (episode 754): {'order_requirements': 1000000, 'container_shortage': 661095, 'operation_number': 604912}
# average env summary (episode 754): {'order_requirements': 1000000.0, 'container_shortage': 661095.0, 'operation_number': 604912.0}
#
# Collecting result:
# env summary (episode 755): {'order_requirements': 1000000, 'container_shortage': 764522, 'operation_number': 405716}
# average env summary (episode 755): {'order_requirements': 1000000.0, 'container_shortage': 764522.0, 'operation_number': 405716.0}
#
# Evaluation result:
# env summary (episode 755): {'order_requirements': 1000000, 'container_shortage': 810346, 'operation_number': 297320}
# average env summary (episode 755): {'order_requirements': 1000000.0, 'container_shortage': 810346.0, 'operation_number': 297320.0}
#
# Collecting result:
# env summary (episode 756): {'order_requirements': 1000000, 'container_shortage': 722658, 'operation_number': 579087}
# average env summary (episode 756): {'order_requirements': 1000000.0, 'container_shortage': 722658.0, 'operation_number': 579087.0}
#
# Collecting result:
# env summary (episode 757): {'order_requirements': 1000000, 'container_shortage': 760874, 'operation_number': 411844}
# average env summary (episode 757): {'order_requirements': 1000000.0, 'container_shortage': 760874.0, 'operation_number': 411844.0}
#
# Collecting result:
# env summary (episode 758): {'order_requirements': 1000000, 'container_shortage': 804453, 'operation_number': 320067}
# average env summary (episode 758): {'order_requirements': 1000000.0, 'container_shortage': 804453.0, 'operation_number': 320067.0}
#
# Collecting result:
# env summary (episode 759): {'order_requirements': 1000000, 'container_shortage': 808284, 'operation_number': 325177}
# average env summary (episode 759): {'order_requirements': 1000000.0, 'container_shortage': 808284.0, 'operation_number': 325177.0}
#
# Collecting result:
# env summary (episode 760): {'order_requirements': 1000000, 'container_shortage': 791574, 'operation_number': 346994}
# average env summary (episode 760): {'order_requirements': 1000000.0, 'container_shortage': 791574.0, 'operation_number': 346994.0}
#
# Evaluation result:
# env summary (episode 760): {'order_requirements': 1000000, 'container_shortage': 810346, 'operation_number': 297320}
# average env summary (episode 760): {'order_requirements': 1000000.0, 'container_shortage': 810346.0, 'operation_number': 297320.0}
#
# Collecting result:
# env summary (episode 761): {'order_requirements': 1000000, 'container_shortage': 804548, 'operation_number': 320802}
# average env summary (episode 761): {'order_requirements': 1000000.0, 'container_shortage': 804548.0, 'operation_number': 320802.0}
#
# Collecting result:
# env summary (episode 762): {'order_requirements': 1000000, 'container_shortage': 739282, 'operation_number': 450595}
# average env summary (episode 762): {'order_requirements': 1000000.0, 'container_shortage': 739282.0, 'operation_number': 450595.0}
#
# Collecting result:
# env summary (episode 763): {'order_requirements': 1000000, 'container_shortage': 825702, 'operation_number': 275518}
# average env summary (episode 763): {'order_requirements': 1000000.0, 'container_shortage': 825702.0, 'operation_number': 275518.0}
#
# Collecting result:
# env summary (episode 764): {'order_requirements': 1000000, 'container_shortage': 702033, 'operation_number': 530338}
# average env summary (episode 764): {'order_requirements': 1000000.0, 'container_shortage': 702033.0, 'operation_number': 530338.0}
#
# Collecting result:
# env summary (episode 765): {'order_requirements': 1000000, 'container_shortage': 769898, 'operation_number': 394651}
# average env summary (episode 765): {'order_requirements': 1000000.0, 'container_shortage': 769898.0, 'operation_number': 394651.0}
#
# Evaluation result:
# env summary (episode 765): {'order_requirements': 1000000, 'container_shortage': 810346, 'operation_number': 297320}
# average env summary (episode 765): {'order_requirements': 1000000.0, 'container_shortage': 810346.0, 'operation_number': 297320.0}
#
# Collecting result:
# env summary (episode 766): {'order_requirements': 1000000, 'container_shortage': 766727, 'operation_number': 393036}
# average env summary (episode 766): {'order_requirements': 1000000.0, 'container_shortage': 766727.0, 'operation_number': 393036.0}
#
# Collecting result:
# env summary (episode 767): {'order_requirements': 1000000, 'container_shortage': 798247, 'operation_number': 331648}
# average env summary (episode 767): {'order_requirements': 1000000.0, 'container_shortage': 798247.0, 'operation_number': 331648.0}
#
# Collecting result:
# env summary (episode 768): {'order_requirements': 1000000, 'container_shortage': 721334, 'operation_number': 486144}
# average env summary (episode 768): {'order_requirements': 1000000.0, 'container_shortage': 721334.0, 'operation_number': 486144.0}
#
# Collecting result:
# env summary (episode 769): {'order_requirements': 1000000, 'container_shortage': 832801, 'operation_number': 260390}
# average env summary (episode 769): {'order_requirements': 1000000.0, 'container_shortage': 832801.0, 'operation_number': 260390.0}
#
# Collecting result:
# env summary (episode 770): {'order_requirements': 1000000, 'container_shortage': 827772, 'operation_number': 267614}
# average env summary (episode 770): {'order_requirements': 1000000.0, 'container_shortage': 827772.0, 'operation_number': 267614.0}
#
# Evaluation result:
# env summary (episode 770): {'order_requirements': 1000000, 'container_shortage': 810346, 'operation_number': 297320}
# average env summary (episode 770): {'order_requirements': 1000000.0, 'container_shortage': 810346.0, 'operation_number': 297320.0}
#
# Collecting result:
# env summary (episode 771): {'order_requirements': 1000000, 'container_shortage': 808281, 'operation_number': 310542}
# average env summary (episode 771): {'order_requirements': 1000000.0, 'container_shortage': 808281.0, 'operation_number': 310542.0}
#
# Collecting result:
# env summary (episode 772): {'order_requirements': 1000000, 'container_shortage': 794721, 'operation_number': 342986}
# average env summary (episode 772): {'order_requirements': 1000000.0, 'container_shortage': 794721.0, 'operation_number': 342986.0}
#
# Collecting result:
# env summary (episode 773): {'order_requirements': 1000000, 'container_shortage': 791106, 'operation_number': 346518}
# average env summary (episode 773): {'order_requirements': 1000000.0, 'container_shortage': 791106.0, 'operation_number': 346518.0}
#
# Collecting result:
# env summary (episode 774): {'order_requirements': 1000000, 'container_shortage': 796671, 'operation_number': 337095}
# average env summary (episode 774): {'order_requirements': 1000000.0, 'container_shortage': 796671.0, 'operation_number': 337095.0}
#
# Collecting result:
# env summary (episode 775): {'order_requirements': 1000000, 'container_shortage': 791792, 'operation_number': 352216}
# average env summary (episode 775): {'order_requirements': 1000000.0, 'container_shortage': 791792.0, 'operation_number': 352216.0}
#
# Evaluation result:
# env summary (episode 775): {'order_requirements': 1000000, 'container_shortage': 810346, 'operation_number': 297320}
# average env summary (episode 775): {'order_requirements': 1000000.0, 'container_shortage': 810346.0, 'operation_number': 297320.0}
#
# Collecting result:
# env summary (episode 776): {'order_requirements': 1000000, 'container_shortage': 718256, 'operation_number': 499404}
# average env summary (episode 776): {'order_requirements': 1000000.0, 'container_shortage': 718256.0, 'operation_number': 499404.0}
#
# Collecting result:
# env summary (episode 777): {'order_requirements': 1000000, 'container_shortage': 794367, 'operation_number': 343213}
# average env summary (episode 777): {'order_requirements': 1000000.0, 'container_shortage': 794367.0, 'operation_number': 343213.0}
#
# Collecting result:
# env summary (episode 778): {'order_requirements': 1000000, 'container_shortage': 836372, 'operation_number': 253735}
# average env summary (episode 778): {'order_requirements': 1000000.0, 'container_shortage': 836372.0, 'operation_number': 253735.0}
#
# Collecting result:
# env summary (episode 779): {'order_requirements': 1000000, 'container_shortage': 780961, 'operation_number': 371486}
# average env summary (episode 779): {'order_requirements': 1000000.0, 'container_shortage': 780961.0, 'operation_number': 371486.0}
#
# Collecting result:
# env summary (episode 780): {'order_requirements': 1000000, 'container_shortage': 762042, 'operation_number': 404640}
# average env summary (episode 780): {'order_requirements': 1000000.0, 'container_shortage': 762042.0, 'operation_number': 404640.0}
#
# Evaluation result:
# env summary (episode 780): {'order_requirements': 1000000, 'container_shortage': 950000, 'operation_number': 0}
# average env summary (episode 780): {'order_requirements': 1000000.0, 'container_shortage': 950000.0, 'operation_number': 0.0}
#
# Collecting result:
# env summary (episode 781): {'order_requirements': 1000000, 'container_shortage': 776226, 'operation_number': 380577}
# average env summary (episode 781): {'order_requirements': 1000000.0, 'container_shortage': 776226.0, 'operation_number': 380577.0}
#
# Collecting result:
# env summary (episode 782): {'order_requirements': 1000000, 'container_shortage': 766267, 'operation_number': 400648}
# average env summary (episode 782): {'order_requirements': 1000000.0, 'container_shortage': 766267.0, 'operation_number': 400648.0}
#
# Collecting result:
# env summary (episode 783): {'order_requirements': 1000000, 'container_shortage': 792110, 'operation_number': 349149}
# average env summary (episode 783): {'order_requirements': 1000000.0, 'container_shortage': 792110.0, 'operation_number': 349149.0}
#
# Collecting result:
# env summary (episode 784): {'order_requirements': 1000000, 'container_shortage': 786593, 'operation_number': 361850}
# average env summary (episode 784): {'order_requirements': 1000000.0, 'container_shortage': 786593.0, 'operation_number': 361850.0}
#
# Collecting result:
# env summary (episode 785): {'order_requirements': 1000000, 'container_shortage': 789356, 'operation_number': 352778}
# average env summary (episode 785): {'order_requirements': 1000000.0, 'container_shortage': 789356.0, 'operation_number': 352778.0}
#
# Evaluation result:
# env summary (episode 785): {'order_requirements': 1000000, 'container_shortage': 950000, 'operation_number': 0}
# average env summary (episode 785): {'order_requirements': 1000000.0, 'container_shortage': 950000.0, 'operation_number': 0.0}
#
# Collecting result:
# env summary (episode 786): {'order_requirements': 1000000, 'container_shortage': 825597, 'operation_number': 284418}
# average env summary (episode 786): {'order_requirements': 1000000.0, 'container_shortage': 825597.0, 'operation_number': 284418.0}
#
# Collecting result:
# env summary (episode 787): {'order_requirements': 1000000, 'container_shortage': 767694, 'operation_number': 394620}
# average env summary (episode 787): {'order_requirements': 1000000.0, 'container_shortage': 767694.0, 'operation_number': 394620.0}
#
# Collecting result:
# env summary (episode 788): {'order_requirements': 1000000, 'container_shortage': 681718, 'operation_number': 585425}
# average env summary (episode 788): {'order_requirements': 1000000.0, 'container_shortage': 681718.0, 'operation_number': 585425.0}
#
# Collecting result:
# env summary (episode 789): {'order_requirements': 1000000, 'container_shortage': 768817, 'operation_number': 403170}
# average env summary (episode 789): {'order_requirements': 1000000.0, 'container_shortage': 768817.0, 'operation_number': 403170.0}
#
# Collecting result:
# env summary (episode 790): {'order_requirements': 1000000, 'container_shortage': 852584, 'operation_number': 229671}
# average env summary (episode 790): {'order_requirements': 1000000.0, 'container_shortage': 852584.0, 'operation_number': 229671.0}
#
# Evaluation result:
# env summary (episode 790): {'order_requirements': 1000000, 'container_shortage': 950000, 'operation_number': 0}
# average env summary (episode 790): {'order_requirements': 1000000.0, 'container_shortage': 950000.0, 'operation_number': 0.0}
#
# Collecting result:
# env summary (episode 791): {'order_requirements': 1000000, 'container_shortage': 754223, 'operation_number': 429627}
# average env summary (episode 791): {'order_requirements': 1000000.0, 'container_shortage': 754223.0, 'operation_number': 429627.0}
#
# Collecting result:
# env summary (episode 792): {'order_requirements': 1000000, 'container_shortage': 816533, 'operation_number': 297339}
# average env summary (episode 792): {'order_requirements': 1000000.0, 'container_shortage': 816533.0, 'operation_number': 297339.0}
#
# Collecting result:
# env summary (episode 793): {'order_requirements': 1000000, 'container_shortage': 767895, 'operation_number': 398181}
# average env summary (episode 793): {'order_requirements': 1000000.0, 'container_shortage': 767895.0, 'operation_number': 398181.0}
#
# Collecting result:
# env summary (episode 794): {'order_requirements': 1000000, 'container_shortage': 815406, 'operation_number': 301050}
# average env summary (episode 794): {'order_requirements': 1000000.0, 'container_shortage': 815406.0, 'operation_number': 301050.0}
#
# Collecting result:
# env summary (episode 795): {'order_requirements': 1000000, 'container_shortage': 749069, 'operation_number': 460342}
# average env summary (episode 795): {'order_requirements': 1000000.0, 'container_shortage': 749069.0, 'operation_number': 460342.0}
#
# Evaluation result:
# env summary (episode 795): {'order_requirements': 1000000, 'container_shortage': 950000, 'operation_number': 0}
# average env summary (episode 795): {'order_requirements': 1000000.0, 'container_shortage': 950000.0, 'operation_number': 0.0}
#
# Collecting result:
# env summary (episode 796): {'order_requirements': 1000000, 'container_shortage': 823703, 'operation_number': 282136}
# average env summary (episode 796): {'order_requirements': 1000000.0, 'container_shortage': 823703.0, 'operation_number': 282136.0}
#
# Collecting result:
# env summary (episode 797): {'order_requirements': 1000000, 'container_shortage': 853196, 'operation_number': 223851}
# average env summary (episode 797): {'order_requirements': 1000000.0, 'container_shortage': 853196.0, 'operation_number': 223851.0}
#
# Collecting result:
# env summary (episode 798): {'order_requirements': 1000000, 'container_shortage': 744958, 'operation_number': 439740}
# average env summary (episode 798): {'order_requirements': 1000000.0, 'container_shortage': 744958.0, 'operation_number': 439740.0}
#
# Collecting result:
# env summary (episode 799): {'order_requirements': 1000000, 'container_shortage': 799708, 'operation_number': 324194}
# average env summary (episode 799): {'order_requirements': 1000000.0, 'container_shortage': 799708.0, 'operation_number': 324194.0}
#
# Collecting result:
# env summary (episode 800): {'order_requirements': 1000000, 'container_shortage': 674072, 'operation_number': 607668}
# average env summary (episode 800): {'order_requirements': 1000000.0, 'container_shortage': 674072.0, 'operation_number': 607668.0}
#
# Evaluation result:
# env summary (episode 800): {'order_requirements': 1000000, 'container_shortage': 950000, 'operation_number': 0}
# average env summary (episode 800): {'order_requirements': 1000000.0, 'container_shortage': 950000.0, 'operation_number': 0.0}
